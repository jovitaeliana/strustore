# %% [markdown]
# ## SAM Inference

# %%
CONF = "2"
# Input and output directories: YJPA
# PREPROCESSED = "../yjpa_scraper/items_listing/preprocessed"
# OUTPUT = "../yjpa_scraper/items_listing/sam/output/conf_"+CONF
# OUTPUT_LBL = "../yjpa_scraper/items_listing/sam/output_labels/conf_"+CONF
# OUTPUT_DP = "../yjpa_scraper/items_listing/sam/output_display/conf_"+CONF
# TEXT_PROMPT_CSV = "../yjpa_scraper/items-prompt.csv"

# Input and output directories: ZM 
PREPROCESSED = "../zm_scraper/auctions/preprocessed"
OUTPUT = "../zm_scraper/auctions/sam/output/conf_"+CONF
OUTPUT_LBL = "../zm_scraper/auctions/sam/output_labels/conf_"+CONF
OUTPUT_DP = "../zm_scraper/auctions/sam/output_display/conf_"+CONF
TEXT_PROMPT_CSV = "../zm_scraper/items-prompt.csv"

# %%
SAM_CHECKPOINT = "./weights/sam_vit_h_4b8939.pth"
SAM_MODEL_TYPE = "vit_h"
DEVICE = "cuda"

# SAM Thresholds
POINTS_PER_SIDE = 32         # Higher = more masks (64/32/16)
PRED_IOU_THRESH = 0.8         # Higher = more confident masks
STABILITY_SCORE_THRESH = 0.9 # Higher = more stable masks
BOX_NMS_THRESH = 0.3 
MIN_MASK_REGION_AREA = 0   # Ignore small blobs (in pixels)

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator

valid_image_ext = [".jpg", ".jpeg", ".png"]

# Load SAM
sam = sam_model_registry[SAM_MODEL_TYPE](checkpoint=SAM_CHECKPOINT)
sam.to(device=DEVICE)

mask_generator = SamAutomaticMaskGenerator(
    model=sam,
    points_per_side=POINTS_PER_SIDE,
    pred_iou_thresh=PRED_IOU_THRESH,
    stability_score_thresh=STABILITY_SCORE_THRESH,
    box_nms_thresh = BOX_NMS_THRESH,
    min_mask_region_area=MIN_MASK_REGION_AREA
)
# default SAMAutomaticMaskGenerator func from github
# mask_generator = SamAutomaticMaskGenerator(
#         model=sam,
#         points_per_side = 16,
#         points_per_batch = 64,
#         pred_iou_thresh = 0.88,
#         stability_score_thresh = 0.95,
#         stability_score_offset = 1.0,
#         box_nms_thresh = 0.7,
#         crop_n_layers = 0,
#         crop_nms_thresh = 0.7,
#         crop_overlap_ratio = 512 / 1500,
#         crop_n_points_downscale_factor = 1,
#         point_grids = None,
#         min_mask_region_area = 1000,
# )

def process_images_for_item(
    input_folder,
    output_images_folder,
    output_labels_folder,
    item_id
):
    os.makedirs(output_images_folder, exist_ok=True)
    os.makedirs(output_labels_folder, exist_ok=True)

    image_paths = [
        os.path.join(input_folder, img)
        for img in sorted(os.listdir(input_folder))
        if os.path.splitext(img)[1].lower() in valid_image_ext
    ]

    if not image_paths:
        print(f"[{item_id}] No images found in {input_folder}. Skipping.")
        return

    for img_path in image_paths:
        filename = os.path.basename(img_path)
        base_filename = os.path.splitext(filename)[0]

        # Load with alpha if it exists
        img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
        alpha_mask = None
        if img is None:
            print(f"[{item_id}] Could not read {img_path}. Skipping.")
            continue

        if img.shape[2] == 4:
            # Split channels
            bgr = img[..., :3]
            alpha = img[..., 3]

            # Create a mask where alpha > 0
            alpha_mask = alpha > 0
            
            # Convert to RGB
            img_rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
            
            # Set fully transparent pixels to magenta
            img_rgb[~alpha_mask] = np.array([255, 0, 255], dtype=np.uint8)

        else:
            # No alpha, normal RGB
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


        # Generate masks
        masks = mask_generator.generate(img_rgb)
        
        # Save masks as .npy file
        masks_array = [mask["segmentation"] for mask in masks]
        output_mask_path = os.path.join(output_labels_folder, base_filename + ".npy")
        np.save(output_mask_path, masks_array)

        # Annotate image by overlaying masks
        annotated = img_rgb.copy()
        for mask in masks:
            segmentation = mask["segmentation"]
            color = np.random.randint(0, 255, (3,), dtype=np.uint8)
            annotated[segmentation] = annotated[segmentation] * 0.4 + color * 0.6

        # Save annotated image
        output_img_path = os.path.join(output_images_folder, base_filename + ".jpg")
        cv2.imwrite(output_img_path, cv2.cvtColor(annotated, cv2.COLOR_RGB2BGR))

        print(f"[{item_id}] Processed {filename} ({len(masks)} masks saved as npy and annotated image)")

def batch_process_sam(
    items_list_csv,
    input_base_dir,
    output_images_base_dir,
    output_labels_base_dir
):
    df = pd.read_csv(items_list_csv, usecols=["id"])
    ids = df["id"].astype(str).tolist()
    
    for item_id in ids:
        input_folder = os.path.join(input_base_dir, item_id)
        output_images_folder = os.path.join(output_images_base_dir, item_id)
        output_labels_folder = os.path.join(output_labels_base_dir, item_id)

        if not os.path.exists(input_folder):
            print(f"[{item_id}] Input folder {input_folder} does not exist. Skipping.")
            continue
        
        # Clear GPU cache with every item
        torch.cuda.empty_cache()
        process_images_for_item(
            input_folder=input_folder,
            output_images_folder=output_images_folder,
            output_labels_folder=output_labels_folder,
            item_id=item_id
        )
    print("All Complete!")

# -------------------------------------------------------------
# Main usage
# -------------------------------------------------------------
if __name__ == "__main__":
    batch_process_sam(
        items_list_csv=TEXT_PROMPT_CSV,
        input_base_dir=PREPROCESSED,
        output_images_base_dir=OUTPUT,
        output_labels_base_dir=OUTPUT_LBL
    )
# Out:
# [1] Processed 1183014126.png (26 masks saved as npy and annotated image)
# [1] Processed 1187040966.png (52 masks saved as npy and annotated image)
# [1] Processed 1187259405.png (8 masks saved as npy and annotated image)
# [1] Processed 1188971238.png (15 masks saved as npy and annotated image)
# [1] Processed 1190862523.png (37 masks saved as npy and annotated image)
# [1] Processed 1190947766.png (65 masks saved as npy and annotated image)
# [1] Processed 1191384462.png (35 masks saved as npy and annotated image)
# [1] Processed b1094792463.png (28 masks saved as npy and annotated image)
# [1] Processed b1183312199.png (113 masks saved as npy and annotated image)
# [1] Processed b1187681880.png (18 masks saved as npy and annotated image)
# [1] Processed b1190374058.png (14 masks saved as npy and annotated image)
# [1] Processed b1191454294.png (13 masks saved as npy and annotated image)
# [1] Processed c1018322104.png (32 masks saved as npy and annotated image)
# [1] Processed c1174455551.png (39 masks saved as npy and annotated image)
# [1] Processed c1176991774.png (35 masks saved as npy and annotated image)
# [1] Processed c1179281381.png (37 masks saved as npy and annotated image)
# [1] Processed c1181899488.png (24 masks saved as npy and annotated image)
# [1] Processed c1186222082.png (9 masks saved as npy and annotated image)
# [1] Processed c1189274607.png (72 masks saved as npy and annotated image)
# [1] Processed c1190311877.png (17 masks saved as npy and annotated image)
# [1] Processed c1190560087.png (14 masks saved as npy and annotated image)
# [1] Processed c1190881000.png (29 masks saved as npy and annotated image)
# [1] Processed c1191011512.png (39 masks saved as npy and annotated image)
# [1] Processed c1191323690.png (34 masks saved as npy and annotated image)
# [1] Processed c1191614944.png (14 masks saved as npy and annotated image)
# [1] Processed d1183331003.png (7 masks saved as npy and annotated image)
# [1] Processed d1187227651.png (17 masks saved as npy and annotated image)
# [1] Processed d1191065516.png (80 masks saved as npy and annotated image)
# [1] Processed d1191230442.png (45 masks saved as npy and annotated image)
# [1] Processed e1144509373.png (12 masks saved as npy and annotated image)
# [1] Processed e1183317765.png (6 masks saved as npy and annotated image)
# [1] Processed e1191097669.png (20 masks saved as npy and annotated image)
# [1] Processed f1152247645.png (24 masks saved as npy and annotated image)
# [1] Processed f1171816057.png (50 masks saved as npy and annotated image)
# [1] Processed f1182381846.png (24 masks saved as npy and annotated image)
# [1] Processed f1185709506.png (35 masks saved as npy and annotated image)
# [1] Processed f1191458213.png (75 masks saved as npy and annotated image)
# [1] Processed f1191614095.png (16 masks saved as npy and annotated image)
# [1] Processed g1121969050.png (52 masks saved as npy and annotated image)
# [1] Processed g1162120624.png (6 masks saved as npy and annotated image)
# [1] Processed g1186111364.png (72 masks saved as npy and annotated image)
# [1] Processed g1187312653.png (20 masks saved as npy and annotated image)
# [1] Processed g1188338616.png (20 masks saved as npy and annotated image)
# [1] Processed g1190646585.png (17 masks saved as npy and annotated image)
# [1] Processed g1190860301.png (20 masks saved as npy and annotated image)
# [1] Processed g1190999084.png (46 masks saved as npy and annotated image)
# [1] Processed g1191217110.png (113 masks saved as npy and annotated image)
# [1] Processed h1155548441.png (17 masks saved as npy and annotated image)
# [1] Processed h1175361047.png (35 masks saved as npy and annotated image)
# [1] Processed h1179263795.png (41 masks saved as npy and annotated image)
# [1] Processed h1180981091.png (19 masks saved as npy and annotated image)
# [1] Processed h1191354377.png (17 masks saved as npy and annotated image)
# [1] Processed h1191357858.png (13 masks saved as npy and annotated image)
# [1] Processed h1191485348.png (8 masks saved as npy and annotated image)
# [1] Processed h1191494654.png (37 masks saved as npy and annotated image)
# [1] Processed h1191566508.png (14 masks saved as npy and annotated image)
# [1] Processed h1191606615.png (95 masks saved as npy and annotated image)
# [1] Processed j1155396060.png (28 masks saved as npy and annotated image)
# [1] Processed j1187062556.png (57 masks saved as npy and annotated image)
# [1] Processed j1188522884.png (13 masks saved as npy and annotated image)
# [1] Processed j1190303466.png (21 masks saved as npy and annotated image)
# [1] Processed j1191354950.png (13 masks saved as npy and annotated image)
# [1] Processed j1191431672.png (99 masks saved as npy and annotated image)
# [1] Processed k1178398503.png (12 masks saved as npy and annotated image)
# [1] Processed k1185974489.png (8 masks saved as npy and annotated image)
# [1] Processed k1187236896.png (19 masks saved as npy and annotated image)
# [1] Processed k1190017607.png (8 masks saved as npy and annotated image)
# [1] Processed k1190557636.png (13 masks saved as npy and annotated image)
# [1] Processed k1190934472.png (8 masks saved as npy and annotated image)
# [1] Processed k1190957510.png (81 masks saved as npy and annotated image)
# [1] Processed k1191139466.png (6 masks saved as npy and annotated image)
# [1] Processed k1191177775.png (27 masks saved as npy and annotated image)
# [1] Processed k1191345098.png (32 masks saved as npy and annotated image)
# [1] Processed k1191395334.png (15 masks saved as npy and annotated image)
# [1] Processed k1191474797.png (88 masks saved as npy and annotated image)
# [1] Processed k1191477198.png (28 masks saved as npy and annotated image)
# [1] Processed l1163916088.png (61 masks saved as npy and annotated image)
# [1] Processed l1173943616.png (71 masks saved as npy and annotated image)
# [1] Processed l1180181252.png (9 masks saved as npy and annotated image)
# [1] Processed l1182133390.png (35 masks saved as npy and annotated image)
# [1] Processed l1185983984.png (11 masks saved as npy and annotated image)
# [1] Processed l1187215014.png (26 masks saved as npy and annotated image)
# [1] Processed l1187709741.png (76 masks saved as npy and annotated image)
# [1] Processed l1188323777.png (23 masks saved as npy and annotated image)
# [1] Processed l1188981602.png (14 masks saved as npy and annotated image)
# [1] Processed l1190559645.png (8 masks saved as npy and annotated image)
# [1] Processed l1190830129.png (10 masks saved as npy and annotated image)
# [1] Processed m1133776499.png (42 masks saved as npy and annotated image)
# [1] Processed m1168646860.png (28 masks saved as npy and annotated image)
# [1] Processed m1174452367.png (22 masks saved as npy and annotated image)
# [1] Processed m1187216150.png (12 masks saved as npy and annotated image)
# [1] Processed m1188973836.png (42 masks saved as npy and annotated image)
# [1] Processed m1191510476.png (32 masks saved as npy and annotated image)
# [1] Processed n1050873591.png (73 masks saved as npy and annotated image)
# [1] Processed n1177515783.png (31 masks saved as npy and annotated image)
# [1] Processed n1177560446.png (19 masks saved as npy and annotated image)
# [1] Processed n1181963058.png (41 masks saved as npy and annotated image)
# [1] Processed n1184979547.png (43 masks saved as npy and annotated image)
# [1] Processed n1189266389.png (44 masks saved as npy and annotated image)
# [1] Processed n1190306474.png (79 masks saved as npy and annotated image)
# [1] Processed n1191590384.png (29 masks saved as npy and annotated image)
# [1] Processed n1191681464.png (50 masks saved as npy and annotated image)
# [1] Processed n1191690494.png (114 masks saved as npy and annotated image)
# [1] Processed o1111669448.png (31 masks saved as npy and annotated image)
# [1] Processed o1119853616.png (28 masks saved as npy and annotated image)
# [1] Processed o1148253450.png (29 masks saved as npy and annotated image)
# [1] Processed o1186239441.png (30 masks saved as npy and annotated image)
# [1] Processed o1187637806.png (26 masks saved as npy and annotated image)
# [1] Processed o1190507451.png (72 masks saved as npy and annotated image)
# [1] Processed o1190563887.png (6 masks saved as npy and annotated image)
# [1] Processed o1191069257.png (46 masks saved as npy and annotated image)
# [1] Processed p1127453774.png (45 masks saved as npy and annotated image)
# [1] Processed p1183630489.png (53 masks saved as npy and annotated image)
# [1] Processed p1185977494.png (10 masks saved as npy and annotated image)
# [1] Processed p1187246330.png (11 masks saved as npy and annotated image)
# [1] Processed p1188910687.png (60 masks saved as npy and annotated image)
# [1] Processed p1190564688.png (9 masks saved as npy and annotated image)
# [1] Processed p1190570350.png (14 masks saved as npy and annotated image)
# [1] Processed q1169973454.png (81 masks saved as npy and annotated image)
# [1] Processed q1177578657.png (24 masks saved as npy and annotated image)
# [1] Processed q1177627244.png (18 masks saved as npy and annotated image)
# [1] Processed q1180810479.png (56 masks saved as npy and annotated image)
# [1] Processed q1183324759.png (32 masks saved as npy and annotated image)
# [1] Processed q1185787171.png (41 masks saved as npy and annotated image)
# [1] Processed q1187025650.png (21 masks saved as npy and annotated image)
# [1] Processed q1187396416.png (61 masks saved as npy and annotated image)
# [1] Processed q1188300755.png (45 masks saved as npy and annotated image)
# [1] Processed q1189807341.png (28 masks saved as npy and annotated image)
# [1] Processed q1190933101.png (66 masks saved as npy and annotated image)
# [1] Processed q1190999908.png (46 masks saved as npy and annotated image)
# [1] Processed q1191392184.png (26 masks saved as npy and annotated image)
# [1] Processed q1191599905.png (74 masks saved as npy and annotated image)
# [1] Processed q1191671881.png (119 masks saved as npy and annotated image)
# [1] Processed r1140105858.png (42 masks saved as npy and annotated image)
# [1] Processed r1172860507.png (25 masks saved as npy and annotated image)
# [1] Processed r1186986297.png (32 masks saved as npy and annotated image)
# [1] Processed r1188237662.png (48 masks saved as npy and annotated image)
# [1] Processed r1188366109.png (14 masks saved as npy and annotated image)
# [1] Processed r1189452439.png (41 masks saved as npy and annotated image)
# [1] Processed r1190826351.png (12 masks saved as npy and annotated image)
# [1] Processed r1190987605.png (49 masks saved as npy and annotated image)
# [1] Processed r1191213977.png (44 masks saved as npy and annotated image)
# [1] Processed r1191406191.png (27 masks saved as npy and annotated image)
# [1] Processed s1119897266.png (11 masks saved as npy and annotated image)
# [1] Processed s1158964294.png (38 masks saved as npy and annotated image)
# [1] Processed s1174518776.png (18 masks saved as npy and annotated image)
# [1] Processed s1175248638.png (31 masks saved as npy and annotated image)
# [1] Processed s1178157340.png (21 masks saved as npy and annotated image)
# [1] Processed s1180179542.png (18 masks saved as npy and annotated image)
# [1] Processed s1190129857.png (70 masks saved as npy and annotated image)
# [1] Processed s1190829449.png (15 masks saved as npy and annotated image)
# [1] Processed s1191227795.png (120 masks saved as npy and annotated image)
# [1] Processed s1191791966.png (19 masks saved as npy and annotated image)
# [1] Processed t1144496280.png (9 masks saved as npy and annotated image)
# [1] Processed t1175000873.png (55 masks saved as npy and annotated image)
# [1] Processed t1185967298.png (17 masks saved as npy and annotated image)
# [1] Processed t1189958345.png (27 masks saved as npy and annotated image)
# [1] Processed t1190248790.png (18 masks saved as npy and annotated image)
# [1] Processed t1190954755.png (107 masks saved as npy and annotated image)
# [1] Processed t1191463002.png (18 masks saved as npy and annotated image)
# [1] Processed u1125653836.png (32 masks saved as npy and annotated image)
# [1] Processed u1173708917.png (28 masks saved as npy and annotated image)
# [1] Processed u1175252424.png (32 masks saved as npy and annotated image)
# [1] Processed u1177556155.png (27 masks saved as npy and annotated image)
# [1] Processed u1185912108.png (21 masks saved as npy and annotated image)
# [1] Processed u1187634347.png (73 masks saved as npy and annotated image)
# [1] Processed u1187785966.png (99 masks saved as npy and annotated image)
# [1] Processed u1190891670.png (120 masks saved as npy and annotated image)
# [1] Processed u1191585367.png (37 masks saved as npy and annotated image)
# [1] Processed v1120503911.png (46 masks saved as npy and annotated image)
# [1] Processed v1157073564.png (31 masks saved as npy and annotated image)
# [1] Processed v1173706351.png (18 masks saved as npy and annotated image)
# [1] Processed v1181907375.png (31 masks saved as npy and annotated image)
# [1] Processed v1184067515.png (139 masks saved as npy and annotated image)
# [1] Processed v1184566023.png (27 masks saved as npy and annotated image)
# [1] Processed v1185996273.png (15 masks saved as npy and annotated image)
# [1] Processed v1187261662.png (19 masks saved as npy and annotated image)
# [1] Processed v1189794703.png (46 masks saved as npy and annotated image)
# [1] Processed v1190298402.png (53 masks saved as npy and annotated image)
# [1] Processed v1191007699.png (40 masks saved as npy and annotated image)
# [1] Processed v1191359696.png (81 masks saved as npy and annotated image)
# [1] Processed v1191543625.png (113 masks saved as npy and annotated image)
# [1] Processed w1156067263.png (28 masks saved as npy and annotated image)
# [1] Processed w1169319899.png (27 masks saved as npy and annotated image)
# [1] Processed w1181337501.png (14 masks saved as npy and annotated image)
# [1] Processed w1187675968.png (22 masks saved as npy and annotated image)
# [1] Processed w1190844926.png (62 masks saved as npy and annotated image)
# [1] Processed w1190845066.png (19 masks saved as npy and annotated image)
# [1] Processed w1190871465.png (40 masks saved as npy and annotated image)
# [1] Processed w1191415731.png (21 masks saved as npy and annotated image)
# [1] Processed x1121603563.png (45 masks saved as npy and annotated image)
# [1] Processed x1144495093.png (15 masks saved as npy and annotated image)
# [1] Processed x1144497640.png (14 masks saved as npy and annotated image)
# [1] Processed x1179990049.png (14 masks saved as npy and annotated image)
# [1] Processed x1187673916.png (41 masks saved as npy and annotated image)
# [1] Processed x1189677434.png (30 masks saved as npy and annotated image)
# [1] Processed x1190805798.png (58 masks saved as npy and annotated image)
# [1] Processed x1191588773.png (43 masks saved as npy and annotated image)
# [1] Processed x1191598905.png (40 masks saved as npy and annotated image)
# [1] Processed x1191726070.png (30 masks saved as npy and annotated image)
# [2] Processed 1183422386.png (71 masks saved as npy and annotated image)
# [2] Processed 1184973984.png (56 masks saved as npy and annotated image)
# [2] Processed 1191044626.png (80 masks saved as npy and annotated image)
# [2] Processed 1191541604.png (60 masks saved as npy and annotated image)
# [2] Processed 1191618378.png (38 masks saved as npy and annotated image)
# [2] Processed b1174068183.png (44 masks saved as npy and annotated image)
# [2] Processed b1188791317.png (37 masks saved as npy and annotated image)
# [2] Processed b1190826799.png (35 masks saved as npy and annotated image)
# [2] Processed b1191603128.png (88 masks saved as npy and annotated image)
# [2] Processed c1132411431.png (70 masks saved as npy and annotated image)
# [2] Processed c1187483831.png (60 masks saved as npy and annotated image)
# [2] Processed c1191308923.png (74 masks saved as npy and annotated image)
# [2] Processed c1191755886.png (60 masks saved as npy and annotated image)
# [2] Processed c583016002.png (65 masks saved as npy and annotated image)
# [2] Processed d1191083725.png (40 masks saved as npy and annotated image)
# [2] Processed d1191104993.png (55 masks saved as npy and annotated image)
# [2] Processed d1191807097.png (62 masks saved as npy and annotated image)
# [2] Processed e1145787141.png (52 masks saved as npy and annotated image)
# [2] Processed e1191032005.png (99 masks saved as npy and annotated image)
# [2] Processed e1191332130.png (82 masks saved as npy and annotated image)
# [2] Processed f1109446657.png (42 masks saved as npy and annotated image)
# [2] Processed g1182426614.png (50 masks saved as npy and annotated image)
# [2] Processed g1191389421.png (47 masks saved as npy and annotated image)
# [2] Processed h1055489564.png (120 masks saved as npy and annotated image)
# [2] Processed j1188223998.png (59 masks saved as npy and annotated image)
# [2] Processed j1191314319.png (59 masks saved as npy and annotated image)
# [2] Processed j1191793085.png (74 masks saved as npy and annotated image)
# [2] Processed k1116223413.png (49 masks saved as npy and annotated image)
# [2] Processed k1141542872.png (100 masks saved as npy and annotated image)
# [2] Processed k1144655228.png (45 masks saved as npy and annotated image)
# [2] Processed k1184414767.png (31 masks saved as npy and annotated image)
# [2] Processed k1191027678.png (58 masks saved as npy and annotated image)
# [2] Processed l1171615527.png (32 masks saved as npy and annotated image)
# [2] Processed l1189425708.png (111 masks saved as npy and annotated image)
# [2] Processed l1191318353.png (78 masks saved as npy and annotated image)
# [2] Processed m1175679082.png (63 masks saved as npy and annotated image)
# [2] Processed m1190271639.png (59 masks saved as npy and annotated image)
# [2] Processed m1191712171.png (23 masks saved as npy and annotated image)
# [2] Processed n1175534688.png (64 masks saved as npy and annotated image)
# [2] Processed n1190154096.png (44 masks saved as npy and annotated image)
# [2] Processed n1190944641.png (28 masks saved as npy and annotated image)
# [2] Processed n1191483955.png (58 masks saved as npy and annotated image)
# [2] Processed o1087687490.png (29 masks saved as npy and annotated image)
# [2] Processed o1158492337.png (53 masks saved as npy and annotated image)
# [2] Processed o1161050466.png (54 masks saved as npy and annotated image)
# [2] Processed o1181780489.png (71 masks saved as npy and annotated image)
# [2] Processed o1185235396.png (84 masks saved as npy and annotated image)
# [2] Processed o1187156535.png (28 masks saved as npy and annotated image)
# [2] Processed o1191351759.png (108 masks saved as npy and annotated image)
# [2] Processed p1101871478.png (110 masks saved as npy and annotated image)
# [2] Processed p1191810626.png (56 masks saved as npy and annotated image)
# [2] Processed q1154290089.png (96 masks saved as npy and annotated image)
# [2] Processed q1169757893.png (46 masks saved as npy and annotated image)
# [2] Processed q1190301197.png (14 masks saved as npy and annotated image)
# [2] Processed q1191503953.png (42 masks saved as npy and annotated image)
# [2] Processed s1071217819.png (42 masks saved as npy and annotated image)
# [2] Processed s1187120643.png (162 masks saved as npy and annotated image)
# [2] Processed t1136663262.png (19 masks saved as npy and annotated image)
# [2] Processed t1190192579.png (34 masks saved as npy and annotated image)
# [2] Processed t1191330738.png (46 masks saved as npy and annotated image)
# [2] Processed u1153546272.png (38 masks saved as npy and annotated image)
# [2] Processed u1156583527.png (107 masks saved as npy and annotated image)
# [2] Processed u1159547663.png (95 masks saved as npy and annotated image)
# [2] Processed u1191650354.png (69 masks saved as npy and annotated image)
# [2] Processed v1126760254.png (74 masks saved as npy and annotated image)
# [2] Processed v1140739003.png (57 masks saved as npy and annotated image)
# [2] Processed v1168878467.png (41 masks saved as npy and annotated image)
# [2] Processed v1171652956.png (36 masks saved as npy and annotated image)
# [2] Processed v1180804864.png (94 masks saved as npy and annotated image)
# [2] Processed v1187327043.png (60 masks saved as npy and annotated image)
# [2] Processed v1189178633.png (140 masks saved as npy and annotated image)
# [2] Processed w1180994249.png (87 masks saved as npy and annotated image)
# [2] Processed w1183158454.png (17 masks saved as npy and annotated image)
# [2] Processed w1187906982.png (91 masks saved as npy and annotated image)
# [2] Processed w1190902512.png (96 masks saved as npy and annotated image)
# [2] Processed x1171181348.png (28 masks saved as npy and annotated image)
# [2] Processed x1185026795.png (25 masks saved as npy and annotated image)
# [2] Processed x1190771308.png (63 masks saved as npy and annotated image)
# [3] Processed 1154588944.png (32 masks saved as npy and annotated image)
# [3] Processed 1173009687.png (15 masks saved as npy and annotated image)
# [3] Processed 1182698598.png (35 masks saved as npy and annotated image)
# [3] Processed b1113509703.png (82 masks saved as npy and annotated image)
# [3] Processed b1184343695.png (64 masks saved as npy and annotated image)
# [3] Processed b1187277326.png (15 masks saved as npy and annotated image)
# [3] Processed b1187441783.png (116 masks saved as npy and annotated image)
# [3] Processed b1190656187.png (39 masks saved as npy and annotated image)
# [3] Processed b1191051519.png (21 masks saved as npy and annotated image)
# [3] Processed b1191481415.png (13 masks saved as npy and annotated image)
# [3] Processed c1186738086.png (35 masks saved as npy and annotated image)
# [3] Processed c1189275966.png (81 masks saved as npy and annotated image)
# [3] Processed d1181234166.png (34 masks saved as npy and annotated image)
# [3] Processed d1181561615.png (20 masks saved as npy and annotated image)
# [3] Processed d1189849693.png (36 masks saved as npy and annotated image)
# [3] Processed d1190904638.png (98 masks saved as npy and annotated image)
# [3] Processed d1191355427.png (47 masks saved as npy and annotated image)
# [3] Processed d1191358224.png (14 masks saved as npy and annotated image)
# [3] Processed e1179009805.png (24 masks saved as npy and annotated image)
# [3] Processed e1187403191.png (31 masks saved as npy and annotated image)
# [3] Processed e1190825724.png (43 masks saved as npy and annotated image)
# [3] Processed e1190920853.png (38 masks saved as npy and annotated image)
# [3] Processed e1190950993.png (42 masks saved as npy and annotated image)
# [3] Processed e1191338151.png (95 masks saved as npy and annotated image)
# [3] Processed e1191589903.png (30 masks saved as npy and annotated image)
# [3] Processed f1154734978.png (51 masks saved as npy and annotated image)
# [3] Processed g1086187704.png (104 masks saved as npy and annotated image)
# [3] Processed g1161033076.png (23 masks saved as npy and annotated image)
# [3] Processed g1190570632.png (11 masks saved as npy and annotated image)
# [3] Processed h1154624403.png (24 masks saved as npy and annotated image)
# [3] Processed h1175863238.png (27 masks saved as npy and annotated image)
# [3] Processed h1183729569.png (31 masks saved as npy and annotated image)
# [3] Processed h1184041004.png (26 masks saved as npy and annotated image)
# [3] Processed h1186186428.png (53 masks saved as npy and annotated image)
# [3] Processed h1190298916.png (17 masks saved as npy and annotated image)
# [3] Processed h1191064243.png (68 masks saved as npy and annotated image)
# [3] Processed j1184298272.png (35 masks saved as npy and annotated image)
# [3] Processed j1185687129.png (21 masks saved as npy and annotated image)
# [3] Processed j1187022551.png (23 masks saved as npy and annotated image)
# [3] Processed j1189710052.png (114 masks saved as npy and annotated image)
# [3] Processed j1190929952.png (32 masks saved as npy and annotated image)
# [3] Processed j1191735371.png (166 masks saved as npy and annotated image)
# [3] Processed j652750569.png (56 masks saved as npy and annotated image)
# [3] Processed k1183034177.png (40 masks saved as npy and annotated image)
# [3] Processed k1190981428.png (12 masks saved as npy and annotated image)
# [3] Processed k1191614437.png (8 masks saved as npy and annotated image)
# [3] Processed l1120732506.png (24 masks saved as npy and annotated image)
# [3] Processed l1160447824.png (56 masks saved as npy and annotated image)
# [3] Processed l1177536628.png (57 masks saved as npy and annotated image)
# [3] Processed l1180842849.png (30 masks saved as npy and annotated image)
# [3] Processed l1183172879.png (61 masks saved as npy and annotated image)
# [3] Processed l1185868613.png (40 masks saved as npy and annotated image)
# [3] Processed l1189543757.png (64 masks saved as npy and annotated image)
# [3] Processed l1191104386.png (21 masks saved as npy and annotated image)
# [3] Processed l1191174227.png (26 masks saved as npy and annotated image)
# [3] Processed l1191353837.png (39 masks saved as npy and annotated image)
# [3] Processed l1191485635.png (99 masks saved as npy and annotated image)
# [3] Processed m1148753453.png (33 masks saved as npy and annotated image)
# [3] Processed m1169461915.png (68 masks saved as npy and annotated image)
# [3] Processed m1179874250.png (35 masks saved as npy and annotated image)
# [3] Processed m1184169495.png (84 masks saved as npy and annotated image)
# [3] Processed m1187017242.png (28 masks saved as npy and annotated image)
# [3] Processed m1189471840.png (55 masks saved as npy and annotated image)
# [3] Processed m1190952251.png (42 masks saved as npy and annotated image)
# [3] Processed m1190985464.png (28 masks saved as npy and annotated image)
# [3] Processed m1191120382.png (31 masks saved as npy and annotated image)
# [3] Processed m1191425689.png (31 masks saved as npy and annotated image)
# [3] Processed m1191475505.png (76 masks saved as npy and annotated image)
# [3] Processed n1173190176.png (20 masks saved as npy and annotated image)
# [3] Processed n1182383022.png (27 masks saved as npy and annotated image)
# [3] Processed n1191144106.png (20 masks saved as npy and annotated image)
# [3] Processed n1191478282.png (28 masks saved as npy and annotated image)
# [3] Processed n1191554586.png (27 masks saved as npy and annotated image)
# [3] Processed n1191611788.png (12 masks saved as npy and annotated image)
# [3] Processed o1179024769.png (49 masks saved as npy and annotated image)
# [3] Processed o1186960589.png (92 masks saved as npy and annotated image)
# [3] Processed o1189958228.png (32 masks saved as npy and annotated image)
# [3] Processed o1190121007.png (33 masks saved as npy and annotated image)
# [3] Processed o1190797730.png (33 masks saved as npy and annotated image)
# [3] Processed o1190944251.png (35 masks saved as npy and annotated image)
# [3] Processed o1191824345.png (33 masks saved as npy and annotated image)
# [3] Processed o1191829396.png (37 masks saved as npy and annotated image)
# [3] Processed p1171340896.png (22 masks saved as npy and annotated image)
# [3] Processed p1186003322.png (24 masks saved as npy and annotated image)
# [3] Processed p1188443975.png (27 masks saved as npy and annotated image)
# [3] Processed p1191182933.png (9 masks saved as npy and annotated image)
# [3] Processed q1175201682.png (39 masks saved as npy and annotated image)
# [3] Processed q1181093253.png (14 masks saved as npy and annotated image)
# [3] Processed q1191056336.png (28 masks saved as npy and annotated image)
# [3] Processed q1191127724.png (137 masks saved as npy and annotated image)
# [3] Processed q1191566819.png (24 masks saved as npy and annotated image)
# [3] Processed r1141596794.png (11 masks saved as npy and annotated image)
# [3] Processed r1170493856.png (23 masks saved as npy and annotated image)
# [3] Processed r1182700824.png (57 masks saved as npy and annotated image)
# [3] Processed r1182777193.png (33 masks saved as npy and annotated image)
# [3] Processed r1189527569.png (28 masks saved as npy and annotated image)
# [3] Processed r1191326691.png (39 masks saved as npy and annotated image)
# [3] Processed s1167344625.png (28 masks saved as npy and annotated image)
# [3] Processed s1182286586.png (43 masks saved as npy and annotated image)
# [3] Processed s1190827711.png (44 masks saved as npy and annotated image)
# [3] Processed s1191115211.png (22 masks saved as npy and annotated image)
# [3] Processed t1185857977.png (51 masks saved as npy and annotated image)
# [3] Processed t1190955488.png (37 masks saved as npy and annotated image)
# [3] Processed t1191103807.png (27 masks saved as npy and annotated image)
# [3] Processed t1191527313.png (30 masks saved as npy and annotated image)
# [3] Processed u1190927750.png (25 masks saved as npy and annotated image)
# [3] Processed u1190987515.png (57 masks saved as npy and annotated image)
# [3] Processed u1191088615.png (46 masks saved as npy and annotated image)
# [3] Processed v1187033255.png (57 masks saved as npy and annotated image)
# [3] Processed w1184158234.png (64 masks saved as npy and annotated image)
# [3] Processed w1190860261.png (63 masks saved as npy and annotated image)
# [3] Processed w1191003804.png (50 masks saved as npy and annotated image)
# [3] Processed w1191481916.png (82 masks saved as npy and annotated image)
# [3] Processed w1191550818.png (22 masks saved as npy and annotated image)
# [3] Processed w1191615331.png (12 masks saved as npy and annotated image)
# [3] Processed x1152907365.png (29 masks saved as npy and annotated image)
# [3] Processed x1163817037.png (26 masks saved as npy and annotated image)
# [3] Processed x1179305942.png (37 masks saved as npy and annotated image)
# [3] Processed x1191129028.png (35 masks saved as npy and annotated image)
# [4] Processed 1126237052.png (38 masks saved as npy and annotated image)
# [4] Processed 1190767842.png (12 masks saved as npy and annotated image)
# [4] Processed 1191132465.png (41 masks saved as npy and annotated image)
# [4] Processed 1191736187.png (54 masks saved as npy and annotated image)
# [4] Processed 1191741850.png (58 masks saved as npy and annotated image)
# [4] Processed b1191366748.png (39 masks saved as npy and annotated image)
# [4] Processed b1191538330.png (25 masks saved as npy and annotated image)
# [4] Processed b1191564846.png (46 masks saved as npy and annotated image)
# [4] Processed b1191609816.png (82 masks saved as npy and annotated image)
# [4] Processed c1177551517.png (155 masks saved as npy and annotated image)
# [4] Processed c1189277412.png (31 masks saved as npy and annotated image)
# [4] Processed c1191161357.png (31 masks saved as npy and annotated image)
# [4] Processed c1191261295.png (22 masks saved as npy and annotated image)
# [4] Processed c1191618326.png (17 masks saved as npy and annotated image)
# [4] Processed c1191622454.png (22 masks saved as npy and annotated image)
# [4] Processed c1191683211.png (60 masks saved as npy and annotated image)
# [4] Processed d1156091267.png (57 masks saved as npy and annotated image)
# [4] Processed d1189586751.png (32 masks saved as npy and annotated image)
# [4] Processed d1191474450.png (117 masks saved as npy and annotated image)
# [4] Processed d1191563369.png (34 masks saved as npy and annotated image)
# [4] Processed d1191725332.png (65 masks saved as npy and annotated image)
# [4] Processed e1151547546.png (72 masks saved as npy and annotated image)
# [4] Processed e1191586024.png (39 masks saved as npy and annotated image)
# [4] Processed f1191319101.png (71 masks saved as npy and annotated image)
# [4] Processed f1191552482.png (65 masks saved as npy and annotated image)
# [4] Processed f1191683408.png (63 masks saved as npy and annotated image)
# [4] Processed f1191723507.png (116 masks saved as npy and annotated image)
# [4] Processed g1191558142.png (60 masks saved as npy and annotated image)
# [4] Processed g1191575293.png (41 masks saved as npy and annotated image)
# [4] Processed g1191575542.png (41 masks saved as npy and annotated image)
# [4] Processed g1191622260.png (33 masks saved as npy and annotated image)
# [4] Processed g1191659982.png (67 masks saved as npy and annotated image)
# [4] Processed h1185898711.png (100 masks saved as npy and annotated image)
# [4] Processed h1191600287.png (49 masks saved as npy and annotated image)
# [4] Processed h1191819480.png (155 masks saved as npy and annotated image)
# [4] Processed j1132611060.png (7 masks saved as npy and annotated image)
# [4] Processed j1156079683.png (56 masks saved as npy and annotated image)
# [4] Processed j1187159118.png (88 masks saved as npy and annotated image)
# [4] Processed j1191552346.png (58 masks saved as npy and annotated image)
# [4] Processed j1191559623.png (99 masks saved as npy and annotated image)
# [4] Processed j1191717458.png (43 masks saved as npy and annotated image)
# [4] Processed k1191481449.png (29 masks saved as npy and annotated image)
# [4] Processed k1191483054.png (36 masks saved as npy and annotated image)
# [4] Processed k1191592318.png (52 masks saved as npy and annotated image)
# [4] Processed k1191595454.png (23 masks saved as npy and annotated image)
# [4] Processed l1155377477.png (39 masks saved as npy and annotated image)
# [4] Processed l1173441636.png (69 masks saved as npy and annotated image)
# [4] Processed l1191357408.png (56 masks saved as npy and annotated image)
# [4] Processed l1191456702.png (236 masks saved as npy and annotated image)
# [4] Processed l1191561107.png (52 masks saved as npy and annotated image)
# [4] Processed l1191717769.png (39 masks saved as npy and annotated image)
# [4] Processed m1191439995.png (205 masks saved as npy and annotated image)
# [4] Processed m1191471534.png (177 masks saved as npy and annotated image)
# [4] Processed m1191474270.png (3 masks saved as npy and annotated image)
# [4] Processed m1191500219.png (30 masks saved as npy and annotated image)
# [4] Processed m1191610582.png (23 masks saved as npy and annotated image)
# [4] Processed m1191741674.png (20 masks saved as npy and annotated image)
# [4] Processed n1191445915.png (194 masks saved as npy and annotated image)
# [4] Processed n1191549926.png (57 masks saved as npy and annotated image)
# [4] Processed n1191677586.png (68 masks saved as npy and annotated image)
# [4] Processed n1191764804.png (162 masks saved as npy and annotated image)
# [4] Processed n1191790097.png (48 masks saved as npy and annotated image)
# [4] Processed o1155624630.png (18 masks saved as npy and annotated image)
# [4] Processed o1164318634.png (34 masks saved as npy and annotated image)
# [4] Processed o1179306265.png (52 masks saved as npy and annotated image)
# [4] Processed p1191528595.png (71 masks saved as npy and annotated image)
# [4] Processed p1191543312.png (103 masks saved as npy and annotated image)
# [4] Processed p1191561874.png (54 masks saved as npy and annotated image)
# [4] Processed p1191563290.png (72 masks saved as npy and annotated image)
# [4] Processed p1191568309.png (87 masks saved as npy and annotated image)
# [4] Processed p1191618639.png (16 masks saved as npy and annotated image)
# [4] Processed p1191688073.png (65 masks saved as npy and annotated image)
# [4] Processed p1191731871.png (175 masks saved as npy and annotated image)
# [4] Processed p1191768461.png (44 masks saved as npy and annotated image)
# [4] Processed q1190568074.png (36 masks saved as npy and annotated image)
# [4] Processed q1191533184.png (69 masks saved as npy and annotated image)
# [4] Processed q1191564829.png (53 masks saved as npy and annotated image)
# [4] Processed r1188469601.png (25 masks saved as npy and annotated image)
# [4] Processed r1190773866.png (14 masks saved as npy and annotated image)
# [4] Processed r1191222266.png (42 masks saved as npy and annotated image)
# [4] Processed r1191347605.png (40 masks saved as npy and annotated image)
# [4] Processed r1191413891.png (46 masks saved as npy and annotated image)
# [4] Processed r1191477840.png (105 masks saved as npy and annotated image)
# [4] Processed r1191697987.png (39 masks saved as npy and annotated image)
# [4] Processed s1132109786.png (25 masks saved as npy and annotated image)
# [4] Processed s1190776915.png (31 masks saved as npy and annotated image)
# [4] Processed s1191490755.png (77 masks saved as npy and annotated image)
# [4] Processed s1191535851.png (37 masks saved as npy and annotated image)
# [4] Processed s1191590524.png (108 masks saved as npy and annotated image)
# [4] Processed s1191592557.png (58 masks saved as npy and annotated image)
# [4] Processed s1191626724.png (11 masks saved as npy and annotated image)
# [4] Processed s1191629451.png (46 masks saved as npy and annotated image)
# [4] Processed s1191718238.png (34 masks saved as npy and annotated image)
# [4] Processed t1166294537.png (34 masks saved as npy and annotated image)
# [4] Processed t1175705831.png (50 masks saved as npy and annotated image)
# [4] Processed t1191270704.png (64 masks saved as npy and annotated image)
# [4] Processed t1191616766.png (38 masks saved as npy and annotated image)
# [4] Processed t1191740982.png (58 masks saved as npy and annotated image)
# [4] Processed t1191813442.png (73 masks saved as npy and annotated image)
# [4] Processed u1187177901.png (59 masks saved as npy and annotated image)
# [4] Processed u1191494794.png (59 masks saved as npy and annotated image)
# [4] Processed u1191631296.png (29 masks saved as npy and annotated image)
# [4] Processed v1156090553.png (48 masks saved as npy and annotated image)
# [4] Processed v1190982790.png (33 masks saved as npy and annotated image)
# [4] Processed v1191370227.png (13 masks saved as npy and annotated image)
# [4] Processed v1191469077.png (232 masks saved as npy and annotated image)
# [4] Processed v1191497444.png (75 masks saved as npy and annotated image)
# [4] Processed w1160324955.png (88 masks saved as npy and annotated image)
# [4] Processed w1191421468.png (57 masks saved as npy and annotated image)
# [4] Processed x1189580806.png (20 masks saved as npy and annotated image)
# [4] Processed x1191557690.png (81 masks saved as npy and annotated image)
# [4] Processed x1191573830.png (47 masks saved as npy and annotated image)
# [4] Processed x1191763053.png (67 masks saved as npy and annotated image)
# [5] Processed 1172882303.png (6 masks saved as npy and annotated image)
# [5] Processed 1173555456.png (27 masks saved as npy and annotated image)
# [5] Processed 1186266050.png (8 masks saved as npy and annotated image)
# [5] Processed b1094751541.png (40 masks saved as npy and annotated image)
# [5] Processed b1160855625.png (28 masks saved as npy and annotated image)
# [5] Processed b1184294295.png (27 masks saved as npy and annotated image)
# [5] Processed b1187284300.png (97 masks saved as npy and annotated image)
# [5] Processed b1191057471.png (26 masks saved as npy and annotated image)
# [5] Processed b1191431247.png (28 masks saved as npy and annotated image)
# [5] Processed b1191601386.png (45 masks saved as npy and annotated image)
# [5] Processed b1191737718.png (53 masks saved as npy and annotated image)
# [5] Processed c1114766069.png (67 masks saved as npy and annotated image)
# [5] Processed c1137797775.png (31 masks saved as npy and annotated image)
# [5] Processed c1137804383.png (42 masks saved as npy and annotated image)
# [5] Processed c1147312897.png (28 masks saved as npy and annotated image)
# [5] Processed c1182123800.png (20 masks saved as npy and annotated image)
# [5] Processed c1187760302.png (69 masks saved as npy and annotated image)
# [5] Processed c1187808482.png (32 masks saved as npy and annotated image)
# [5] Processed c1191161357.png (31 masks saved as npy and annotated image)
# [5] Processed c1191189969.png (207 masks saved as npy and annotated image)
# [5] Processed c1191652929.png (64 masks saved as npy and annotated image)
# [5] Processed c1191715044.png (27 masks saved as npy and annotated image)
# [5] Processed d1170656373.png (32 masks saved as npy and annotated image)
# [5] Processed d1189096064.png (44 masks saved as npy and annotated image)
# [5] Processed d1189532281.png (96 masks saved as npy and annotated image)
# [5] Processed d1191456481.png (94 masks saved as npy and annotated image)
# [5] Processed d1191590884.png (27 masks saved as npy and annotated image)
# [5] Processed e1153671351.png (76 masks saved as npy and annotated image)
# [5] Processed e1164543705.png (50 masks saved as npy and annotated image)
# [5] Processed e1178664397.png (95 masks saved as npy and annotated image)
# [5] Processed e1187205501.png (71 masks saved as npy and annotated image)
# [5] Processed e1191616048.png (32 masks saved as npy and annotated image)
# [5] Processed e1191726073.png (82 masks saved as npy and annotated image)
# [5] Processed f1170502361.png (96 masks saved as npy and annotated image)
# [5] Processed f1174041028.png (39 masks saved as npy and annotated image)
# [5] Processed f1175804046.png (58 masks saved as npy and annotated image)
# [5] Processed f1181888895.png (44 masks saved as npy and annotated image)
# [5] Processed f1191115352.png (25 masks saved as npy and annotated image)
# [5] Processed f1191141782.png (56 masks saved as npy and annotated image)
# [5] Processed f1191337222.png (50 masks saved as npy and annotated image)
# [5] Processed f1191413722.png (47 masks saved as npy and annotated image)
# [5] Processed f1191650941.png (110 masks saved as npy and annotated image)
# [5] Processed g1183005819.png (47 masks saved as npy and annotated image)
# [5] Processed g1186021921.png (81 masks saved as npy and annotated image)
# [5] Processed g1190932074.png (180 masks saved as npy and annotated image)
# [5] Processed g1191190021.png (154 masks saved as npy and annotated image)
# [5] Processed g1191594946.png (95 masks saved as npy and annotated image)
# [5] Processed g1191629025.png (54 masks saved as npy and annotated image)
# [5] Processed h1159731759.png (43 masks saved as npy and annotated image)
# [5] Processed h1165331573.png (18 masks saved as npy and annotated image)
# [5] Processed h1183887211.png (55 masks saved as npy and annotated image)
# [5] Processed h1190573807.png (53 masks saved as npy and annotated image)
# [5] Processed h1191165592.png (34 masks saved as npy and annotated image)
# [5] Processed h1191720202.png (139 masks saved as npy and annotated image)
# [5] Processed j1077974654.png (124 masks saved as npy and annotated image)
# [5] Processed j1144083760.png (41 masks saved as npy and annotated image)
# [5] Processed j1150682003.png (34 masks saved as npy and annotated image)
# [5] Processed j1168615692.png (10 masks saved as npy and annotated image)
# [5] Processed j1172535657.png (10 masks saved as npy and annotated image)
# [5] Processed j1182001038.png (25 masks saved as npy and annotated image)
# [5] Processed j1188953489.png (179 masks saved as npy and annotated image)
# [5] Processed j1191072167.png (91 masks saved as npy and annotated image)
# [5] Processed j1191269127.png (72 masks saved as npy and annotated image)
# [5] Processed j1191728283.png (36 masks saved as npy and annotated image)
# [5] Processed j1191729279.png (55 masks saved as npy and annotated image)
# [5] Processed k1125807070.png (8 masks saved as npy and annotated image)
# [5] Processed k1126414922.png (10 masks saved as npy and annotated image)
# [5] Processed k1166614719.png (21 masks saved as npy and annotated image)
# [5] Processed k1187495923.png (28 masks saved as npy and annotated image)
# [5] Processed k1191725213.png (43 masks saved as npy and annotated image)
# [5] Processed k1191729356.png (22 masks saved as npy and annotated image)
# [5] Processed l1103065526.png (19 masks saved as npy and annotated image)
# [5] Processed l1158492569.png (87 masks saved as npy and annotated image)
# [5] Processed l1174471422.png (19 masks saved as npy and annotated image)
# [5] Processed l1178403345.png (20 masks saved as npy and annotated image)
# [5] Processed l1183325556.png (34 masks saved as npy and annotated image)
# [5] Processed l1191182887.png (75 masks saved as npy and annotated image)
# [5] Processed l1191357408.png (56 masks saved as npy and annotated image)
# [5] Processed l1191626006.png (52 masks saved as npy and annotated image)
# [5] Processed m1082208095.png (10 masks saved as npy and annotated image)
# [5] Processed m1165305941.png (39 masks saved as npy and annotated image)
# [5] Processed m1165318477.png (25 masks saved as npy and annotated image)
# [5] Processed m1174503522.png (27 masks saved as npy and annotated image)
# [5] Processed m1177522631.png (87 masks saved as npy and annotated image)
# [5] Processed m1182121273.png (70 masks saved as npy and annotated image)
# [5] Processed m1185715194.png (28 masks saved as npy and annotated image)
# [5] Processed m1191192880.png (84 masks saved as npy and annotated image)
# [5] Processed m1191333843.png (68 masks saved as npy and annotated image)
# [5] Processed m1191719765.png (166 masks saved as npy and annotated image)
# [5] Processed n1125471554.png (78 masks saved as npy and annotated image)
# [5] Processed n1166707764.png (87 masks saved as npy and annotated image)
# [5] Processed n1168197738.png (45 masks saved as npy and annotated image)
# [5] Processed n1171719181.png (41 masks saved as npy and annotated image)
# [5] Processed n1181024942.png (24 masks saved as npy and annotated image)
# [5] Processed n1182986513.png (126 masks saved as npy and annotated image)
# [5] Processed n1189086137.png (37 masks saved as npy and annotated image)
# [5] Processed n1191111346.png (35 masks saved as npy and annotated image)
# [5] Processed n1191341403.png (53 masks saved as npy and annotated image)
# [5] Processed n1191726452.png (38 masks saved as npy and annotated image)
# [5] Processed o1159821854.png (32 masks saved as npy and annotated image)
# [5] Processed o1168947584.png (37 masks saved as npy and annotated image)
# [5] Processed o1181826694.png (27 masks saved as npy and annotated image)
# [5] Processed o1188683650.png (16 masks saved as npy and annotated image)
# [5] Processed o1190668972.png (30 masks saved as npy and annotated image)
# [5] Processed o1191160640.png (62 masks saved as npy and annotated image)
# [5] Processed o1191731498.png (50 masks saved as npy and annotated image)
# [5] Processed p1112819217.png (40 masks saved as npy and annotated image)
# [5] Processed p1176859258.png (79 masks saved as npy and annotated image)
# [5] Processed p1187267693.png (88 masks saved as npy and annotated image)
# [5] Processed p1189882073.png (85 masks saved as npy and annotated image)
# [5] Processed p1190346016.png (51 masks saved as npy and annotated image)
# [5] Processed p1190601349.png (75 masks saved as npy and annotated image)
# [5] Processed p1190654030.png (123 masks saved as npy and annotated image)
# [5] Processed p1191122154.png (28 masks saved as npy and annotated image)
# [5] Processed p1191203493.png (21 masks saved as npy and annotated image)
# [5] Processed p1191731871.png (175 masks saved as npy and annotated image)
# [5] Processed q1031915603.png (41 masks saved as npy and annotated image)
# [5] Processed q1127615847.png (26 masks saved as npy and annotated image)
# [5] Processed q1179759602.png (30 masks saved as npy and annotated image)
# [5] Processed q1186635587.png (35 masks saved as npy and annotated image)
# [5] Processed q1187816041.png (45 masks saved as npy and annotated image)
# [5] Processed q1188122927.png (10 masks saved as npy and annotated image)
# [5] Processed q1191048983.png (26 masks saved as npy and annotated image)
# [5] Processed q1191594770.png (32 masks saved as npy and annotated image)
# [5] Processed q1191730331.png (32 masks saved as npy and annotated image)
# [5] Processed q1191731679.png (30 masks saved as npy and annotated image)
# [5] Processed r1031307592.png (66 masks saved as npy and annotated image)
# [5] Processed r1139580186.png (10 masks saved as npy and annotated image)
# [5] Processed r1189080330.png (41 masks saved as npy and annotated image)
# [5] Processed r1191029497.png (24 masks saved as npy and annotated image)
# [5] Processed r1191158160.png (74 masks saved as npy and annotated image)
# [5] Processed r1191200372.png (71 masks saved as npy and annotated image)
# [5] Processed r1191422542.png (66 masks saved as npy and annotated image)
# [5] Processed r1191425093.png (99 masks saved as npy and annotated image)
# [5] Processed r1191709797.png (203 masks saved as npy and annotated image)
# [5] Processed s1132109786.png (25 masks saved as npy and annotated image)
# [5] Processed s1172904714.png (65 masks saved as npy and annotated image)
# [5] Processed s1185763843.png (26 masks saved as npy and annotated image)
# [5] Processed s1188945072.png (23 masks saved as npy and annotated image)
# [5] Processed s1191118930.png (23 masks saved as npy and annotated image)
# [5] Processed s1191121020.png (26 masks saved as npy and annotated image)
# [5] Processed s1191490904.png (25 masks saved as npy and annotated image)
# [5] Processed s1191595304.png (31 masks saved as npy and annotated image)
# [5] Processed t1139631929.png (28 masks saved as npy and annotated image)
# [5] Processed t1174505316.png (22 masks saved as npy and annotated image)
# [5] Processed t1184982672.png (30 masks saved as npy and annotated image)
# [5] Processed t1185372924.png (66 masks saved as npy and annotated image)
# [5] Processed t1190555286.png (23 masks saved as npy and annotated image)
# [5] Processed t1191234802.png (50 masks saved as npy and annotated image)
# [5] Processed t1191378923.png (99 masks saved as npy and annotated image)
# [5] Processed u1127527151.png (46 masks saved as npy and annotated image)
# [5] Processed u1172645589.png (25 masks saved as npy and annotated image)
# [5] Processed u1172682421.png (39 masks saved as npy and annotated image)
# [5] Processed u1176269869.png (29 masks saved as npy and annotated image)
# [5] Processed u1179101726.png (169 masks saved as npy and annotated image)
# [5] Processed u1180931211.png (22 masks saved as npy and annotated image)
# [5] Processed u1181871260.png (23 masks saved as npy and annotated image)
# [5] Processed u1185937530.png (47 masks saved as npy and annotated image)
# [5] Processed u1190864920.png (81 masks saved as npy and annotated image)
# [5] Processed u1190922502.png (34 masks saved as npy and annotated image)
# [5] Processed u1191230044.png (71 masks saved as npy and annotated image)
# [5] Processed u1191631296.png (29 masks saved as npy and annotated image)
# [5] Processed u1191666133.png (24 masks saved as npy and annotated image)
# [5] Processed v1127514145.png (8 masks saved as npy and annotated image)
# [5] Processed v1169075564.png (8 masks saved as npy and annotated image)
# [5] Processed v1173767938.png (25 masks saved as npy and annotated image)
# [5] Processed v1183934027.png (54 masks saved as npy and annotated image)
# [5] Processed v1187286511.png (83 masks saved as npy and annotated image)
# [5] Processed v1190924120.png (61 masks saved as npy and annotated image)
# [5] Processed v1191128847.png (28 masks saved as npy and annotated image)
# [5] Processed v1191166415.png (87 masks saved as npy and annotated image)
# [5] Processed v1191361604.png (121 masks saved as npy and annotated image)
# [5] Processed w1179740797.png (27 masks saved as npy and annotated image)
# [5] Processed w1190839799.png (97 masks saved as npy and annotated image)
# [5] Processed w1191117368.png (22 masks saved as npy and annotated image)
# [5] Processed w1191185463.png (20 masks saved as npy and annotated image)
# [5] Processed w1191580281.png (24 masks saved as npy and annotated image)
# [5] Processed w1191719574.png (175 masks saved as npy and annotated image)
# [5] Processed x1067950974.png (10 masks saved as npy and annotated image)
# [5] Processed x1155423960.png (21 masks saved as npy and annotated image)
# [5] Processed x1158490255.png (44 masks saved as npy and annotated image)
# [5] Processed x1162366438.png (58 masks saved as npy and annotated image)
# [5] Processed x1162587148.png (28 masks saved as npy and annotated image)
# [5] Processed x1174503138.png (28 masks saved as npy and annotated image)
# [5] Processed x1189139732.png (83 masks saved as npy and annotated image)
# [5] Processed x1191729061.png (46 masks saved as npy and annotated image)
# All Complete!

# %% [markdown]
# ## SAM Visualization

# %%
import matplotlib.pyplot as plt
import os
from math import ceil
import pandas as pd
import numpy as np


valid_image_ext = ['.jpg', '.jpeg', '.png']

def visualize_and_save_images_for_item(
    image_paths,
    output_display_path,
    item_id,
    part_idx,
    num_cols=5
):
    num_images = len(image_paths)
    num_rows = int(ceil(float(num_images) / float(num_cols)))

    f, axarr = plt.subplots(num_rows, num_cols, figsize=(num_cols * 6, num_rows * 6))
    f.tight_layout(pad=3.0)

    # Ensure axarr is a flat list
    if num_rows == 1:
        axarr = [axarr]
    axarr = sum(
        [list(r) if isinstance(r, (list, tuple, np.ndarray)) else [r] for r in axarr],
        []
    )

    for idx in range(num_rows * num_cols):
        ax = axarr[idx]
        ax.axis('off')

        if idx < num_images:
            img_path = image_paths[idx]
            img = plt.imread(img_path)

            filename = os.path.basename(img_path)
            ax.text(
                1.0,
                0.0,
                filename,
                ha="right",
                va="bottom",
                fontsize=9,
                color="white",
                wrap=True,
                transform=ax.transAxes,
                bbox=dict(
                    facecolor="black",
                    alpha=0.5,
                    boxstyle="round,pad=0.3"
                ),
            )
            
    output_file = os.path.join(output_display_path, f"{item_id}_{part_idx}.png")
    plt.savefig(output_file)
    plt.close(f)
    print(f"[{item_id}] Saved visualization part {part_idx} to {output_file}")


# -------------------------------------------------------------
# Main function to iterate over all IDs in ITEMS_LIST
# -------------------------------------------------------------
def batch_visualize_items(
    items_list_csv,
    output_base_dir,
    output_display_dir,
    num_cols=5,
    max_images_per_grid=25
):
    os.makedirs(output_display_dir, exist_ok=True)

    df = pd.read_csv(items_list_csv, usecols=["id"])
    ids = df["id"].astype(str).tolist()

    for item_id in ids:
        input_folder = os.path.join(output_base_dir, item_id)
        if not os.path.exists(input_folder):
            print(f"[{item_id}] Folder {input_folder} does not exist. Skipping.")
            continue

        # Gather all images
        image_paths = [
            os.path.join(input_folder, image)
            for image in sorted(os.listdir(input_folder))
            if os.path.splitext(image)[1].lower() in valid_image_ext
        ]

        if not image_paths:
            print(f"[{item_id}] No images found in {input_folder}. Skipping.")
            continue

        # Split into batches
        total_images = len(image_paths)
        parts = [
            image_paths[i:i + max_images_per_grid]
            for i in range(0, total_images, max_images_per_grid)
        ]

        for part_idx, part_image_paths in enumerate(parts, start=1):
            visualize_and_save_images_for_item(
                image_paths=part_image_paths,
                output_display_path=output_display_dir,
                item_id=item_id,
                part_idx=part_idx,
                num_cols=num_cols
            )

# -------------------------------------------------------------
# Example usage
# -------------------------------------------------------------

batch_visualize_items(
    items_list_csv=TEXT_PROMPT_CSV,
    output_base_dir=OUTPUT,
    output_display_dir=OUTPUT_DP,
    num_cols=5,
    max_images_per_grid=25
)
print("All Complete")
# Out:
# [1] Saved visualization part 1 to ../zm_scraper/listing/sam/output_display/conf_2/1_1.png
# [1] Saved visualization part 2 to ../zm_scraper/listing/sam/output_display/conf_2/1_2.png
# [1] Saved visualization part 3 to ../zm_scraper/listing/sam/output_display/conf_2/1_3.png
# [1] Saved visualization part 4 to ../zm_scraper/listing/sam/output_display/conf_2/1_4.png
# [1] Saved visualization part 5 to ../zm_scraper/listing/sam/output_display/conf_2/1_5.png
# [1] Saved visualization part 6 to ../zm_scraper/listing/sam/output_display/conf_2/1_6.png
# [1] Saved visualization part 7 to ../zm_scraper/listing/sam/output_display/conf_2/1_7.png
# [1] Saved visualization part 8 to ../zm_scraper/listing/sam/output_display/conf_2/1_8.png
# [2] Saved visualization part 1 to ../zm_scraper/listing/sam/output_display/conf_2/2_1.png
# [2] Saved visualization part 2 to ../zm_scraper/listing/sam/output_display/conf_2/2_2.png
# [2] Saved visualization part 3 to ../zm_scraper/listing/sam/output_display/conf_2/2_3.png
# [2] Saved visualization part 4 to ../zm_scraper/listing/sam/output_display/conf_2/2_4.png
# [3] Saved visualization part 1 to ../zm_scraper/listing/sam/output_display/conf_2/3_1.png
# [3] Saved visualization part 2 to ../zm_scraper/listing/sam/output_display/conf_2/3_2.png
# [3] Saved visualization part 3 to ../zm_scraper/listing/sam/output_display/conf_2/3_3.png
# [3] Saved visualization part 4 to ../zm_scraper/listing/sam/output_display/conf_2/3_4.png
# [3] Saved visualization part 5 to ../zm_scraper/listing/sam/output_display/conf_2/3_5.png
# [4] Saved visualization part 1 to ../zm_scraper/listing/sam/output_display/conf_2/4_1.png
# [4] Saved visualization part 2 to ../zm_scraper/listing/sam/output_display/conf_2/4_2.png
# [4] Saved visualization part 3 to ../zm_scraper/listing/sam/output_display/conf_2/4_3.png
# [4] Saved visualization part 4 to ../zm_scraper/listing/sam/output_display/conf_2/4_4.png
# [4] Saved visualization part 5 to ../zm_scraper/listing/sam/output_display/conf_2/4_5.png
# [5] Saved visualization part 1 to ../zm_scraper/listing/sam/output_display/conf_2/5_1.png
# [5] Saved visualization part 2 to ../zm_scraper/listing/sam/output_display/conf_2/5_2.png
# [5] Saved visualization part 3 to ../zm_scraper/listing/sam/output_display/conf_2/5_3.png
# [5] Saved visualization part 4 to ../zm_scraper/listing/sam/output_display/conf_2/5_4.png
# [5] Saved visualization part 5 to ../zm_scraper/listing/sam/output_display/conf_2/5_5.png
# [5] Saved visualization part 6 to ../zm_scraper/listing/sam/output_display/conf_2/5_6.png
# [5] Saved visualization part 7 to ../zm_scraper/listing/sam/output_display/conf_2/5_7.png
# [5] Saved visualization part 8 to ../zm_scraper/listing/sam/output_display/conf_2/5_8.png
# All Complete
