# %% [markdown]
# ## GroundingDINO Inference

# %%
# Input and output directories
INPUT_DIR = "../zm_scraper/auctions/preprocessed"
OUTPUT_DIR = "../zm_scraper/auctions/gdino/output"
OUTPUT_LABELS_DIR = "../zm_scraper/auctions/gdino/output_labels"
OUTPUT_DISPLAY_DIR = "../zm_scraper/auctions/gdino/output_display"

# %%
# Configurable thresholds and prompt
TEXT_PROMPT_CSV = "../zm_scraper/items-prompt.csv"
BOX_THRESHOLD = 0.1
TEXT_THRESHOLD = 0.25
REMOVE_NESTING = True   ## Nesting Filtering during inference (mild postprocessing)
IOU_NMS_THRESHOLD = 0.9

# %%
import os
import cv2
import torch
import pandas as pd
from pathlib import Path
import numpy as np
import json
import math
from groundingdino.util.inference import load_model, load_image, predict, annotate


def iou_xyxy(a, b):
    ax1, ay1, ax2, ay2 = a
    bx1, by1, bx2, by2 = b
    inter_w = max(0.0, min(ax2, bx2) - max(ax1, bx1))
    inter_h = max(0.0, min(ay2, by2) - max(ay1, by1))
    inter = inter_w * inter_h
    if inter <= 0:
        return 0.0
    area_a = max(0.0, ax2 - ax1) * max(0.0, ay2 - ay1)
    area_b = max(0.0, bx2 - bx1) * max(0.0, by2 - by1)
    union = area_a + area_b - inter
    return inter / union if union > 0 else 0.0

# -----------------------------------
# Config
# -----------------------------------
MODEL_CONFIG_PATH = "./groundingdino/config/GroundingDINO_SwinB_cfg.py"
MODEL_WEIGHTS_PATH = "./weights/checkpoint_best_regular.pth"

# -----------------------------------
# Load model
# -----------------------------------
model = load_model(MODEL_CONFIG_PATH, MODEL_WEIGHTS_PATH)

# Create output base dirs
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(OUTPUT_LABELS_DIR, exist_ok=True)

# -----------------------------------
# Load prompts CSV
# -----------------------------------
df_prompts = pd.read_csv(TEXT_PROMPT_CSV)
id_to_prompt = dict(zip(df_prompts["id"].astype(str), df_prompts["prompt"]))

# -----------------------------------
# Process images per ID
# -----------------------------------
for item_id, text_prompt in id_to_prompt.items():
    input_subdir = Path(INPUT_DIR) / item_id
    output_subdir = Path(OUTPUT_DIR) / item_id
    labels_subdir = Path(OUTPUT_LABELS_DIR) / item_id

    if not input_subdir.exists():
        print(f"Skipping {item_id}: folder {input_subdir} does not exist.")
        continue

    output_subdir.mkdir(parents=True, exist_ok=True)
    labels_subdir.mkdir(parents=True, exist_ok=True)

    # Loop over all images in this ID's folder
    for filename in os.listdir(input_subdir):
        input_path = input_subdir / filename

        # Skip non-image files
        if not (
            filename.lower().endswith(".jpg")
            or filename.lower().endswith(".jpeg")
            or filename.lower().endswith(".png")
        ):
            continue

        base_filename = os.path.splitext(filename)[0]

        # Load image
        image_source, image = load_image(str(input_path))
        hgt, wid = image_source.shape[:2]

        # Predict
        boxes, logits, phrases = predict(
            model=model,
            image=image,
            caption=text_prompt,
            box_threshold=BOX_THRESHOLD,
            text_threshold=TEXT_THRESHOLD,
        )

        # Prepare detections
        detections = []
        for i in range(len(boxes)):
            cx_norm, cy_norm, w_norm, h_norm = boxes[i].tolist()

            cx_abs = cx_norm * wid
            cy_abs = cy_norm * hgt
            w_abs = w_norm * wid
            h_abs = h_norm * hgt

            x_min = cx_abs - w_abs / 2
            y_min = cy_abs - h_abs / 2
            x_max = cx_abs + w_abs / 2
            y_max = cy_abs + h_abs / 2

            area = w_abs * h_abs

            phrase = phrases[i] if phrases[i] else "NIL"
            detections.append({
                "box_norm": [cx_norm, cy_norm, w_norm, h_norm],
                "box_abs": [x_min, y_min, x_max, y_max],
                "logit": logits[i],
                "phrase": phrase,
                "area": area
            })

        if REMOVE_NESTING:
            # Sort by confidence descending so we keep the stronger one first
            detections_sorted = sorted(detections, key=lambda d: float(d["logit"]), reverse=True)
            kept = []
            for det in detections_sorted:
                keep = True
                for k in kept:
                    if iou_xyxy(det["box_abs"], k["box_abs"]) >= IOU_NMS_THRESHOLD:
                        # Overlaps too much with a higher-confidence box -> drop
                        keep = False
                        break
                if keep:
                    kept.append(det)
            detections = kept


        # Reconstruct lists for annotation
        final_boxes = [d["box_norm"] for d in detections]
        final_logits = [d["logit"] for d in detections]
        final_phrases = [d["phrase"] for d in detections]

        if final_boxes:
            final_boxes_tensor = torch.tensor(final_boxes)
        else:
            final_boxes_tensor = torch.empty((0, 4))

        # Annotate
        annotated_frame = annotate(
            image_source=image_source,
            boxes=final_boxes_tensor,
            logits=final_logits,
            phrases=final_phrases,
        )
        
        # Draw annotation IDs on the image
        for idx, det in enumerate(detections, start=1):
            x_min, y_min, x_max, y_max = det["box_abs"]
            label_id = str(idx)  # ID starting at 1 for this image
            cv2.putText(
                annotated_frame,
                label_id,
                (int(x_min), int(y_min) - 5),  # slightly above the top-left corner
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,        # font scale
                (0, 255, 0),  # green text
                2,          # thickness
                cv2.LINE_AA
            )


        # Save annotated image
        output_image_path = output_subdir / filename
        cv2.imwrite(str(output_image_path), annotated_frame)

        # -----------------------------------
        # Save labels in COCO JSON format
        # -----------------------------------
        coco_output = {
            "images": [{
                "id": 1,  # You can increment across dataset if aggregating
                "file_name": filename,
                "width": wid,
                "height": hgt
            }],
            "categories": [],
            "annotations": []
        }

        category_name_to_id = {}
        category_counter = 1
        annotation_id = 1

        for det in detections:
            phrase = det["phrase"]
            if phrase not in category_name_to_id:
                category_name_to_id[phrase] = category_counter
                coco_output["categories"].append({
                    "id": category_counter,
                    "name": phrase
                })
                category_counter += 1

            x_min, y_min, x_max, y_max = det["box_abs"]
            coco_bbox = [
                int(x_min),
                int(y_min),
                int(x_max - x_min),  # width
                int(y_max - y_min)   # height
            ]

            coco_output["annotations"].append({
                "id": annotation_id,
                "image_id": 1,
                "category_id": category_name_to_id[phrase],
                "bbox": [round(float(v), 3) for v in coco_bbox],  # round each bbox value
                "area": int(det["area"]),
                "score": round(float(det["logit"]), 3),
                "iscrowd": 0
            })
            annotation_id += 1

        # Save JSON
        output_json_path = labels_subdir / f"{base_filename}.json"
        with open(output_json_path, "w") as f:
            json.dump(coco_output, f, indent=2)
        
#         Save as text
#         output_label_path = labels_subdir / (base_filename + ".txt")
#         with open(output_label_path, "w") as f:
#             for det in detections:
#                 x_min, y_min, x_max, y_max = det["box_abs"]
#                 line = (
#                     f"{det['phrase']} {det['logit']:.4f} "
#                     f"{x_min:.2f} {y_min:.2f} {x_max:.2f} {y_max:.2f}\n"
#                 )
#                 f.write(line)

        print(f"[{item_id}] Processed {filename} -> {output_image_path}")

print("All images processed.")
# Out:
# final text_encoder_type: bert-base-uncased
# FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
# UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
# UserWarning: None of the inputs have requires_grad=True. Gradients will be None
# [1] Processed c1190881000.png -> ../zm_scraper/listing/gdino/output/1/c1190881000.png
# [1] Processed b1187681880.png -> ../zm_scraper/listing/gdino/output/1/b1187681880.png
# [1] Processed x1189677434.png -> ../zm_scraper/listing/gdino/output/1/x1189677434.png
# [1] Processed m1168646860.png -> ../zm_scraper/listing/gdino/output/1/m1168646860.png
# [1] Processed r1186986297.png -> ../zm_scraper/listing/gdino/output/1/r1186986297.png
# [1] Processed c1191323690.png -> ../zm_scraper/listing/gdino/output/1/c1191323690.png
# [1] Processed o1191069257.png -> ../zm_scraper/listing/gdino/output/1/o1191069257.png
# [1] Processed q1190999908.png -> ../zm_scraper/listing/gdino/output/1/q1190999908.png
# [1] Processed h1191606615.png -> ../zm_scraper/listing/gdino/output/1/h1191606615.png
# [1] Processed x1191598905.png -> ../zm_scraper/listing/gdino/output/1/x1191598905.png
# [1] Processed m1191510476.png -> ../zm_scraper/listing/gdino/output/1/m1191510476.png
# [1] Processed l1182133390.png -> ../zm_scraper/listing/gdino/output/1/l1182133390.png
# [1] Processed q1190933101.png -> ../zm_scraper/listing/gdino/output/1/q1190933101.png
# [1] Processed w1156067263.png -> ../zm_scraper/listing/gdino/output/1/w1156067263.png
# [1] Processed g1121969050.png -> ../zm_scraper/listing/gdino/output/1/g1121969050.png
# [1] Processed k1190557636.png -> ../zm_scraper/listing/gdino/output/1/k1190557636.png
# [1] Processed t1185967298.png -> ../zm_scraper/listing/gdino/output/1/t1185967298.png
# [1] Processed k1191477198.png -> ../zm_scraper/listing/gdino/output/1/k1191477198.png
# [1] Processed o1190563887.png -> ../zm_scraper/listing/gdino/output/1/o1190563887.png
# [1] Processed j1190303466.png -> ../zm_scraper/listing/gdino/output/1/j1190303466.png
# [1] Processed r1190826351.png -> ../zm_scraper/listing/gdino/output/1/r1190826351.png
# [1] Processed l1190559645.png -> ../zm_scraper/listing/gdino/output/1/l1190559645.png
# [1] Processed l1188323777.png -> ../zm_scraper/listing/gdino/output/1/l1188323777.png
# [1] Processed q1187025650.png -> ../zm_scraper/listing/gdino/output/1/q1187025650.png
# [1] Processed s1190129857.png -> ../zm_scraper/listing/gdino/output/1/s1190129857.png
# [1] Processed t1190954755.png -> ../zm_scraper/listing/gdino/output/1/t1190954755.png
# [1] Processed f1185709506.png -> ../zm_scraper/listing/gdino/output/1/f1185709506.png
# [1] Processed w1190844926.png -> ../zm_scraper/listing/gdino/output/1/w1190844926.png
# [1] Processed v1187261662.png -> ../zm_scraper/listing/gdino/output/1/v1187261662.png
# [1] Processed m1133776499.png -> ../zm_scraper/listing/gdino/output/1/m1133776499.png
# [1] Processed q1191599905.png -> ../zm_scraper/listing/gdino/output/1/q1191599905.png
# [1] Processed n1177560446.png -> ../zm_scraper/listing/gdino/output/1/n1177560446.png
# [1] Processed p1183630489.png -> ../zm_scraper/listing/gdino/output/1/p1183630489.png
# [1] Processed r1188237662.png -> ../zm_scraper/listing/gdino/output/1/r1188237662.png
# [1] Processed x1191588773.png -> ../zm_scraper/listing/gdino/output/1/x1191588773.png
# [1] Processed q1177578657.png -> ../zm_scraper/listing/gdino/output/1/q1177578657.png
# [1] Processed j1188522884.png -> ../zm_scraper/listing/gdino/output/1/j1188522884.png
# [1] Processed u1125653836.png -> ../zm_scraper/listing/gdino/output/1/u1125653836.png
# [1] Processed c1018322104.png -> ../zm_scraper/listing/gdino/output/1/c1018322104.png
# [1] Processed r1191406191.png -> ../zm_scraper/listing/gdino/output/1/r1191406191.png
# [1] Processed 1188971238.png -> ../zm_scraper/listing/gdino/output/1/1188971238.png
# [1] Processed t1175000873.png -> ../zm_scraper/listing/gdino/output/1/t1175000873.png
# [1] Processed p1185977494.png -> ../zm_scraper/listing/gdino/output/1/p1185977494.png
# [1] Processed o1119853616.png -> ../zm_scraper/listing/gdino/output/1/o1119853616.png
# [1] Processed k1191139466.png -> ../zm_scraper/listing/gdino/output/1/k1191139466.png
# [1] Processed 1191384462.png -> ../zm_scraper/listing/gdino/output/1/1191384462.png
# [1] Processed h1191566508.png -> ../zm_scraper/listing/gdino/output/1/h1191566508.png
# [1] Processed l1185983984.png -> ../zm_scraper/listing/gdino/output/1/l1185983984.png
# [1] Processed k1178398503.png -> ../zm_scraper/listing/gdino/output/1/k1178398503.png
# [1] Processed w1187675968.png -> ../zm_scraper/listing/gdino/output/1/w1187675968.png
# [1] Processed p1190564688.png -> ../zm_scraper/listing/gdino/output/1/p1190564688.png
# [1] Processed u1173708917.png -> ../zm_scraper/listing/gdino/output/1/u1173708917.png
# [1] Processed q1188300755.png -> ../zm_scraper/listing/gdino/output/1/q1188300755.png
# [1] Processed d1183331003.png -> ../zm_scraper/listing/gdino/output/1/d1183331003.png
# [1] Processed x1191726070.png -> ../zm_scraper/listing/gdino/output/1/x1191726070.png
# [1] Processed u1190891670.png -> ../zm_scraper/listing/gdino/output/1/u1190891670.png
# [1] Processed c1191614944.png -> ../zm_scraper/listing/gdino/output/1/c1191614944.png
# [1] Processed n1190306474.png -> ../zm_scraper/listing/gdino/output/1/n1190306474.png
# [1] Processed w1190845066.png -> ../zm_scraper/listing/gdino/output/1/w1190845066.png
# [1] Processed c1190311877.png -> ../zm_scraper/listing/gdino/output/1/c1190311877.png
# [1] Processed h1191354377.png -> ../zm_scraper/listing/gdino/output/1/h1191354377.png
# [1] Processed v1184566023.png -> ../zm_scraper/listing/gdino/output/1/v1184566023.png
# [1] Processed x1187673916.png -> ../zm_scraper/listing/gdino/output/1/x1187673916.png
# [1] Processed d1191230442.png -> ../zm_scraper/listing/gdino/output/1/d1191230442.png
# [1] Processed g1190860301.png -> ../zm_scraper/listing/gdino/output/1/g1190860301.png
# [1] Processed g1190999084.png -> ../zm_scraper/listing/gdino/output/1/g1190999084.png
# [1] Processed c1191011512.png -> ../zm_scraper/listing/gdino/output/1/c1191011512.png
# [1] Processed c1174455551.png -> ../zm_scraper/listing/gdino/output/1/c1174455551.png
# [1] Processed v1181907375.png -> ../zm_scraper/listing/gdino/output/1/v1181907375.png
# [1] Processed t1190248790.png -> ../zm_scraper/listing/gdino/output/1/t1190248790.png
# [1] Processed q1191671881.png -> ../zm_scraper/listing/gdino/output/1/q1191671881.png
# [1] Processed f1152247645.png -> ../zm_scraper/listing/gdino/output/1/f1152247645.png
# [1] Processed q1180810479.png -> ../zm_scraper/listing/gdino/output/1/q1180810479.png
# [1] Processed o1186239441.png -> ../zm_scraper/listing/gdino/output/1/o1186239441.png
# [1] Processed n1050873591.png -> ../zm_scraper/listing/gdino/output/1/n1050873591.png
# [1] Processed g1191217110.png -> ../zm_scraper/listing/gdino/output/1/g1191217110.png
# [1] Processed h1179263795.png -> ../zm_scraper/listing/gdino/output/1/h1179263795.png
# [1] Processed 1190862523.png -> ../zm_scraper/listing/gdino/output/1/1190862523.png
# [1] Processed c1186222082.png -> ../zm_scraper/listing/gdino/output/1/c1186222082.png
# [1] Processed u1185912108.png -> ../zm_scraper/listing/gdino/output/1/u1185912108.png
# [1] Processed t1144496280.png -> ../zm_scraper/listing/gdino/output/1/t1144496280.png
# [1] Processed g1187312653.png -> ../zm_scraper/listing/gdino/output/1/g1187312653.png
# [1] Processed n1191681464.png -> ../zm_scraper/listing/gdino/output/1/n1191681464.png
# [1] Processed v1173706351.png -> ../zm_scraper/listing/gdino/output/1/v1173706351.png
# [1] Processed s1191791966.png -> ../zm_scraper/listing/gdino/output/1/s1191791966.png
# [1] Processed h1191357858.png -> ../zm_scraper/listing/gdino/output/1/h1191357858.png
# [1] Processed r1190987605.png -> ../zm_scraper/listing/gdino/output/1/r1190987605.png
# [1] Processed s1119897266.png -> ../zm_scraper/listing/gdino/output/1/s1119897266.png
# [1] Processed o1187637806.png -> ../zm_scraper/listing/gdino/output/1/o1187637806.png
# [1] Processed m1187216150.png -> ../zm_scraper/listing/gdino/output/1/m1187216150.png
# [1] Processed h1191485348.png -> ../zm_scraper/listing/gdino/output/1/h1191485348.png
# [1] Processed v1185996273.png -> ../zm_scraper/listing/gdino/output/1/v1185996273.png
# [1] Processed u1187634347.png -> ../zm_scraper/listing/gdino/output/1/u1187634347.png
# [1] Processed q1185787171.png -> ../zm_scraper/listing/gdino/output/1/q1185787171.png
# [1] Processed t1189958345.png -> ../zm_scraper/listing/gdino/output/1/t1189958345.png
# [1] Processed h1155548441.png -> ../zm_scraper/listing/gdino/output/1/h1155548441.png
# [1] Processed k1191395334.png -> ../zm_scraper/listing/gdino/output/1/k1191395334.png
# [1] Processed j1187062556.png -> ../zm_scraper/listing/gdino/output/1/j1187062556.png
# [1] Processed x1121603563.png -> ../zm_scraper/listing/gdino/output/1/x1121603563.png
# [1] Processed w1181337501.png -> ../zm_scraper/listing/gdino/output/1/w1181337501.png
# [1] Processed n1191590384.png -> ../zm_scraper/listing/gdino/output/1/n1191590384.png
# [1] Processed n1191690494.png -> ../zm_scraper/listing/gdino/output/1/n1191690494.png
# [1] Processed l1180181252.png -> ../zm_scraper/listing/gdino/output/1/l1180181252.png
# [1] Processed p1187246330.png -> ../zm_scraper/listing/gdino/output/1/p1187246330.png
# [1] Processed w1191415731.png -> ../zm_scraper/listing/gdino/output/1/w1191415731.png
# [1] Processed u1191585367.png -> ../zm_scraper/listing/gdino/output/1/u1191585367.png
# [1] Processed s1178157340.png -> ../zm_scraper/listing/gdino/output/1/s1178157340.png
# [1] Processed b1190374058.png -> ../zm_scraper/listing/gdino/output/1/b1190374058.png
# [1] Processed s1180179542.png -> ../zm_scraper/listing/gdino/output/1/s1180179542.png
# [1] Processed c1176991774.png -> ../zm_scraper/listing/gdino/output/1/c1176991774.png
# [1] Processed x1144495093.png -> ../zm_scraper/listing/gdino/output/1/x1144495093.png
# [1] Processed o1190507451.png -> ../zm_scraper/listing/gdino/output/1/o1190507451.png
# [1] Processed f1191458213.png -> ../zm_scraper/listing/gdino/output/1/f1191458213.png
# [1] Processed g1190646585.png -> ../zm_scraper/listing/gdino/output/1/g1190646585.png
# [1] Processed w1190871465.png -> ../zm_scraper/listing/gdino/output/1/w1190871465.png
# [1] Processed q1189807341.png -> ../zm_scraper/listing/gdino/output/1/q1189807341.png
# [1] Processed s1174518776.png -> ../zm_scraper/listing/gdino/output/1/s1174518776.png
# [1] Processed v1191543625.png -> ../zm_scraper/listing/gdino/output/1/v1191543625.png
# [1] Processed q1191392184.png -> ../zm_scraper/listing/gdino/output/1/q1191392184.png
# [1] Processed o1148253450.png -> ../zm_scraper/listing/gdino/output/1/o1148253450.png
# [1] Processed 1187040966.png -> ../zm_scraper/listing/gdino/output/1/1187040966.png
# [1] Processed s1190829449.png -> ../zm_scraper/listing/gdino/output/1/s1190829449.png
# [1] Processed k1187236896.png -> ../zm_scraper/listing/gdino/output/1/k1187236896.png
# [1] Processed n1177515783.png -> ../zm_scraper/listing/gdino/output/1/n1177515783.png
# [1] Processed r1191213977.png -> ../zm_scraper/listing/gdino/output/1/r1191213977.png
# [1] Processed h1175361047.png -> ../zm_scraper/listing/gdino/output/1/h1175361047.png
# [1] Processed o1111669448.png -> ../zm_scraper/listing/gdino/output/1/o1111669448.png
# [1] Processed l1187215014.png -> ../zm_scraper/listing/gdino/output/1/l1187215014.png
# [1] Processed c1179281381.png -> ../zm_scraper/listing/gdino/output/1/c1179281381.png
# [1] Processed c1190560087.png -> ../zm_scraper/listing/gdino/output/1/c1190560087.png
# [1] Processed e1191097669.png -> ../zm_scraper/listing/gdino/output/1/e1191097669.png
# [1] Processed n1184979547.png -> ../zm_scraper/listing/gdino/output/1/n1184979547.png
# [1] Processed f1191614095.png -> ../zm_scraper/listing/gdino/output/1/f1191614095.png
# [1] Processed n1189266389.png -> ../zm_scraper/listing/gdino/output/1/n1189266389.png
# [1] Processed s1175248638.png -> ../zm_scraper/listing/gdino/output/1/s1175248638.png
# [1] Processed x1144497640.png -> ../zm_scraper/listing/gdino/output/1/x1144497640.png
# [1] Processed j1191354950.png -> ../zm_scraper/listing/gdino/output/1/j1191354950.png
# [1] Processed r1172860507.png -> ../zm_scraper/listing/gdino/output/1/r1172860507.png
# [1] Processed c1181899488.png -> ../zm_scraper/listing/gdino/output/1/c1181899488.png
# [1] Processed c1189274607.png -> ../zm_scraper/listing/gdino/output/1/c1189274607.png
# [1] Processed k1190017607.png -> ../zm_scraper/listing/gdino/output/1/k1190017607.png
# [1] Processed q1169973454.png -> ../zm_scraper/listing/gdino/output/1/q1169973454.png
# [1] Processed p1190570350.png -> ../zm_scraper/listing/gdino/output/1/p1190570350.png
# [1] Processed v1191359696.png -> ../zm_scraper/listing/gdino/output/1/v1191359696.png
# [1] Processed 1190947766.png -> ../zm_scraper/listing/gdino/output/1/1190947766.png
# [1] Processed x1190805798.png -> ../zm_scraper/listing/gdino/output/1/x1190805798.png
# [1] Processed f1182381846.png -> ../zm_scraper/listing/gdino/output/1/f1182381846.png
# [1] Processed s1191227795.png -> ../zm_scraper/listing/gdino/output/1/s1191227795.png
# [1] Processed q1187396416.png -> ../zm_scraper/listing/gdino/output/1/q1187396416.png
# [1] Processed h1191494654.png -> ../zm_scraper/listing/gdino/output/1/h1191494654.png
# [1] Processed k1191177775.png -> ../zm_scraper/listing/gdino/output/1/k1191177775.png
# [1] Processed r1188366109.png -> ../zm_scraper/listing/gdino/output/1/r1188366109.png
# [1] Processed v1184067515.png -> ../zm_scraper/listing/gdino/output/1/v1184067515.png
# [1] Processed b1191454294.png -> ../zm_scraper/listing/gdino/output/1/b1191454294.png
# [1] Processed m1174452367.png -> ../zm_scraper/listing/gdino/output/1/m1174452367.png
# [1] Processed k1185974489.png -> ../zm_scraper/listing/gdino/output/1/k1185974489.png
# [1] Processed b1094792463.png -> ../zm_scraper/listing/gdino/output/1/b1094792463.png
# [1] Processed 1187259405.png -> ../zm_scraper/listing/gdino/output/1/1187259405.png
# [1] Processed l1163916088.png -> ../zm_scraper/listing/gdino/output/1/l1163916088.png
# [1] Processed s1158964294.png -> ../zm_scraper/listing/gdino/output/1/s1158964294.png
# [1] Processed v1191007699.png -> ../zm_scraper/listing/gdino/output/1/v1191007699.png
# [1] Processed g1188338616.png -> ../zm_scraper/listing/gdino/output/1/g1188338616.png
# [1] Processed k1191345098.png -> ../zm_scraper/listing/gdino/output/1/k1191345098.png
# [1] Processed f1171816057.png -> ../zm_scraper/listing/gdino/output/1/f1171816057.png
# [1] Processed l1190830129.png -> ../zm_scraper/listing/gdino/output/1/l1190830129.png
# [1] Processed r1189452439.png -> ../zm_scraper/listing/gdino/output/1/r1189452439.png
# [1] Processed v1190298402.png -> ../zm_scraper/listing/gdino/output/1/v1190298402.png
# [1] Processed u1177556155.png -> ../zm_scraper/listing/gdino/output/1/u1177556155.png
# [1] Processed u1175252424.png -> ../zm_scraper/listing/gdino/output/1/u1175252424.png
# [1] Processed k1191474797.png -> ../zm_scraper/listing/gdino/output/1/k1191474797.png
# [1] Processed q1177627244.png -> ../zm_scraper/listing/gdino/output/1/q1177627244.png
# [1] Processed h1180981091.png -> ../zm_scraper/listing/gdino/output/1/h1180981091.png
# [1] Processed l1173943616.png -> ../zm_scraper/listing/gdino/output/1/l1173943616.png
# [1] Processed e1144509373.png -> ../zm_scraper/listing/gdino/output/1/e1144509373.png
# [1] Processed v1189794703.png -> ../zm_scraper/listing/gdino/output/1/v1189794703.png
# [1] Processed d1187227651.png -> ../zm_scraper/listing/gdino/output/1/d1187227651.png
# [1] Processed g1186111364.png -> ../zm_scraper/listing/gdino/output/1/g1186111364.png
# [1] Processed x1179990049.png -> ../zm_scraper/listing/gdino/output/1/x1179990049.png
# [1] Processed g1162120624.png -> ../zm_scraper/listing/gdino/output/1/g1162120624.png
# [1] Processed l1187709741.png -> ../zm_scraper/listing/gdino/output/1/l1187709741.png
# [1] Processed v1157073564.png -> ../zm_scraper/listing/gdino/output/1/v1157073564.png
# [1] Processed n1181963058.png -> ../zm_scraper/listing/gdino/output/1/n1181963058.png
# [1] Processed p1127453774.png -> ../zm_scraper/listing/gdino/output/1/p1127453774.png
# [1] Processed l1188981602.png -> ../zm_scraper/listing/gdino/output/1/l1188981602.png
# [1] Processed t1191463002.png -> ../zm_scraper/listing/gdino/output/1/t1191463002.png
# [1] Processed r1140105858.png -> ../zm_scraper/listing/gdino/output/1/r1140105858.png
# [1] Processed d1191065516.png -> ../zm_scraper/listing/gdino/output/1/d1191065516.png
# [1] Processed m1188973836.png -> ../zm_scraper/listing/gdino/output/1/m1188973836.png
# [1] Processed k1190934472.png -> ../zm_scraper/listing/gdino/output/1/k1190934472.png
# [1] Processed k1190957510.png -> ../zm_scraper/listing/gdino/output/1/k1190957510.png
# [1] Processed 1183014126.png -> ../zm_scraper/listing/gdino/output/1/1183014126.png
# [1] Processed w1169319899.png -> ../zm_scraper/listing/gdino/output/1/w1169319899.png
# [1] Processed j1155396060.png -> ../zm_scraper/listing/gdino/output/1/j1155396060.png
# [1] Processed q1183324759.png -> ../zm_scraper/listing/gdino/output/1/q1183324759.png
# [1] Processed j1191431672.png -> ../zm_scraper/listing/gdino/output/1/j1191431672.png
# [1] Processed u1187785966.png -> ../zm_scraper/listing/gdino/output/1/u1187785966.png
# [1] Processed e1183317765.png -> ../zm_scraper/listing/gdino/output/1/e1183317765.png
# [1] Processed v1120503911.png -> ../zm_scraper/listing/gdino/output/1/v1120503911.png
# [1] Processed p1188910687.png -> ../zm_scraper/listing/gdino/output/1/p1188910687.png
# [1] Processed b1183312199.png -> ../zm_scraper/listing/gdino/output/1/b1183312199.png
# [2] Processed x1185026795.png -> ../zm_scraper/listing/gdino/output/2/x1185026795.png
# [2] Processed 1183422386.png -> ../zm_scraper/listing/gdino/output/2/1183422386.png
# [2] Processed e1191032005.png -> ../zm_scraper/listing/gdino/output/2/e1191032005.png
# [2] Processed w1183158454.png -> ../zm_scraper/listing/gdino/output/2/w1183158454.png
# [2] Processed o1181780489.png -> ../zm_scraper/listing/gdino/output/2/o1181780489.png
# [2] Processed d1191083725.png -> ../zm_scraper/listing/gdino/output/2/d1191083725.png
# [2] Processed s1071217819.png -> ../zm_scraper/listing/gdino/output/2/s1071217819.png
# [2] Processed t1136663262.png -> ../zm_scraper/listing/gdino/output/2/t1136663262.png
# [2] Processed o1161050466.png -> ../zm_scraper/listing/gdino/output/2/o1161050466.png
# [2] Processed c1187483831.png -> ../zm_scraper/listing/gdino/output/2/c1187483831.png
# [2] Processed v1171652956.png -> ../zm_scraper/listing/gdino/output/2/v1171652956.png
# [2] Processed j1191314319.png -> ../zm_scraper/listing/gdino/output/2/j1191314319.png
# [2] Processed b1174068183.png -> ../zm_scraper/listing/gdino/output/2/b1174068183.png
# [2] Processed v1168878467.png -> ../zm_scraper/listing/gdino/output/2/v1168878467.png
# [2] Processed o1158492337.png -> ../zm_scraper/listing/gdino/output/2/o1158492337.png
# [2] Processed v1189178633.png -> ../zm_scraper/listing/gdino/output/2/v1189178633.png
# [2] Processed k1184414767.png -> ../zm_scraper/listing/gdino/output/2/k1184414767.png
# [2] Processed o1185235396.png -> ../zm_scraper/listing/gdino/output/2/o1185235396.png
# [2] Processed e1145787141.png -> ../zm_scraper/listing/gdino/output/2/e1145787141.png
# [2] Processed 1184973984.png -> ../zm_scraper/listing/gdino/output/2/1184973984.png
# [2] Processed k1191027678.png -> ../zm_scraper/listing/gdino/output/2/k1191027678.png
# [2] Processed f1109446657.png -> ../zm_scraper/listing/gdino/output/2/f1109446657.png
# [2] Processed h1055489564.png -> ../zm_scraper/listing/gdino/output/2/h1055489564.png
# [2] Processed w1180994249.png -> ../zm_scraper/listing/gdino/output/2/w1180994249.png
# [2] Processed n1190944641.png -> ../zm_scraper/listing/gdino/output/2/n1190944641.png
# [2] Processed m1175679082.png -> ../zm_scraper/listing/gdino/output/2/m1175679082.png
# [2] Processed s1187120643.png -> ../zm_scraper/listing/gdino/output/2/s1187120643.png
# [2] Processed g1191389421.png -> ../zm_scraper/listing/gdino/output/2/g1191389421.png
# [2] Processed b1191603128.png -> ../zm_scraper/listing/gdino/output/2/b1191603128.png
# [2] Processed m1190271639.png -> ../zm_scraper/listing/gdino/output/2/m1190271639.png
# [2] Processed b1188791317.png -> ../zm_scraper/listing/gdino/output/2/b1188791317.png
# [2] Processed t1190192579.png -> ../zm_scraper/listing/gdino/output/2/t1190192579.png
# [2] Processed q1191503953.png -> ../zm_scraper/listing/gdino/output/2/q1191503953.png
# [2] Processed x1190771308.png -> ../zm_scraper/listing/gdino/output/2/x1190771308.png
# [2] Processed o1191351759.png -> ../zm_scraper/listing/gdino/output/2/o1191351759.png
# [2] Processed v1180804864.png -> ../zm_scraper/listing/gdino/output/2/v1180804864.png
# [2] Processed n1190154096.png -> ../zm_scraper/listing/gdino/output/2/n1190154096.png
# [2] Processed 1191541604.png -> ../zm_scraper/listing/gdino/output/2/1191541604.png
# [2] Processed u1191650354.png -> ../zm_scraper/listing/gdino/output/2/u1191650354.png
# [2] Processed n1175534688.png -> ../zm_scraper/listing/gdino/output/2/n1175534688.png
# [2] Processed n1191483955.png -> ../zm_scraper/listing/gdino/output/2/n1191483955.png
# [2] Processed x1171181348.png -> ../zm_scraper/listing/gdino/output/2/x1171181348.png
# [2] Processed j1191793085.png -> ../zm_scraper/listing/gdino/output/2/j1191793085.png
# [2] Processed w1187906982.png -> ../zm_scraper/listing/gdino/output/2/w1187906982.png
# [2] Processed d1191104993.png -> ../zm_scraper/listing/gdino/output/2/d1191104993.png
# [2] Processed j1188223998.png -> ../zm_scraper/listing/gdino/output/2/j1188223998.png
# [2] Processed l1171615527.png -> ../zm_scraper/listing/gdino/output/2/l1171615527.png
# [2] Processed k1144655228.png -> ../zm_scraper/listing/gdino/output/2/k1144655228.png
# [2] Processed o1187156535.png -> ../zm_scraper/listing/gdino/output/2/o1187156535.png
# [2] Processed l1191318353.png -> ../zm_scraper/listing/gdino/output/2/l1191318353.png
# [2] Processed o1087687490.png -> ../zm_scraper/listing/gdino/output/2/o1087687490.png
# [2] Processed p1191810626.png -> ../zm_scraper/listing/gdino/output/2/p1191810626.png
# [2] Processed v1140739003.png -> ../zm_scraper/listing/gdino/output/2/v1140739003.png
# [2] Processed d1191807097.png -> ../zm_scraper/listing/gdino/output/2/d1191807097.png
# [2] Processed m1191712171.png -> ../zm_scraper/listing/gdino/output/2/m1191712171.png
# [2] Processed e1191332130.png -> ../zm_scraper/listing/gdino/output/2/e1191332130.png
# [2] Processed b1190826799.png -> ../zm_scraper/listing/gdino/output/2/b1190826799.png
# [2] Processed u1159547663.png -> ../zm_scraper/listing/gdino/output/2/u1159547663.png
# [2] Processed l1189425708.png -> ../zm_scraper/listing/gdino/output/2/l1189425708.png
# [2] Processed 1191044626.png -> ../zm_scraper/listing/gdino/output/2/1191044626.png
# [2] Processed c1132411431.png -> ../zm_scraper/listing/gdino/output/2/c1132411431.png
# [2] Processed w1190902512.png -> ../zm_scraper/listing/gdino/output/2/w1190902512.png
# [2] Processed q1154290089.png -> ../zm_scraper/listing/gdino/output/2/q1154290089.png
# [2] Processed q1190301197.png -> ../zm_scraper/listing/gdino/output/2/q1190301197.png
# [2] Processed 1191618378.png -> ../zm_scraper/listing/gdino/output/2/1191618378.png
# [2] Processed u1153546272.png -> ../zm_scraper/listing/gdino/output/2/u1153546272.png
# [2] Processed t1191330738.png -> ../zm_scraper/listing/gdino/output/2/t1191330738.png
# [2] Processed c1191308923.png -> ../zm_scraper/listing/gdino/output/2/c1191308923.png
# [2] Processed k1116223413.png -> ../zm_scraper/listing/gdino/output/2/k1116223413.png
# [2] Processed v1187327043.png -> ../zm_scraper/listing/gdino/output/2/v1187327043.png
# [2] Processed c1191755886.png -> ../zm_scraper/listing/gdino/output/2/c1191755886.png
# [2] Processed c583016002.png -> ../zm_scraper/listing/gdino/output/2/c583016002.png
# [2] Processed q1169757893.png -> ../zm_scraper/listing/gdino/output/2/q1169757893.png
# [2] Processed u1156583527.png -> ../zm_scraper/listing/gdino/output/2/u1156583527.png
# [2] Processed p1101871478.png -> ../zm_scraper/listing/gdino/output/2/p1101871478.png
# [2] Processed g1182426614.png -> ../zm_scraper/listing/gdino/output/2/g1182426614.png
# [2] Processed v1126760254.png -> ../zm_scraper/listing/gdino/output/2/v1126760254.png
# [2] Processed k1141542872.png -> ../zm_scraper/listing/gdino/output/2/k1141542872.png
# [3] Processed e1190950993.png -> ../zm_scraper/listing/gdino/output/3/e1190950993.png
# [3] Processed n1191554586.png -> ../zm_scraper/listing/gdino/output/3/n1191554586.png
# [3] Processed m1191120382.png -> ../zm_scraper/listing/gdino/output/3/m1191120382.png
# [3] Processed k1183034177.png -> ../zm_scraper/listing/gdino/output/3/k1183034177.png
# [3] Processed n1191611788.png -> ../zm_scraper/listing/gdino/output/3/n1191611788.png
# [3] Processed l1120732506.png -> ../zm_scraper/listing/gdino/output/3/l1120732506.png
# [3] Processed g1086187704.png -> ../zm_scraper/listing/gdino/output/3/g1086187704.png
# [3] Processed b1113509703.png -> ../zm_scraper/listing/gdino/output/3/b1113509703.png
# [3] Processed t1191103807.png -> ../zm_scraper/listing/gdino/output/3/t1191103807.png
# [3] Processed s1191115211.png -> ../zm_scraper/listing/gdino/output/3/s1191115211.png
# [3] Processed o1191829396.png -> ../zm_scraper/listing/gdino/output/3/o1191829396.png
# [3] Processed q1191566819.png -> ../zm_scraper/listing/gdino/output/3/q1191566819.png
# [3] Processed w1191615331.png -> ../zm_scraper/listing/gdino/output/3/w1191615331.png
# [3] Processed o1191824345.png -> ../zm_scraper/listing/gdino/output/3/o1191824345.png
# [3] Processed e1190825724.png -> ../zm_scraper/listing/gdino/output/3/e1190825724.png
# [3] Processed q1175201682.png -> ../zm_scraper/listing/gdino/output/3/q1175201682.png
# [3] Processed e1191338151.png -> ../zm_scraper/listing/gdino/output/3/e1191338151.png
# [3] Processed b1187277326.png -> ../zm_scraper/listing/gdino/output/3/b1187277326.png
# [3] Processed w1191003804.png -> ../zm_scraper/listing/gdino/output/3/w1191003804.png
# [3] Processed 1182698598.png -> ../zm_scraper/listing/gdino/output/3/1182698598.png
# [3] Processed e1179009805.png -> ../zm_scraper/listing/gdino/output/3/e1179009805.png
# [3] Processed f1154734978.png -> ../zm_scraper/listing/gdino/output/3/f1154734978.png
# [3] Processed d1181561615.png -> ../zm_scraper/listing/gdino/output/3/d1181561615.png
# [3] Processed c1186738086.png -> ../zm_scraper/listing/gdino/output/3/c1186738086.png
# [3] Processed e1190920853.png -> ../zm_scraper/listing/gdino/output/3/e1190920853.png
# [3] Processed u1190927750.png -> ../zm_scraper/listing/gdino/output/3/u1190927750.png
# [3] Processed h1186186428.png -> ../zm_scraper/listing/gdino/output/3/h1186186428.png
# [3] Processed s1167344625.png -> ../zm_scraper/listing/gdino/output/3/s1167344625.png
# [3] Processed m1191475505.png -> ../zm_scraper/listing/gdino/output/3/m1191475505.png
# [3] Processed h1191064243.png -> ../zm_scraper/listing/gdino/output/3/h1191064243.png
# [3] Processed e1191589903.png -> ../zm_scraper/listing/gdino/output/3/e1191589903.png
# [3] Processed d1191358224.png -> ../zm_scraper/listing/gdino/output/3/d1191358224.png
# [3] Processed j1184298272.png -> ../zm_scraper/listing/gdino/output/3/j1184298272.png
# [3] Processed x1163817037.png -> ../zm_scraper/listing/gdino/output/3/x1163817037.png
# [3] Processed m1179874250.png -> ../zm_scraper/listing/gdino/output/3/m1179874250.png
# [3] Processed l1191104386.png -> ../zm_scraper/listing/gdino/output/3/l1191104386.png
# [3] Processed l1189543757.png -> ../zm_scraper/listing/gdino/output/3/l1189543757.png
# [3] Processed b1190656187.png -> ../zm_scraper/listing/gdino/output/3/b1190656187.png
# [3] Processed r1170493856.png -> ../zm_scraper/listing/gdino/output/3/r1170493856.png
# [3] Processed b1191051519.png -> ../zm_scraper/listing/gdino/output/3/b1191051519.png
# [3] Processed h1154624403.png -> ../zm_scraper/listing/gdino/output/3/h1154624403.png
# [3] Processed w1191481916.png -> ../zm_scraper/listing/gdino/output/3/w1191481916.png
# [3] Processed w1190860261.png -> ../zm_scraper/listing/gdino/output/3/w1190860261.png
# [3] Processed o1190121007.png -> ../zm_scraper/listing/gdino/output/3/o1190121007.png
# [3] Processed t1185857977.png -> ../zm_scraper/listing/gdino/output/3/t1185857977.png
# [3] Processed m1190985464.png -> ../zm_scraper/listing/gdino/output/3/m1190985464.png
# [3] Processed j1189710052.png -> ../zm_scraper/listing/gdino/output/3/j1189710052.png
# [3] Processed g1161033076.png -> ../zm_scraper/listing/gdino/output/3/g1161033076.png
# [3] Processed o1179024769.png -> ../zm_scraper/listing/gdino/output/3/o1179024769.png
# [3] Processed l1185868613.png -> ../zm_scraper/listing/gdino/output/3/l1185868613.png
# [3] Processed l1191174227.png -> ../zm_scraper/listing/gdino/output/3/l1191174227.png
# [3] Processed v1187033255.png -> ../zm_scraper/listing/gdino/output/3/v1187033255.png
# [3] Processed d1190904638.png -> ../zm_scraper/listing/gdino/output/3/d1190904638.png
# [3] Processed j1191735371.png -> ../zm_scraper/listing/gdino/output/3/j1191735371.png
# [3] Processed e1187403191.png -> ../zm_scraper/listing/gdino/output/3/e1187403191.png
# [3] Processed m1148753453.png -> ../zm_scraper/listing/gdino/output/3/m1148753453.png
# [3] Processed h1184041004.png -> ../zm_scraper/listing/gdino/output/3/h1184041004.png
# [3] Processed x1152907365.png -> ../zm_scraper/listing/gdino/output/3/x1152907365.png
# [3] Processed h1183729569.png -> ../zm_scraper/listing/gdino/output/3/h1183729569.png
# [3] Processed m1184169495.png -> ../zm_scraper/listing/gdino/output/3/m1184169495.png
# [3] Processed n1173190176.png -> ../zm_scraper/listing/gdino/output/3/n1173190176.png
# [3] Processed l1160447824.png -> ../zm_scraper/listing/gdino/output/3/l1160447824.png
# [3] Processed s1182286586.png -> ../zm_scraper/listing/gdino/output/3/s1182286586.png
# [3] Processed x1191129028.png -> ../zm_scraper/listing/gdino/output/3/x1191129028.png
# [3] Processed n1182383022.png -> ../zm_scraper/listing/gdino/output/3/n1182383022.png
# [3] Processed l1191485635.png -> ../zm_scraper/listing/gdino/output/3/l1191485635.png
# [3] Processed m1190952251.png -> ../zm_scraper/listing/gdino/output/3/m1190952251.png
# [3] Processed b1184343695.png -> ../zm_scraper/listing/gdino/output/3/b1184343695.png
# [3] Processed t1190955488.png -> ../zm_scraper/listing/gdino/output/3/t1190955488.png
# [3] Processed j652750569.png -> ../zm_scraper/listing/gdino/output/3/j652750569.png
# [3] Processed d1181234166.png -> ../zm_scraper/listing/gdino/output/3/d1181234166.png
# [3] Processed s1190827711.png -> ../zm_scraper/listing/gdino/output/3/s1190827711.png
# [3] Processed n1191478282.png -> ../zm_scraper/listing/gdino/output/3/n1191478282.png
# [3] Processed h1175863238.png -> ../zm_scraper/listing/gdino/output/3/h1175863238.png
# [3] Processed o1189958228.png -> ../zm_scraper/listing/gdino/output/3/o1189958228.png
# [3] Processed p1191182933.png -> ../zm_scraper/listing/gdino/output/3/p1191182933.png
# [3] Processed o1190797730.png -> ../zm_scraper/listing/gdino/output/3/o1190797730.png
# [3] Processed q1181093253.png -> ../zm_scraper/listing/gdino/output/3/q1181093253.png
# [3] Processed l1177536628.png -> ../zm_scraper/listing/gdino/output/3/l1177536628.png
# [3] Processed u1190987515.png -> ../zm_scraper/listing/gdino/output/3/u1190987515.png
# [3] Processed w1191550818.png -> ../zm_scraper/listing/gdino/output/3/w1191550818.png
# [3] Processed n1191144106.png -> ../zm_scraper/listing/gdino/output/3/n1191144106.png
# [3] Processed q1191127724.png -> ../zm_scraper/listing/gdino/output/3/q1191127724.png
# [3] Processed r1191326691.png -> ../zm_scraper/listing/gdino/output/3/r1191326691.png
# [3] Processed h1190298916.png -> ../zm_scraper/listing/gdino/output/3/h1190298916.png
# [3] Processed k1191614437.png -> ../zm_scraper/listing/gdino/output/3/k1191614437.png
# [3] Processed r1141596794.png -> ../zm_scraper/listing/gdino/output/3/r1141596794.png
# [3] Processed m1189471840.png -> ../zm_scraper/listing/gdino/output/3/m1189471840.png
# [3] Processed o1186960589.png -> ../zm_scraper/listing/gdino/output/3/o1186960589.png
# [3] Processed q1191056336.png -> ../zm_scraper/listing/gdino/output/3/q1191056336.png
# [3] Processed c1189275966.png -> ../zm_scraper/listing/gdino/output/3/c1189275966.png
# [3] Processed l1180842849.png -> ../zm_scraper/listing/gdino/output/3/l1180842849.png
# [3] Processed b1191481415.png -> ../zm_scraper/listing/gdino/output/3/b1191481415.png
# [3] Processed p1188443975.png -> ../zm_scraper/listing/gdino/output/3/p1188443975.png
# [3] Processed k1190981428.png -> ../zm_scraper/listing/gdino/output/3/k1190981428.png
# [3] Processed l1183172879.png -> ../zm_scraper/listing/gdino/output/3/l1183172879.png
# [3] Processed m1187017242.png -> ../zm_scraper/listing/gdino/output/3/m1187017242.png
# [3] Processed 1173009687.png -> ../zm_scraper/listing/gdino/output/3/1173009687.png
# [3] Processed p1186003322.png -> ../zm_scraper/listing/gdino/output/3/p1186003322.png
# [3] Processed m1169461915.png -> ../zm_scraper/listing/gdino/output/3/m1169461915.png
# [3] Processed u1191088615.png -> ../zm_scraper/listing/gdino/output/3/u1191088615.png
# [3] Processed j1187022551.png -> ../zm_scraper/listing/gdino/output/3/j1187022551.png
# [3] Processed r1182777193.png -> ../zm_scraper/listing/gdino/output/3/r1182777193.png
# [3] Processed 1154588944.png -> ../zm_scraper/listing/gdino/output/3/1154588944.png
# [3] Processed d1189849693.png -> ../zm_scraper/listing/gdino/output/3/d1189849693.png
# [3] Processed d1191355427.png -> ../zm_scraper/listing/gdino/output/3/d1191355427.png
# [3] Processed l1191353837.png -> ../zm_scraper/listing/gdino/output/3/l1191353837.png
# [3] Processed t1191527313.png -> ../zm_scraper/listing/gdino/output/3/t1191527313.png
# [3] Processed b1187441783.png -> ../zm_scraper/listing/gdino/output/3/b1187441783.png
# [3] Processed j1185687129.png -> ../zm_scraper/listing/gdino/output/3/j1185687129.png
# [3] Processed w1184158234.png -> ../zm_scraper/listing/gdino/output/3/w1184158234.png
# [3] Processed m1191425689.png -> ../zm_scraper/listing/gdino/output/3/m1191425689.png
# [3] Processed o1190944251.png -> ../zm_scraper/listing/gdino/output/3/o1190944251.png
# [3] Processed p1171340896.png -> ../zm_scraper/listing/gdino/output/3/p1171340896.png
# [3] Processed g1190570632.png -> ../zm_scraper/listing/gdino/output/3/g1190570632.png
# [3] Processed j1190929952.png -> ../zm_scraper/listing/gdino/output/3/j1190929952.png
# [3] Processed x1179305942.png -> ../zm_scraper/listing/gdino/output/3/x1179305942.png
# [3] Processed r1182700824.png -> ../zm_scraper/listing/gdino/output/3/r1182700824.png
# [3] Processed r1189527569.png -> ../zm_scraper/listing/gdino/output/3/r1189527569.png
# [4] Processed s1191590524.png -> ../zm_scraper/listing/gdino/output/4/s1191590524.png
# [4] Processed t1166294537.png -> ../zm_scraper/listing/gdino/output/4/t1166294537.png
# [4] Processed m1191500219.png -> ../zm_scraper/listing/gdino/output/4/m1191500219.png
# [4] Processed k1191595454.png -> ../zm_scraper/listing/gdino/output/4/k1191595454.png
# [4] Processed s1191629451.png -> ../zm_scraper/listing/gdino/output/4/s1191629451.png
# [4] Processed d1189586751.png -> ../zm_scraper/listing/gdino/output/4/d1189586751.png
# [4] Processed s1191592557.png -> ../zm_scraper/listing/gdino/output/4/s1191592557.png
# [4] Processed g1191558142.png -> ../zm_scraper/listing/gdino/output/4/g1191558142.png
# [4] Processed q1190568074.png -> ../zm_scraper/listing/gdino/output/4/q1190568074.png
# [4] Processed u1187177901.png -> ../zm_scraper/listing/gdino/output/4/u1187177901.png
# [4] Processed o1179306265.png -> ../zm_scraper/listing/gdino/output/4/o1179306265.png
# [4] Processed n1191790097.png -> ../zm_scraper/listing/gdino/output/4/n1191790097.png
# [4] Processed t1191270704.png -> ../zm_scraper/listing/gdino/output/4/t1191270704.png
# [4] Processed j1132611060.png -> ../zm_scraper/listing/gdino/output/4/j1132611060.png
# [4] Processed x1191573830.png -> ../zm_scraper/listing/gdino/output/4/x1191573830.png
# [4] Processed 1191741850.png -> ../zm_scraper/listing/gdino/output/4/1191741850.png
# [4] Processed h1185898711.png -> ../zm_scraper/listing/gdino/output/4/h1185898711.png
# [4] Processed d1191563369.png -> ../zm_scraper/listing/gdino/output/4/d1191563369.png
# [4] Processed m1191474270.png -> ../zm_scraper/listing/gdino/output/4/m1191474270.png
# [4] Processed e1151547546.png -> ../zm_scraper/listing/gdino/output/4/e1151547546.png
# [4] Processed p1191563290.png -> ../zm_scraper/listing/gdino/output/4/p1191563290.png
# [4] Processed f1191723507.png -> ../zm_scraper/listing/gdino/output/4/f1191723507.png
# [4] Processed j1191717458.png -> ../zm_scraper/listing/gdino/output/4/j1191717458.png
# [4] Processed v1191497444.png -> ../zm_scraper/listing/gdino/output/4/v1191497444.png
# [4] Processed b1191366748.png -> ../zm_scraper/listing/gdino/output/4/b1191366748.png
# [4] Processed l1173441636.png -> ../zm_scraper/listing/gdino/output/4/l1173441636.png
# [4] Processed p1191561874.png -> ../zm_scraper/listing/gdino/output/4/p1191561874.png
# [4] Processed c1191683211.png -> ../zm_scraper/listing/gdino/output/4/c1191683211.png
# [4] Processed l1191717769.png -> ../zm_scraper/listing/gdino/output/4/l1191717769.png
# [4] Processed p1191731871.png -> ../zm_scraper/listing/gdino/output/4/p1191731871.png
# [4] Processed d1191725332.png -> ../zm_scraper/listing/gdino/output/4/d1191725332.png
# [4] Processed j1191552346.png -> ../zm_scraper/listing/gdino/output/4/j1191552346.png
# [4] Processed t1191616766.png -> ../zm_scraper/listing/gdino/output/4/t1191616766.png
# [4] Processed h1191819480.png -> ../zm_scraper/listing/gdino/output/4/h1191819480.png
# [4] Processed s1191718238.png -> ../zm_scraper/listing/gdino/output/4/s1191718238.png
# [4] Processed m1191439995.png -> ../zm_scraper/listing/gdino/output/4/m1191439995.png
# [4] Processed s1191535851.png -> ../zm_scraper/listing/gdino/output/4/s1191535851.png
# [4] Processed o1155624630.png -> ../zm_scraper/listing/gdino/output/4/o1155624630.png
# [4] Processed t1175705831.png -> ../zm_scraper/listing/gdino/output/4/t1175705831.png
# [4] Processed q1191533184.png -> ../zm_scraper/listing/gdino/output/4/q1191533184.png
# [4] Processed n1191677586.png -> ../zm_scraper/listing/gdino/output/4/n1191677586.png
# [4] Processed j1156079683.png -> ../zm_scraper/listing/gdino/output/4/j1156079683.png
# [4] Processed k1191481449.png -> ../zm_scraper/listing/gdino/output/4/k1191481449.png
# [4] Processed r1191413891.png -> ../zm_scraper/listing/gdino/output/4/r1191413891.png
# [4] Processed x1189580806.png -> ../zm_scraper/listing/gdino/output/4/x1189580806.png
# [4] Processed w1160324955.png -> ../zm_scraper/listing/gdino/output/4/w1160324955.png
# [4] Processed 1191132465.png -> ../zm_scraper/listing/gdino/output/4/1191132465.png
# [4] Processed m1191610582.png -> ../zm_scraper/listing/gdino/output/4/m1191610582.png
# [4] Processed r1191477840.png -> ../zm_scraper/listing/gdino/output/4/r1191477840.png
# [4] Processed v1191469077.png -> ../zm_scraper/listing/gdino/output/4/v1191469077.png
# [4] Processed f1191552482.png -> ../zm_scraper/listing/gdino/output/4/f1191552482.png
# [4] Processed e1191586024.png -> ../zm_scraper/listing/gdino/output/4/e1191586024.png
# [4] Processed f1191683408.png -> ../zm_scraper/listing/gdino/output/4/f1191683408.png
# [4] Processed o1164318634.png -> ../zm_scraper/listing/gdino/output/4/o1164318634.png
# [4] Processed m1191741674.png -> ../zm_scraper/listing/gdino/output/4/m1191741674.png
# [4] Processed l1191456702.png -> ../zm_scraper/listing/gdino/output/4/l1191456702.png
# [4] Processed v1156090553.png -> ../zm_scraper/listing/gdino/output/4/v1156090553.png
# [4] Processed g1191622260.png -> ../zm_scraper/listing/gdino/output/4/g1191622260.png
# [4] Processed s1191490755.png -> ../zm_scraper/listing/gdino/output/4/s1191490755.png
# [4] Processed n1191764804.png -> ../zm_scraper/listing/gdino/output/4/n1191764804.png
# [4] Processed p1191543312.png -> ../zm_scraper/listing/gdino/output/4/p1191543312.png
# [4] Processed n1191445915.png -> ../zm_scraper/listing/gdino/output/4/n1191445915.png
# [4] Processed v1191370227.png -> ../zm_scraper/listing/gdino/output/4/v1191370227.png
# [4] Processed g1191659982.png -> ../zm_scraper/listing/gdino/output/4/g1191659982.png
# [4] Processed w1191421468.png -> ../zm_scraper/listing/gdino/output/4/w1191421468.png
# [4] Processed g1191575542.png -> ../zm_scraper/listing/gdino/output/4/g1191575542.png
# [4] Processed r1188469601.png -> ../zm_scraper/listing/gdino/output/4/r1188469601.png
# [4] Processed l1191357408.png -> ../zm_scraper/listing/gdino/output/4/l1191357408.png
# [4] Processed x1191763053.png -> ../zm_scraper/listing/gdino/output/4/x1191763053.png
# [4] Processed r1191697987.png -> ../zm_scraper/listing/gdino/output/4/r1191697987.png
# [4] Processed s1132109786.png -> ../zm_scraper/listing/gdino/output/4/s1132109786.png
# [4] Processed b1191564846.png -> ../zm_scraper/listing/gdino/output/4/b1191564846.png
# [4] Processed c1177551517.png -> ../zm_scraper/listing/gdino/output/4/c1177551517.png
# [4] Processed d1156091267.png -> ../zm_scraper/listing/gdino/output/4/d1156091267.png
# [4] Processed l1191561107.png -> ../zm_scraper/listing/gdino/output/4/l1191561107.png
# [4] Processed t1191813442.png -> ../zm_scraper/listing/gdino/output/4/t1191813442.png
# [4] Processed k1191483054.png -> ../zm_scraper/listing/gdino/output/4/k1191483054.png
# [4] Processed r1190773866.png -> ../zm_scraper/listing/gdino/output/4/r1190773866.png
# [4] Processed q1191564829.png -> ../zm_scraper/listing/gdino/output/4/q1191564829.png
# [4] Processed p1191688073.png -> ../zm_scraper/listing/gdino/output/4/p1191688073.png
# [4] Processed 1191736187.png -> ../zm_scraper/listing/gdino/output/4/1191736187.png
# [4] Processed c1191161357.png -> ../zm_scraper/listing/gdino/output/4/c1191161357.png
# [4] Processed d1191474450.png -> ../zm_scraper/listing/gdino/output/4/d1191474450.png
# [4] Processed j1191559623.png -> ../zm_scraper/listing/gdino/output/4/j1191559623.png
# [4] Processed c1189277412.png -> ../zm_scraper/listing/gdino/output/4/c1189277412.png
# [4] Processed 1126237052.png -> ../zm_scraper/listing/gdino/output/4/1126237052.png
# [4] Processed p1191768461.png -> ../zm_scraper/listing/gdino/output/4/p1191768461.png
# [4] Processed c1191622454.png -> ../zm_scraper/listing/gdino/output/4/c1191622454.png
# [4] Processed 1190767842.png -> ../zm_scraper/listing/gdino/output/4/1190767842.png
# [4] Processed p1191618639.png -> ../zm_scraper/listing/gdino/output/4/p1191618639.png
# [4] Processed u1191631296.png -> ../zm_scraper/listing/gdino/output/4/u1191631296.png
# [4] Processed r1191222266.png -> ../zm_scraper/listing/gdino/output/4/r1191222266.png
# [4] Processed n1191549926.png -> ../zm_scraper/listing/gdino/output/4/n1191549926.png
# [4] Processed h1191600287.png -> ../zm_scraper/listing/gdino/output/4/h1191600287.png
# [4] Processed p1191568309.png -> ../zm_scraper/listing/gdino/output/4/p1191568309.png
# [4] Processed v1190982790.png -> ../zm_scraper/listing/gdino/output/4/v1190982790.png
# [4] Processed f1191319101.png -> ../zm_scraper/listing/gdino/output/4/f1191319101.png
# [4] Processed k1191592318.png -> ../zm_scraper/listing/gdino/output/4/k1191592318.png
# [4] Processed j1187159118.png -> ../zm_scraper/listing/gdino/output/4/j1187159118.png
# [4] Processed x1191557690.png -> ../zm_scraper/listing/gdino/output/4/x1191557690.png
# [4] Processed s1191626724.png -> ../zm_scraper/listing/gdino/output/4/s1191626724.png
# [4] Processed l1155377477.png -> ../zm_scraper/listing/gdino/output/4/l1155377477.png
# [4] Processed b1191609816.png -> ../zm_scraper/listing/gdino/output/4/b1191609816.png
# [4] Processed b1191538330.png -> ../zm_scraper/listing/gdino/output/4/b1191538330.png
# [4] Processed r1191347605.png -> ../zm_scraper/listing/gdino/output/4/r1191347605.png
# [4] Processed g1191575293.png -> ../zm_scraper/listing/gdino/output/4/g1191575293.png
# [4] Processed c1191618326.png -> ../zm_scraper/listing/gdino/output/4/c1191618326.png
# [4] Processed p1191528595.png -> ../zm_scraper/listing/gdino/output/4/p1191528595.png
# [4] Processed u1191494794.png -> ../zm_scraper/listing/gdino/output/4/u1191494794.png
# [4] Processed s1190776915.png -> ../zm_scraper/listing/gdino/output/4/s1190776915.png
# [4] Processed t1191740982.png -> ../zm_scraper/listing/gdino/output/4/t1191740982.png
# [4] Processed m1191471534.png -> ../zm_scraper/listing/gdino/output/4/m1191471534.png
# [4] Processed c1191261295.png -> ../zm_scraper/listing/gdino/output/4/c1191261295.png
# [5] Processed n1125471554.png -> ../zm_scraper/listing/gdino/output/5/n1125471554.png
# [5] Processed w1191719574.png -> ../zm_scraper/listing/gdino/output/5/w1191719574.png
# [5] Processed c1182123800.png -> ../zm_scraper/listing/gdino/output/5/c1182123800.png
# [5] Processed b1187284300.png -> ../zm_scraper/listing/gdino/output/5/b1187284300.png
# [5] Processed l1103065526.png -> ../zm_scraper/listing/gdino/output/5/l1103065526.png
# [5] Processed j1077974654.png -> ../zm_scraper/listing/gdino/output/5/j1077974654.png
# [5] Processed u1172682421.png -> ../zm_scraper/listing/gdino/output/5/u1172682421.png
# [5] Processed g1183005819.png -> ../zm_scraper/listing/gdino/output/5/g1183005819.png
# [5] Processed u1172645589.png -> ../zm_scraper/listing/gdino/output/5/u1172645589.png
# [5] Processed d1191456481.png -> ../zm_scraper/listing/gdino/output/5/d1191456481.png
# [5] Processed r1191709797.png -> ../zm_scraper/listing/gdino/output/5/r1191709797.png
# [5] Processed b1184294295.png -> ../zm_scraper/listing/gdino/output/5/b1184294295.png
# [5] Processed v1169075564.png -> ../zm_scraper/listing/gdino/output/5/v1169075564.png
# [5] Processed q1188122927.png -> ../zm_scraper/listing/gdino/output/5/q1188122927.png
# [5] Processed m1174503522.png -> ../zm_scraper/listing/gdino/output/5/m1174503522.png
# [5] Processed w1191117368.png -> ../zm_scraper/listing/gdino/output/5/w1191117368.png
# [5] Processed x1067950974.png -> ../zm_scraper/listing/gdino/output/5/x1067950974.png
# [5] Processed u1179101726.png -> ../zm_scraper/listing/gdino/output/5/u1179101726.png
# [5] Processed v1127514145.png -> ../zm_scraper/listing/gdino/output/5/v1127514145.png
# [5] Processed s1191595304.png -> ../zm_scraper/listing/gdino/output/5/s1191595304.png
# [5] Processed x1191729061.png -> ../zm_scraper/listing/gdino/output/5/x1191729061.png
# [5] Processed f1181888895.png -> ../zm_scraper/listing/gdino/output/5/f1181888895.png
# [5] Processed q1191730331.png -> ../zm_scraper/listing/gdino/output/5/q1191730331.png
# [5] Processed s1191118930.png -> ../zm_scraper/listing/gdino/output/5/s1191118930.png
# [5] Processed f1170502361.png -> ../zm_scraper/listing/gdino/output/5/f1170502361.png
# [5] Processed r1191425093.png -> ../zm_scraper/listing/gdino/output/5/r1191425093.png
# [5] Processed d1191590884.png -> ../zm_scraper/listing/gdino/output/5/d1191590884.png
# [5] Processed n1191726452.png -> ../zm_scraper/listing/gdino/output/5/n1191726452.png
# [5] Processed l1191626006.png -> ../zm_scraper/listing/gdino/output/5/l1191626006.png
# [5] Processed v1173767938.png -> ../zm_scraper/listing/gdino/output/5/v1173767938.png
# [5] Processed 1172882303.png -> ../zm_scraper/listing/gdino/output/5/1172882303.png
# [5] Processed u1181871260.png -> ../zm_scraper/listing/gdino/output/5/u1181871260.png
# [5] Processed x1158490255.png -> ../zm_scraper/listing/gdino/output/5/x1158490255.png
# [5] Processed 1186266050.png -> ../zm_scraper/listing/gdino/output/5/1186266050.png
# [5] Processed e1164543705.png -> ../zm_scraper/listing/gdino/output/5/e1164543705.png
# [5] Processed s1191490904.png -> ../zm_scraper/listing/gdino/output/5/s1191490904.png
# [5] Processed r1189080330.png -> ../zm_scraper/listing/gdino/output/5/r1189080330.png
# [5] Processed e1191616048.png -> ../zm_scraper/listing/gdino/output/5/e1191616048.png
# [5] Processed m1177522631.png -> ../zm_scraper/listing/gdino/output/5/m1177522631.png
# [5] Processed j1172535657.png -> ../zm_scraper/listing/gdino/output/5/j1172535657.png
# [5] Processed s1185763843.png -> ../zm_scraper/listing/gdino/output/5/s1185763843.png
# [5] Processed t1174505316.png -> ../zm_scraper/listing/gdino/output/5/t1174505316.png
# [5] Processed k1166614719.png -> ../zm_scraper/listing/gdino/output/5/k1166614719.png
# [5] Processed o1188683650.png -> ../zm_scraper/listing/gdino/output/5/o1188683650.png
# [5] Processed u1180931211.png -> ../zm_scraper/listing/gdino/output/5/u1180931211.png
# [5] Processed g1191594946.png -> ../zm_scraper/listing/gdino/output/5/g1191594946.png
# [5] Processed p1190654030.png -> ../zm_scraper/listing/gdino/output/5/p1190654030.png
# [5] Processed p1112819217.png -> ../zm_scraper/listing/gdino/output/5/p1112819217.png
# [5] Processed v1187286511.png -> ../zm_scraper/listing/gdino/output/5/v1187286511.png
# [5] Processed q1186635587.png -> ../zm_scraper/listing/gdino/output/5/q1186635587.png
# [5] Processed q1191048983.png -> ../zm_scraper/listing/gdino/output/5/q1191048983.png
# [5] Processed n1166707764.png -> ../zm_scraper/listing/gdino/output/5/n1166707764.png
# [5] Processed o1159821854.png -> ../zm_scraper/listing/gdino/output/5/o1159821854.png
# [5] Processed n1191111346.png -> ../zm_scraper/listing/gdino/output/5/n1191111346.png
# [5] Processed c1187760302.png -> ../zm_scraper/listing/gdino/output/5/c1187760302.png
# [5] Processed f1191337222.png -> ../zm_scraper/listing/gdino/output/5/f1191337222.png
# [5] Processed p1191731871.png -> ../zm_scraper/listing/gdino/output/5/p1191731871.png
# [5] Processed j1168615692.png -> ../zm_scraper/listing/gdino/output/5/j1168615692.png
# [5] Processed f1191413722.png -> ../zm_scraper/listing/gdino/output/5/f1191413722.png
# [5] Processed d1189532281.png -> ../zm_scraper/listing/gdino/output/5/d1189532281.png
# [5] Processed j1144083760.png -> ../zm_scraper/listing/gdino/output/5/j1144083760.png
# [5] Processed e1191726073.png -> ../zm_scraper/listing/gdino/output/5/e1191726073.png
# [5] Processed j1150682003.png -> ../zm_scraper/listing/gdino/output/5/j1150682003.png
# [5] Processed u1191666133.png -> ../zm_scraper/listing/gdino/output/5/u1191666133.png
# [5] Processed c1114766069.png -> ../zm_scraper/listing/gdino/output/5/c1114766069.png
# [5] Processed f1191115352.png -> ../zm_scraper/listing/gdino/output/5/f1191115352.png
# [5] Processed f1174041028.png -> ../zm_scraper/listing/gdino/output/5/f1174041028.png
# [5] Processed e1178664397.png -> ../zm_scraper/listing/gdino/output/5/e1178664397.png
# [5] Processed p1187267693.png -> ../zm_scraper/listing/gdino/output/5/p1187267693.png
# [5] Processed e1187205501.png -> ../zm_scraper/listing/gdino/output/5/e1187205501.png
# [5] Processed j1191728283.png -> ../zm_scraper/listing/gdino/output/5/j1191728283.png
# [5] Processed m1191719765.png -> ../zm_scraper/listing/gdino/output/5/m1191719765.png
# [5] Processed u1127527151.png -> ../zm_scraper/listing/gdino/output/5/u1127527151.png
# [5] Processed n1181024942.png -> ../zm_scraper/listing/gdino/output/5/n1181024942.png
# [5] Processed b1191057471.png -> ../zm_scraper/listing/gdino/output/5/b1191057471.png
# [5] Processed p1190346016.png -> ../zm_scraper/listing/gdino/output/5/p1190346016.png
# [5] Processed u1185937530.png -> ../zm_scraper/listing/gdino/output/5/u1185937530.png
# [5] Processed k1191729356.png -> ../zm_scraper/listing/gdino/output/5/k1191729356.png
# [5] Processed c1191715044.png -> ../zm_scraper/listing/gdino/output/5/c1191715044.png
# [5] Processed x1155423960.png -> ../zm_scraper/listing/gdino/output/5/x1155423960.png
# [5] Processed n1182986513.png -> ../zm_scraper/listing/gdino/output/5/n1182986513.png
# [5] Processed m1191333843.png -> ../zm_scraper/listing/gdino/output/5/m1191333843.png
# [5] Processed j1188953489.png -> ../zm_scraper/listing/gdino/output/5/j1188953489.png
# [5] Processed s1172904714.png -> ../zm_scraper/listing/gdino/output/5/s1172904714.png
# [5] Processed p1191203493.png -> ../zm_scraper/listing/gdino/output/5/p1191203493.png
# [5] Processed v1191128847.png -> ../zm_scraper/listing/gdino/output/5/v1191128847.png
# [5] Processed x1162366438.png -> ../zm_scraper/listing/gdino/output/5/x1162366438.png
# [5] Processed c1191189969.png -> ../zm_scraper/listing/gdino/output/5/c1191189969.png
# [5] Processed m1185715194.png -> ../zm_scraper/listing/gdino/output/5/m1185715194.png
# [5] Processed k1125807070.png -> ../zm_scraper/listing/gdino/output/5/k1125807070.png
# [5] Processed m1182121273.png -> ../zm_scraper/listing/gdino/output/5/m1182121273.png
# [5] Processed m1082208095.png -> ../zm_scraper/listing/gdino/output/5/m1082208095.png
# [5] Processed c1137804383.png -> ../zm_scraper/listing/gdino/output/5/c1137804383.png
# [5] Processed w1190839799.png -> ../zm_scraper/listing/gdino/output/5/w1190839799.png
# [5] Processed v1191361604.png -> ../zm_scraper/listing/gdino/output/5/v1191361604.png
# [5] Processed g1186021921.png -> ../zm_scraper/listing/gdino/output/5/g1186021921.png
# [5] Processed r1191200372.png -> ../zm_scraper/listing/gdino/output/5/r1191200372.png
# [5] Processed j1191269127.png -> ../zm_scraper/listing/gdino/output/5/j1191269127.png
# [5] Processed u1190864920.png -> ../zm_scraper/listing/gdino/output/5/u1190864920.png
# [5] Processed v1191166415.png -> ../zm_scraper/listing/gdino/output/5/v1191166415.png
# [5] Processed r1031307592.png -> ../zm_scraper/listing/gdino/output/5/r1031307592.png
# [5] Processed k1191725213.png -> ../zm_scraper/listing/gdino/output/5/k1191725213.png
# [5] Processed m1165305941.png -> ../zm_scraper/listing/gdino/output/5/m1165305941.png
# [5] Processed q1191594770.png -> ../zm_scraper/listing/gdino/output/5/q1191594770.png
# [5] Processed o1168947584.png -> ../zm_scraper/listing/gdino/output/5/o1168947584.png
# [5] Processed c1147312897.png -> ../zm_scraper/listing/gdino/output/5/c1147312897.png
# [5] Processed u1191230044.png -> ../zm_scraper/listing/gdino/output/5/u1191230044.png
# [5] Processed l1191357408.png -> ../zm_scraper/listing/gdino/output/5/l1191357408.png
# [5] Processed f1191650941.png -> ../zm_scraper/listing/gdino/output/5/f1191650941.png
# [5] Processed m1165318477.png -> ../zm_scraper/listing/gdino/output/5/m1165318477.png
# [5] Processed g1190932074.png -> ../zm_scraper/listing/gdino/output/5/g1190932074.png
# [5] Processed r1191158160.png -> ../zm_scraper/listing/gdino/output/5/r1191158160.png
# [5] Processed p1191122154.png -> ../zm_scraper/listing/gdino/output/5/p1191122154.png
# [5] Processed p1176859258.png -> ../zm_scraper/listing/gdino/output/5/p1176859258.png
# [5] Processed f1191141782.png -> ../zm_scraper/listing/gdino/output/5/f1191141782.png
# [5] Processed s1132109786.png -> ../zm_scraper/listing/gdino/output/5/s1132109786.png
# [5] Processed n1171719181.png -> ../zm_scraper/listing/gdino/output/5/n1171719181.png
# [5] Processed t1190555286.png -> ../zm_scraper/listing/gdino/output/5/t1190555286.png
# [5] Processed q1127615847.png -> ../zm_scraper/listing/gdino/output/5/q1127615847.png
# [5] Processed t1184982672.png -> ../zm_scraper/listing/gdino/output/5/t1184982672.png
# [5] Processed o1191731498.png -> ../zm_scraper/listing/gdino/output/5/o1191731498.png
# [5] Processed l1174471422.png -> ../zm_scraper/listing/gdino/output/5/l1174471422.png
# [5] Processed q1179759602.png -> ../zm_scraper/listing/gdino/output/5/q1179759602.png
# [5] Processed r1139580186.png -> ../zm_scraper/listing/gdino/output/5/r1139580186.png
# [5] Processed m1191192880.png -> ../zm_scraper/listing/gdino/output/5/m1191192880.png
# [5] Processed v1183934027.png -> ../zm_scraper/listing/gdino/output/5/v1183934027.png
# [5] Processed c1137797775.png -> ../zm_scraper/listing/gdino/output/5/c1137797775.png
# [5] Processed t1139631929.png -> ../zm_scraper/listing/gdino/output/5/t1139631929.png
# [5] Processed j1191072167.png -> ../zm_scraper/listing/gdino/output/5/j1191072167.png
# [5] Processed n1191341403.png -> ../zm_scraper/listing/gdino/output/5/n1191341403.png
# [5] Processed l1183325556.png -> ../zm_scraper/listing/gdino/output/5/l1183325556.png
# [5] Processed 1173555456.png -> ../zm_scraper/listing/gdino/output/5/1173555456.png
# [5] Processed d1189096064.png -> ../zm_scraper/listing/gdino/output/5/d1189096064.png
# [5] Processed q1191731679.png -> ../zm_scraper/listing/gdino/output/5/q1191731679.png
# [5] Processed u1190922502.png -> ../zm_scraper/listing/gdino/output/5/u1190922502.png
# [5] Processed r1191029497.png -> ../zm_scraper/listing/gdino/output/5/r1191029497.png
# [5] Processed s1188945072.png -> ../zm_scraper/listing/gdino/output/5/s1188945072.png
# [5] Processed j1191729279.png -> ../zm_scraper/listing/gdino/output/5/j1191729279.png
# [5] Processed h1165331573.png -> ../zm_scraper/listing/gdino/output/5/h1165331573.png
# [5] Processed t1185372924.png -> ../zm_scraper/listing/gdino/output/5/t1185372924.png
# [5] Processed g1191190021.png -> ../zm_scraper/listing/gdino/output/5/g1191190021.png
# [5] Processed c1191161357.png -> ../zm_scraper/listing/gdino/output/5/c1191161357.png
# [5] Processed n1189086137.png -> ../zm_scraper/listing/gdino/output/5/n1189086137.png
# [5] Processed o1181826694.png -> ../zm_scraper/listing/gdino/output/5/o1181826694.png
# [5] Processed o1191160640.png -> ../zm_scraper/listing/gdino/output/5/o1191160640.png
# [5] Processed j1182001038.png -> ../zm_scraper/listing/gdino/output/5/j1182001038.png
# [5] Processed t1191378923.png -> ../zm_scraper/listing/gdino/output/5/t1191378923.png
# [5] Processed o1190668972.png -> ../zm_scraper/listing/gdino/output/5/o1190668972.png
# [5] Processed v1190924120.png -> ../zm_scraper/listing/gdino/output/5/v1190924120.png
# [5] Processed b1191601386.png -> ../zm_scraper/listing/gdino/output/5/b1191601386.png
# [5] Processed u1176269869.png -> ../zm_scraper/listing/gdino/output/5/u1176269869.png
# [5] Processed w1179740797.png -> ../zm_scraper/listing/gdino/output/5/w1179740797.png
# [5] Processed p1190601349.png -> ../zm_scraper/listing/gdino/output/5/p1190601349.png
# [5] Processed k1187495923.png -> ../zm_scraper/listing/gdino/output/5/k1187495923.png
# [5] Processed e1153671351.png -> ../zm_scraper/listing/gdino/output/5/e1153671351.png
# [5] Processed h1190573807.png -> ../zm_scraper/listing/gdino/output/5/h1190573807.png
# [5] Processed d1170656373.png -> ../zm_scraper/listing/gdino/output/5/d1170656373.png
# [5] Processed u1191631296.png -> ../zm_scraper/listing/gdino/output/5/u1191631296.png
# [5] Processed p1189882073.png -> ../zm_scraper/listing/gdino/output/5/p1189882073.png
# [5] Processed h1183887211.png -> ../zm_scraper/listing/gdino/output/5/h1183887211.png
# [5] Processed t1191234802.png -> ../zm_scraper/listing/gdino/output/5/t1191234802.png
# [5] Processed k1126414922.png -> ../zm_scraper/listing/gdino/output/5/k1126414922.png
# [5] Processed b1094751541.png -> ../zm_scraper/listing/gdino/output/5/b1094751541.png
# [5] Processed b1191737718.png -> ../zm_scraper/listing/gdino/output/5/b1191737718.png
# [5] Processed b1160855625.png -> ../zm_scraper/listing/gdino/output/5/b1160855625.png
# [5] Processed g1191629025.png -> ../zm_scraper/listing/gdino/output/5/g1191629025.png
# [5] Processed r1191422542.png -> ../zm_scraper/listing/gdino/output/5/r1191422542.png
# [5] Processed q1031915603.png -> ../zm_scraper/listing/gdino/output/5/q1031915603.png
# [5] Processed l1178403345.png -> ../zm_scraper/listing/gdino/output/5/l1178403345.png
# [5] Processed f1175804046.png -> ../zm_scraper/listing/gdino/output/5/f1175804046.png
# [5] Processed s1191121020.png -> ../zm_scraper/listing/gdino/output/5/s1191121020.png
# [5] Processed w1191580281.png -> ../zm_scraper/listing/gdino/output/5/w1191580281.png
# [5] Processed x1162587148.png -> ../zm_scraper/listing/gdino/output/5/x1162587148.png
# [5] Processed l1191182887.png -> ../zm_scraper/listing/gdino/output/5/l1191182887.png
# [5] Processed x1189139732.png -> ../zm_scraper/listing/gdino/output/5/x1189139732.png
# [5] Processed q1187816041.png -> ../zm_scraper/listing/gdino/output/5/q1187816041.png
# [5] Processed h1159731759.png -> ../zm_scraper/listing/gdino/output/5/h1159731759.png
# [5] Processed h1191720202.png -> ../zm_scraper/listing/gdino/output/5/h1191720202.png
# [5] Processed c1187808482.png -> ../zm_scraper/listing/gdino/output/5/c1187808482.png
# [5] Processed w1191185463.png -> ../zm_scraper/listing/gdino/output/5/w1191185463.png
# [5] Processed b1191431247.png -> ../zm_scraper/listing/gdino/output/5/b1191431247.png
# [5] Processed c1191652929.png -> ../zm_scraper/listing/gdino/output/5/c1191652929.png
# [5] Processed x1174503138.png -> ../zm_scraper/listing/gdino/output/5/x1174503138.png
# [5] Processed n1168197738.png -> ../zm_scraper/listing/gdino/output/5/n1168197738.png
# [5] Processed h1191165592.png -> ../zm_scraper/listing/gdino/output/5/h1191165592.png
# [5] Processed l1158492569.png -> ../zm_scraper/listing/gdino/output/5/l1158492569.png
# All images processed.

# %% [markdown]
# ## Visualize images

# %%
import matplotlib.pyplot as plt
import os
from math import ceil
import pandas as pd
import numpy as np


valid_image_ext = ['.jpg', '.jpeg', '.png']

def visualize_and_save_images_for_item(
    image_paths,
    output_display_path,
    item_id,
    part_idx,
    prompt="",
    box_thresh=0.0,
    text_thresh=0.0,
    num_cols=5
):
    num_images = len(image_paths)
    num_rows = int(ceil(float(num_images) / float(num_cols)))

    f, axarr = plt.subplots(num_rows, num_cols, figsize=(num_cols * 6, num_rows * 6))
    f.tight_layout(pad=3.0)

    # Ensure axarr is flattened list
    if num_rows == 1:
        axarr = [axarr]
    axarr = sum([list(r) if isinstance(r, (list, tuple, np.ndarray)) else [r] for r in axarr], [])

    for idx in range(num_rows * num_cols):
        ax = axarr[idx]
        ax.axis('off')

        if idx < num_images:
            img_path = image_paths[idx]
            img = plt.imread(img_path)

            overlay_text = (
                f"{os.path.basename(img_path)}\n"
                f"Prompt: '{prompt}'\n"
                f"Box Thresh: {box_thresh} | Text Thresh: {text_thresh}"
            )

            ax.imshow(img)
            ax.text(
                1.0,
                0.0,
                overlay_text,
                ha="right",
                va="bottom",
                fontsize=9,
                color="white",
                wrap=True,
                transform=ax.transAxes,
                bbox=dict(
                    facecolor="black",
                    alpha=0.5,
                    boxstyle="round,pad=0.3"
                ),
            )

    output_file = os.path.join(output_display_path, f"{item_id}_{part_idx}.png")
    plt.savefig(output_file)
    plt.close(f)
    print(f"[{item_id}] Saved visualization part {part_idx} to {output_file}")


# -------------------------------------------------------------
# Main function to iterate over all IDs in ITEMS_LIST
# -------------------------------------------------------------
def batch_visualize_items(
    items_list_csv,
    output_base_dir,
    output_display_dir,
    num_cols=5,
    box_thresh=0.0,
    text_thresh=0.0,
    max_images_per_grid=25
):
    os.makedirs(output_display_dir, exist_ok=True)

    df = pd.read_csv(items_list_csv, usecols=["id", "prompt"])
    ids_and_prompts = df[["id", "prompt"]].astype(str).values.tolist()

    for item_id, prompt in ids_and_prompts:
        input_folder = os.path.join(output_base_dir, item_id)
        if not os.path.exists(input_folder):
            print(f"[{item_id}] Folder {input_folder} does not exist. Skipping.")
            continue

        # Gather all images
        image_paths = [
            os.path.join(input_folder, image)
            for image in sorted(os.listdir(input_folder))
            if os.path.splitext(image)[1].lower() in valid_image_ext
        ]

        if not image_paths:
            print(f"[{item_id}] No images found in {input_folder}. Skipping.")
            continue

        # Split into batches of max_images_per_grid
        total_images = len(image_paths)
        parts = [
            image_paths[i:i + max_images_per_grid]
            for i in range(0, total_images, max_images_per_grid)
        ]

        for part_idx, part_image_paths in enumerate(parts, start=1):
            visualize_and_save_images_for_item(
                image_paths=part_image_paths,
                output_display_path=output_display_dir,
                item_id=item_id,
                part_idx=part_idx,
                prompt=prompt,
                box_thresh=box_thresh,
                text_thresh=text_thresh,
                num_cols=num_cols
            )

# -------------------------------------------------------------
# Example usage
# -------------------------------------------------------------

batch_visualize_items(
    items_list_csv=TEXT_PROMPT_CSV,
    output_base_dir=OUTPUT_DIR,
    output_display_dir=OUTPUT_DISPLAY_DIR,
    num_cols=5,
    box_thresh=BOX_THRESHOLD,
    text_thresh=TEXT_THRESHOLD,
    max_images_per_grid=25
)
# Out:
# [1] Saved visualization part 1 to ../zm_scraper/listing/gdino/output_display/1_1.png
# [1] Saved visualization part 2 to ../zm_scraper/listing/gdino/output_display/1_2.png
# [1] Saved visualization part 3 to ../zm_scraper/listing/gdino/output_display/1_3.png
# [1] Saved visualization part 4 to ../zm_scraper/listing/gdino/output_display/1_4.png
# [1] Saved visualization part 5 to ../zm_scraper/listing/gdino/output_display/1_5.png
# [1] Saved visualization part 6 to ../zm_scraper/listing/gdino/output_display/1_6.png
# [1] Saved visualization part 7 to ../zm_scraper/listing/gdino/output_display/1_7.png
# [1] Saved visualization part 8 to ../zm_scraper/listing/gdino/output_display/1_8.png
# [2] Saved visualization part 1 to ../zm_scraper/listing/gdino/output_display/2_1.png
# [2] Saved visualization part 2 to ../zm_scraper/listing/gdino/output_display/2_2.png
# [2] Saved visualization part 3 to ../zm_scraper/listing/gdino/output_display/2_3.png
# [2] Saved visualization part 4 to ../zm_scraper/listing/gdino/output_display/2_4.png
# [3] Saved visualization part 1 to ../zm_scraper/listing/gdino/output_display/3_1.png
# [3] Saved visualization part 2 to ../zm_scraper/listing/gdino/output_display/3_2.png
# [3] Saved visualization part 3 to ../zm_scraper/listing/gdino/output_display/3_3.png
# [3] Saved visualization part 4 to ../zm_scraper/listing/gdino/output_display/3_4.png
# [3] Saved visualization part 5 to ../zm_scraper/listing/gdino/output_display/3_5.png
# [4] Saved visualization part 1 to ../zm_scraper/listing/gdino/output_display/4_1.png
# [4] Saved visualization part 2 to ../zm_scraper/listing/gdino/output_display/4_2.png
# [4] Saved visualization part 3 to ../zm_scraper/listing/gdino/output_display/4_3.png
# [4] Saved visualization part 4 to ../zm_scraper/listing/gdino/output_display/4_4.png
# [4] Saved visualization part 5 to ../zm_scraper/listing/gdino/output_display/4_5.png
# [5] Saved visualization part 1 to ../zm_scraper/listing/gdino/output_display/5_1.png
# [5] Saved visualization part 2 to ../zm_scraper/listing/gdino/output_display/5_2.png
# [5] Saved visualization part 3 to ../zm_scraper/listing/gdino/output_display/5_3.png
# [5] Saved visualization part 4 to ../zm_scraper/listing/gdino/output_display/5_4.png
# [5] Saved visualization part 5 to ../zm_scraper/listing/gdino/output_display/5_5.png
# [5] Saved visualization part 6 to ../zm_scraper/listing/gdino/output_display/5_6.png
# [5] Saved visualization part 7 to ../zm_scraper/listing/gdino/output_display/5_7.png
# [5] Saved visualization part 8 to ../zm_scraper/listing/gdino/output_display/5_8.png
