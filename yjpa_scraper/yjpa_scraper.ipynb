# %% [markdown]
# ## Pull Firebase Items List

# %%
FIREBASE_CLIENT_EMAIL="firebase-adminsdk-xxx@xxxx"
FIREBASE_PRIVATE_KEY=""
FIREBASE_PROJECT_ID="strustore-dev"

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import csv

# Build service account info dictionary from your variables
service_account_info = {
    "type": "service_account",
    "project_id": FIREBASE_PROJECT_ID,
    "private_key_id": "",
    "private_key": FIREBASE_PRIVATE_KEY.replace('\\n', '\n'),
    "client_email": FIREBASE_CLIENT_EMAIL,
    "client_id": "",
    "auth_uri": "https://accounts.google.com/o/oauth2/auth",
    "token_uri": "https://oauth2.googleapis.com/token",
    "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
    "client_x509_cert_url": ""
}

# Initialize Firebase app only once
if not firebase_admin._apps:
    cred = credentials.Certificate(service_account_info)
    firebase_admin.initialize_app(cred)

# Firestore client
db = firestore.client()

# Reference the 'items' collection
items_ref = db.collection('items')
docs = items_ref.stream()

csv_file_path = 'items.csv'

# Open CSV in write mode (clears the file)
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['id', 'db_id', 'item'])  # Header: sequential id, Firestore id, item name

    names_written = set()
    counter = 1  # Sequential ID counter

    for doc in docs:
        data = doc.to_dict()
        name = data.get('name', '')
        deleted = data.get('deleted', '')
        doc_id = doc.id

        if name == "New Item":
            print(f"🟡 Skipping 'New Item': Document ID = {doc_id}")
            continue

        if name in names_written:
            print(f"🔴 Duplicate in this run '{name}': Document ID = {doc_id}")
            continue

        if not deleted:
            writer.writerow([counter, doc_id, name])
            names_written.add(name)
            counter += 1

print("✅ items.csv has been created (overwritten).")
# Out:
# 🟡 Skipping 'New Item': Document ID = 0cVfA7cKl81hJzeYJeom
# 🔴 Duplicate in this run 'Inazuma Eleven Strikers 2013 (Wii)': Document ID = 2Q4SfkYkCGo9DbkGLPL9
# 🟡 Skipping 'New Item': Document ID = 30ipZsRWdB2s7Ur9KHmm
# 🔴 Duplicate in this run 'DDR Pad (boxed)': Document ID = 56kNwe7QwO0UG5KnIPLN
# 🟡 Skipping 'New Item': Document ID = 6EVr8m5dMCqBbFTlawD8
# 🟡 Skipping 'New Item': Document ID = 8KumJVAauDHs7V6k7KeW
# 🔴 Duplicate in this run 'Dragon Quest V (PS2)': Document ID = 9GevT39JnBUbBRxSUTOm
# 🟡 Skipping 'New Item': Document ID = 9dhSQ1nh7z1Dawxgi4yi
# 🔴 Duplicate in this run 'NFC Reader': Document ID = BQFije9nEgpgAILS2kRj
# 🟡 Skipping 'New Item': Document ID = Ca1FLv7Odsjsg3AcNE0d
# 🟡 Skipping 'New Item': Document ID = DgaPN3SGa5G1v2ERokjb
# 🔴 Duplicate in this run 'Royds Stick': Document ID = FU4iq83itVNXL5iERr8F
# 🔴 Duplicate in this run 'DRM V0/2': Document ID = Gvh6hL230MY787xMr35q
# 🔴 Duplicate in this run 'GC Mem 59': Document ID = HYjGDe8fm7cetdJZb01V
# 🟡 Skipping 'New Item': Document ID = KOqVzaPnC3ChzIWactNJ
# 🔴 Duplicate in this run 'Pokémon Silver': Document ID = MYolCyLnUl0cNl5YNFiY
# 🔴 Duplicate in this run 'PS2 HDD': Document ID = NcmaLyFD86ODaqNp4tL1
# 🔴 Duplicate in this run 'DDR Pad': Document ID = Pnl1GrDQlveUOpbYxRiw
# 🔴 Duplicate in this run 'GC Mem 251': Document ID = RAKnvJ7dvaUJQi2t8bEp
# 🔴 Duplicate in this run 'Wii U Zelda': Document ID = RG23gQZ6lFrn16lIdcZU
# 🔴 Duplicate in this run 'Saturn Karaoke': Document ID = S2q6yjiDCaGw7MoBeP04
# 🟡 Skipping 'New Item': Document ID = Si2qGhtQcE4LsJMe8P43
# 🔴 Duplicate in this run 'GC Mem 251': Document ID = SuBqpVGHu7R4KEc41u6w
# 🟡 Skipping 'New Item': Document ID = TRW6KdVbo0PKqTyxx6NC
# 🟡 Skipping 'New Item': Document ID = UbeTWhFVvNt29w9V0XPt
# 🔴 Duplicate in this run 'GC Mem 251': Document ID = WNmtu7CFCRmKAvZVwDLI
# 🔴 Duplicate in this run 'DRM V1': Document ID = Ww5gPESUPbgQxJvX1wJI
# 🔴 Duplicate in this run 'N64 Mic': Document ID = XPChNFHcrmENzg9H3GXk
# 🔴 Duplicate in this run 'R.O.B. (boxed)': Document ID = XcXOOGDDKwj6v83PjHWv
# 🟡 Skipping 'New Item': Document ID = XqdHsT66NJYD6hrrl2XM
# 🔴 Duplicate in this run 'SNES Super Scope': Document ID = XyQAMAiKj3XZYj3a42kq
# 🔴 Duplicate in this run 'Xbox 360 Con': Document ID = YEDKufSjsuAktbmBKey6
# 🔴 Duplicate in this run 'Mario DDR Pad': Document ID = YN9Z5cJEIfJSsiDovjks
# 🔴 Duplicate in this run 'DS Original': Document ID = YNZxS0e2Sb6OjET8b2hF
# 🔴 Duplicate in this run 'VMU': Document ID = YQX0CqbqcFNLZS0FErYN
# 🟡 Skipping 'New Item': Document ID = a5hmkG0hajcxrYKJ4iz2
# 🔴 Duplicate in this run 'Wii Con': Document ID = b8qny0UINYF1xlhOixX3
# 🔴 Duplicate in this run 'PS4': Document ID = ciVyF1xNTAJbNPmAirT2
# 🔴 Duplicate in this run 'NFC Reader (boxed)': Document ID = cwKWplZkxTUUgPt22H23
# 🔴 Duplicate in this run 'Saturn Mem': Document ID = d1CQsD1aDvzEt4XCkvqv
# 🔴 Duplicate in this run 'Xbox 360 Power Cord': Document ID = dB0F2TDXk0r5ieeUtVjT
# 🔴 Duplicate in this run 'Saturn Mem (King of Fighters)': Document ID = dTvWzAiaedBqZmo950GE
# 🔴 Duplicate in this run 'GC Mem Knockoff 1019': Document ID = eVB4mhNLlXvRtB8tNPfI
# 🔴 Duplicate in this run 'PS4 VR Processor V1': Document ID = evLWoFLEPBkUMw3gZ6kF
# 🔴 Duplicate in this run 'DRM Twin Stick': Document ID = f65p6oVPEF9LsREuybz3
# 🔴 Duplicate in this run 'Wario World (GC)': Document ID = fpNi9BUy9YUZYpg04wFg
# 🔴 Duplicate in this run 'Hori Compact Joystick': Document ID = gE3O3181jDM7uzdUPL0C
# 🔴 Duplicate in this run 'DRM Mic': Document ID = gP78A1Gi9cAkZIy8bFH4
# 🔴 Duplicate in this run 'Pokémon Gold': Document ID = gUd0fJ9qJSF4p1x7Q3y6
# 🔴 Duplicate in this run 'Wii LAN Adapter': Document ID = gbl4kuNcEw3VPpSpoLoh
# 🔴 Duplicate in this run 'BustAMove Con (boxed)': Document ID = gu05UWNRnbCJqodQnXLy
# 🟡 Skipping 'New Item': Document ID = h31X1XO0HLNBXu85rj9J
# 🟡 Skipping 'New Item': Document ID = hmwy9V84aL5LqzJdqpQ8
# 🔴 Duplicate in this run 'N64 Rumble Pak': Document ID = iSEFx0RZ7TJncf8vHiy9
# 🔴 Duplicate in this run '256G SD Card': Document ID = jYotoGWyBLIbzsylEaZU
# 🔴 Duplicate in this run 'DS Lite Charger': Document ID = jqkZXrfe1CH6BdjKyOSu
# 🔴 Duplicate in this run 'Pokémon Red': Document ID = kbebsr2Uiw0vHqxwe5u8
# 🔴 Duplicate in this run 'GC Mem Knockoff 251': Document ID = kv3fSaFCLtBNEYp89CyJ
# 🔴 Duplicate in this run 'GDEMU SD Extender Kit': Document ID = kwwBExkJn7EuxHSAgyMS
# 🔴 Duplicate in this run 'Xbox 360': Document ID = l2bjty7GmccjrRmFq1lt
# 🔴 Duplicate in this run 'Hitachi Hisaturn': Document ID = l4Rlk7lthWkVqlpbYJvl
# 🟡 Skipping 'New Item': Document ID = lPPfsIoK4EDt4Bz6LpBT
# 🔴 Duplicate in this run 'PS2 LAN Adapter': Document ID = nTKBq7MsYmeCA4GfOvhR
# 🟡 Skipping 'New Item': Document ID = oFa1L6JDIkP8elOP9gZx
# 🔴 Duplicate in this run 'Saturn Con': Document ID = oozhREosfDUd53NCabhx
# 🔴 Duplicate in this run 'DRM Popn': Document ID = pADxAec6wgaKVfLwGDWm
# 🔴 Duplicate in this run 'Capcom CPS Fighter': Document ID = qV275GbKMmnf9Jxg8TeT
# 🔴 Duplicate in this run 'Blue N64 Con (boxed)': Document ID = qX0iwPRrd1YKSvBWH1xI
# 🔴 Duplicate in this run 'Xbox One': Document ID = s74T11i1hWSNvWmJKJrE
# 🟡 Skipping 'New Item': Document ID = sCVVbuFw0PPXPUWvsqWn
# 🟡 Skipping 'New Item': Document ID = sEupY6lwSOxR7TX9hrEZ
# 🔴 Duplicate in this run 'Wii American': Document ID = sUWosbZmyyWWQ7DJWPek
# 🔴 Duplicate in this run 'Beavis and Butthead (PS)': Document ID = sbv4Sp1M4wQsHXBdIa5N
# 🔴 Duplicate in this run 'N64 Transfer Pak': Document ID = tdO4wvApY4bCxqBsPTVL
# 🔴 Duplicate in this run 'Sega FS': Document ID = tiUuG0uVugmLdufVDLIB
# 🔴 Duplicate in this run 'N64 ASCII Fishing Reels': Document ID = tt7DvZVbg28Q2NeRUYQv
# 🔴 Duplicate in this run 'DRM Shell': Document ID = u0qs67ImmmrAU5rVwQny
# 🔴 Duplicate in this run 'FIFA Street (PS3)': Document ID = w0H3LQg5q1bMbLVTSydb
# 🔴 Duplicate in this run 'Pokémon Battle Revolution (Wii)': Document ID = wvcxLINprl1F7Hag3L1c
# 🔴 Duplicate in this run 'Hori FS SS': Document ID = x4Zdopfvj7E8EHZAFyLh
# 🔴 Duplicate in this run 'Command Stick FS': Document ID = xLJup6aHVkxsQIb3P6ZS
# 🔴 Duplicate in this run 'N64 Con Pak': Document ID = xODlyzmGtSLy5b2V1JmX
# 🔴 Duplicate in this run 'Pokémon Yellow': Document ID = xZz3wgRpgNiNmKguiBK4
# 🔴 Duplicate in this run 'N64 Con': Document ID = yOXZHleWBYSl0tuh0qLy
# 🔴 Duplicate in this run 'DRM Fishing Reel': Document ID = z11WBsv69uTNglzT1CxV
# 🟡 Skipping 'New Item': Document ID = ztvaxtLIrk4rzs52nPiq
# 🔴 Duplicate in this run 'Gameboy Printer': Document ID = zxTXJHJ8IS4oSoFJQ1Gh
# ✅ items.csv has been created (overwritten).

# %% [markdown]
# ## Create Item Urls

# %%
ITEMS_LIST = "items-select.csv"
ITEMS_URL = "items-url.csv"
ITEMS_LISTING_MENU = "./items_listing_menu/"
ITEMS_LISTING_JSON = "./items_listing/json"
ITEMS_LISTING_IMG = "./items_listing/raw"
SCRAPE_LISTING_LIMIT = 50

# %%
import pandas as pd

items_file = ITEMS_LIST
url_file = ITEMS_URL


df = pd.read_csv(items_file, usecols=['id', 'search_jp', 'auccat_id', 'min_price_yen'])

with open(url_file, "w", encoding="utf-8") as f:
    # File Header
    f.write("id,url\n")
    for index, row in df.iterrows():
        min_price_yen = row['min_price_yen']
        min_price_yen = int(min_price_yen) if min_price_yen else 0
        search_jp = str(row['search_jp']).strip()
        auccat_id = int(row['auccat_id'])
        item_id = row['id']

        url = (
            f"https://auctions.yahoo.co.jp/search/search?"
            f"min={min_price_yen}&max=&va={search_jp}&n=50&mode=1&auccat={auccat_id}&fixed=2"
        )

        print(url)  # optional: show on console

        # ✅ Save each line as: id, url
        f.write(f"{item_id},{url}\n")
# Out:
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=コントローラ&n=50&mode=1&auccat=22850&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=22850&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=22860&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=2084237619&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=2084290226&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=つりコン64&n=50&mode=1&auccat=22850&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=メモリーカード&n=50&mode=1&auccat=22860&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=10000&max=&va=コントローラ&n=50&mode=1&auccat=2084045784&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=0&max=&va=クラシックコントローラーPRO&n=50&mode=1&auccat=2084217064&fixed=2
# https://auctions.yahoo.co.jp/search/search?min=3000&max=&va=リモコン&n=50&mode=1&auccat=2084217064&fixed=2

# %% [markdown]
# ## Scrapy: Retrieve up to 50 listings from each url (5sec delay)

# %%
import csv
import requests
import time
import os

# Path to your global vals
items_file = ITEMS_URL
items_listing_menu = ITEMS_LISTING_MENU

# Ensure the folder exists
os.makedirs(items_listing_menu, exist_ok=True)

with open(items_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        item_id = row['id']
        url = row['url']

        print(f"Fetching {url}")
        
        # Making the Request
        try:
            response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"Request failed for {url}: {e}")
            continue

        # Save the HTML
        filename = os.path.join(items_listing_menu, f"{item_id}.html")
        with open(filename, "w", encoding="utf-8") as f:
            f.write(response.text)

        print(f"Saved response to {filename}")

        # Wait 5 seconds before next requst
        time.sleep(5)
        
print("All listing menus retrieved!")
# Out:
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=コントローラ&n=50&mode=1&auccat=22850&fixed=2
# Saved response to ./items_listing_menu/108.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=22850&fixed=2
# Saved response to ./items_listing_menu/37.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=22860&fixed=2
# Saved response to ./items_listing_menu/199.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=2084237619&fixed=2
# Saved response to ./items_listing_menu/193.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=本体&n=50&mode=1&auccat=2084290226&fixed=2
# Saved response to ./items_listing_menu/244.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=つりコン64&n=50&mode=1&auccat=22850&fixed=2
# Saved response to ./items_listing_menu/100.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=メモリーカード&n=50&mode=1&auccat=22860&fixed=2
# Saved response to ./items_listing_menu/210.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=10000&max=&va=コントローラ&n=50&mode=1&auccat=2084045784&fixed=2
# Saved response to ./items_listing_menu/154.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=0&max=&va=クラシックコントローラーPRO&n=50&mode=1&auccat=2084217064&fixed=2
# Saved response to ./items_listing_menu/95.html
# Fetching https://auctions.yahoo.co.jp/search/search?min=3000&max=&va=リモコン&n=50&mode=1&auccat=2084217064&fixed=2
# Saved response to ./items_listing_menu/99.html

# %% [markdown]
# ## Read HTML and gather data from listings

# %%
import time

# Record the start time
start_time = time.time()

# %%
import os
import csv
import json
import time
from bs4 import BeautifulSoup
from googletrans import Translator


# Inputs
items_file = ITEMS_URL
items_listing_menu = ITEMS_LISTING_MENU
items_listing_json = ITEMS_LISTING_JSON
items_listing_img = ITEMS_LISTING_IMG
scrape_listing_limit = 50

# Ensure output folder exists
os.makedirs(items_listing_json, exist_ok=True)
os.makedirs(items_listing_img, exist_ok=True)

# Read your CSV to get IDs (and to confirm which IDs you expect)
ids = []
with open(items_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        ids.append(row['id'])

translator = Translator()

# For each id, parse HTML
for item_id in ids:
    html_path = os.path.join(items_listing_menu, f"{item_id}.html")
    if not os.path.exists(html_path):
        print(f"HTML file missing for {item_id}, skipping...")
        continue

    with open(html_path, encoding="utf-8") as f:
        html = f.read()

    soup = BeautifulSoup(html, "html.parser")
    divs = soup.find_all("div", class_="Product__image")
    divs = divs[:scrape_listing_limit]

    listings = []
    for div in divs:
        # Instead of div.get(), get the <a> with the data I need
        a_tag = div.find("a")
        if not a_tag:
            print("No <a> tag found inside div, skipping this listing.")
            continue
        
        # Parse image url to a high res version  
        raw_img = a_tag.get("data-auction-img", "").strip()
        clean_img = raw_img.split("?", 1)[0] if raw_img else ""
        # Translate title JP > EN
        auction_title_jp = a_tag.get("data-auction-title", "").strip()
        auction_title_en = ""
        if auction_title_jp:
            try:
                translated = translator.translate(auction_title_jp, src="ja", dest="en")
                auction_title_en = translated.text
            except Exception as e:
                print(f"Translation error: {e}")
                auction_title_en = ""
        
        listings.append({
            "auction_id": a_tag.get("data-auction-id", "").strip(),
            "auction_category": a_tag.get("data-auction-category", "").strip(),
            "auction_title": auction_title_jp,
            "auction_title_en": auction_title_en,
            "auction_img": clean_img,
            "auction_price": a_tag.get("data-auction-price", "").strip(),
            "auction_isflea": a_tag.get("data-auction-isflea", "").strip(),
            "auction_isfreeshipping": a_tag.get("data-auction-isfreeshipping", "").strip()
        })

    # Save to JSON file named {id}.json
    output_path = os.path.join(items_listing_json, f"{item_id}.json")
    with open(output_path, "w", encoding="utf-8") as out_f:
        json.dump(listings, out_f, ensure_ascii=False, indent=2)

    print(f"Saved {len(listings)} listings to {output_path}")
    
    # Download images from each json
    item_img_folder = os.path.join(items_listing_img, item_id)
    os.makedirs(item_img_folder, exist_ok=True)
    for listing in listings:
        img_url = listing["auction_img"]
        auction_id = listing["auction_id"]
        if not img_url or not auction_id:
            print(f"Skipping image download for empty img or id in listing.")
            continue

        img_filename = os.path.join(item_img_folder, f"{auction_id}.jpg")

        try:
            response = requests.get(img_url, timeout=10)
            response.raise_for_status()
            with open(img_filename, "wb") as img_file:
                img_file.write(response.content)
            #print(f"Downloaded image for auction {auction_id}")
            # 1 second delay each image
            time.sleep(1)
        except Exception as e:
            print(f"Error downloading image for {auction_id}: {e}")
    print(f"Downloaded images for item {item_id}")
# Out:
# Saved 50 listings to ./items_listing/json/108.json
# Downloaded image for auction n1190546392
# Downloaded image for auction k1190812682
# Downloaded image for auction u1190796085
# Downloaded image for auction c1190908462
# Downloaded image for auction n1190546392
# Downloaded image for auction q1190614814
# Downloaded image for auction j1190197725
# Downloaded image for auction g1190619600
# Downloaded image for auction e1190775844
# Downloaded image for auction g1190939719
# Downloaded image for auction w1190910649
# Downloaded image for auction v1190912743
# Downloaded image for auction n1190792262
# Downloaded image for auction f1190128894
# Downloaded image for auction r1190642791
# Downloaded image for auction q1190444247
# Downloaded image for auction k1190812682
# Downloaded image for auction c1190415151
# Downloaded image for auction g1190789755
# Downloaded image for auction j1190792838
# Downloaded image for auction u1159528119
# Downloaded image for auction c1190182495
# Downloaded image for auction f1190436459
# Downloaded image for auction s1190628245
# Downloaded image for auction j1191033788
# Downloaded image for auction x1190626531
# Downloaded image for auction c1190122848
# Downloaded image for auction h1190635331
# Downloaded image for auction p1190564677
# Downloaded image for auction r1190979441
# Downloaded image for auction f1190169202
# Downloaded image for auction j1190569707
# Downloaded image for auction l1190987916
# Downloaded image for auction l1190792038
# Downloaded image for auction x1190928070
# Downloaded image for auction p1190578008
# Downloaded image for auction j1190641560
# Downloaded image for auction b1190137335
# Downloaded image for auction 1190622460
# Downloaded image for auction c1190432138
# Downloaded image for auction n1190552473
# Downloaded image for auction d1190418090
# Downloaded image for auction n1189328860
# Downloaded image for auction p1190562299
# Downloaded image for auction b1190830546
# Downloaded image for auction m1190773917
# Downloaded image for auction n1190928453
# Downloaded image for auction u1190943438
# Downloaded image for auction n1190437880
# Downloaded image for auction w1190276028
# Saved 50 listings to ./items_listing/json/37.json
# Downloaded image for auction n1190546392
# Downloaded image for auction e1187921901
# Downloaded image for auction 1172204044
# Downloaded image for auction c1190211387
# Downloaded image for auction q1190614814
# Downloaded image for auction j1190197725
# Downloaded image for auction g1190619600
# Downloaded image for auction s1190387078
# Downloaded image for auction l1190307385
# Downloaded image for auction o1190073608
# Downloaded image for auction s1190811085
# Downloaded image for auction g1190641979
# Downloaded image for auction d1190639352
# Downloaded image for auction q1190310785
# Downloaded image for auction o1190781268
# Downloaded image for auction 1190302665
# Downloaded image for auction v1190315281
# Downloaded image for auction n1190248890
# Downloaded image for auction r1190941532
# Downloaded image for auction s1190969609
# Downloaded image for auction h1190627830
# Downloaded image for auction x1190936585
# Saved 28 listings to ./items_listing/json/95.json
# Downloaded image for auction q1189825933
# Downloaded image for auction b1190689980
# Downloaded image for auction e1190678569
# Downloaded image for auction j1190682486
# Downloaded image for auction o1188554997
# Downloaded image for auction s1185738346
# Downloaded image for auction f1188549763
# Downloaded image for auction k1190623034
# Downloaded image for auction v1181909841
# Downloaded image for auction n1146528596
# Downloaded image for auction r1190095897
# Downloaded image for auction c1189810750
# Downloaded image for auction d1183178821
# Downloaded image for auction c1184537851
# Downloaded image for auction j1186730495
# Downloaded image for auction r1181649798
# Downloaded image for auction f1146543252
# Downloaded image for auction h1155594633
# Downloaded image for auction 1124390175
# Downloaded image for auction v1180451899
# Downloaded image for auction d1180454519
# Downloaded image for auction x1082240593
# Downloaded image for auction c1011367971
# Downloaded image for auction c1146760557
# Downloaded image for auction t1187489390
# Downloaded image for auction q1188046556
# Downloaded image for auction w1186988353
# Downloaded image for auction e1184410303
# Saved 50 listings to ./items_listing/json/99.json
# Downloaded image for auction c1191013907
# Downloaded image for auction p1190300770
# Downloaded image for auction x1190296126
# Downloaded image for auction m1190655515
# Downloaded image for auction l1190794975
# Downloaded image for auction p1190720187
# Downloaded image for auction r1190670621
# Downloaded image for auction o1190668498
# Downloaded image for auction d1190778503
# Downloaded image for auction w1190345464
# Downloaded image for auction g1190474054
# Downloaded image for auction e1190615219
# Downloaded image for auction c1191013907
# Downloaded image for auction g1188239267
# Downloaded image for auction p1190291360
# Downloaded image for auction u1190174062
# Downloaded image for auction v1190496587
# Downloaded image for auction c1190676782
# Downloaded image for auction n1190208234
# Downloaded image for auction u1190380306
# Downloaded image for auction h1190646455
# Downloaded image for auction g1187345046
# Downloaded image for auction h1190789783
# Downloaded image for auction c1190311213
# Downloaded image for auction n1189269829
# Downloaded image for auction d1183182842
# Downloaded image for auction m1190672838
# Downloaded image for auction d1190132477
# Downloaded image for auction o1190759904
# Downloaded image for auction p1190907251
# Downloaded image for auction j1190640261
# Downloaded image for auction c1190766860
# Downloaded image for auction n1190922361
# Downloaded image for auction x1190362463
# Downloaded image for auction w1190306026
# Downloaded image for auction v1191024392
# Downloaded image for auction k1190765018
# Downloaded image for auction 1190891439
# Downloaded image for auction c1190387359
# Downloaded image for auction n1190157648
# Downloaded image for auction d1190105584
# Downloaded image for auction b1190454059
# Downloaded image for auction w1190914591
# Downloaded image for auction j1190746350
# Downloaded image for auction u1191043431
# Downloaded image for auction c1189242629
# Downloaded image for auction c1190280735
# Downloaded image for auction k1186363476
# Downloaded image for auction o1190372213
# Downloaded image for auction q1190809793

# %%
# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.4f} seconds")
# Out:
# Elapsed time: 874.7346 seconds
