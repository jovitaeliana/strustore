# %%
FIREBASE_CRED_PATH = "../misc/strustore-dev-firebase-adminsdk-emic5-85ed2690d9.json"

MODEL="gdino" #sam/gdino/manual
ANNOTATION_SPLIT = "../Open-GroundingDino/annotations/dataset_split.json"
LENS = f"../zm_scraper/auctions/{MODEL}/lens/"
MANUAL_POSTPROCESSED_LBL = "../Open-GroundingDino/annotations/test_coco.json" #manual
GDINO_POSTPROCESSED_LBL = "../zm_scraper/auctions/gdino/output_labels" #gdino 
SAM_POSTPROCESSED_LBL = "../zm_scraper/auctions/sam/postprocessed/labels" #sam

RAW = "../zm_scraper/auctions/raw"
PREPROCESSED = "../zm_scraper/auctions/preprocessed"
BUCKET_NAME = "strustore-dev.firebasestorage.app"
TEXT_PROMPT_CSV = "../zm_scraper/items-prompt.csv"

OVERWRITE_RESULTS=False

# %% [markdown]
# ## SAM : Extract Masks from .npy files and save them into firestore

# %%
# obtain masks and their public urls
import os
import numpy as np
import cv2
import pandas as pd
import json
import firebase_admin
from firebase_admin import credentials, storage

os.makedirs(LENS, exist_ok=True)

# Initialize Firebase only if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate(FIREBASE_CRED_PATH)
    firebase_admin.initialize_app(cred, {
        'storageBucket': BUCKET_NAME
    })
bucket = storage.bucket()

# ────────────── Load Dataset Split ──────────────
with open(ANNOTATION_SPLIT, "r") as f:
    split_data = json.load(f)

test_split = split_data.get("test", {})

# ────────────── FUNCTIONS ──────────────
def upload_image_to_firebase(image_array, remote_name):
    """Uploads an image (NumPy array) as PNG to Firebase without saving locally."""
    success, encoded_image = cv2.imencode('.png', image_array)
    if not success:
        raise ValueError("Failed to encode image to PNG.")

    blob = bucket.blob(remote_name)
    blob.upload_from_string(encoded_image.tobytes(), content_type='image/png')
    blob.make_public()  # Make file publicly accessible
    return blob.public_url

def extract_and_upload_masks(image_path, label_path, item_id, auction_id):
    """Extract masks and original image crops, upload to Firebase."""
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"[ERROR] Image not found: {image_path}")
        return {}

    if image.shape[2] == 4:  # Drop alpha if present
        image = image[:, :, :3]

    label_map = np.load(label_path)
    region_ids = np.unique(label_map)
    region_ids = region_ids[region_ids > 0]  # Exclude background

    mask_data = {}

    for region_id in region_ids:
        mask = (label_map == region_id).astype(np.uint8)
        ys, xs = np.where(mask == 1)
        if ys.size == 0 or xs.size == 0:
            continue

        # Compute bounding box
        y_min, y_max = int(ys.min()), int(ys.max())
        x_min, x_max = int(xs.min()), int(xs.max())

        # Expand by 5%
        height, width = image.shape[:2]
        delta_x = int((x_max - x_min) * 0.05)
        delta_y = int((y_max - y_min) * 0.05)

        x_min = max(0, x_min - delta_x)
        y_min = max(0, y_min - delta_y)
        x_max = min(width - 1, x_max + delta_x)
        y_max = min(height - 1, y_max + delta_y)

        # Crop original image using expanded bounding box
        original_crop = image[y_min:y_max+1, x_min:x_max+1]

        # Convert original crop to PNG and upload
        firebase_crop_name = f"{MODEL}/{item_id}/{auction_id}/mask_{region_id}.png"
        url = upload_image_to_firebase(original_crop, firebase_crop_name)


        # Save both URLs in JSON
        mask_data[str(region_id)] = {
            "url": url,
            "bbox": [x_min, y_min, x_max, y_max],
            "results": [],
            "tokens": []
        }

    return mask_data


def process_items():
    df = pd.read_csv(TEXT_PROMPT_CSV)
    item_ids = df['id'].astype(str).tolist()

    for item in item_ids:
        if item not in test_split:
            print(f"[SKIP] Item {item} not in test split.")
            continue

        allowed_files = test_split[item]  # e.g., ["auction1.jpg", "auction2.jpg"]
        allowed_ids = set([os.path.splitext(fname)[0] for fname in allowed_files])

        print(f"\nProcessing Item: {item} (Allowed auctions: {len(allowed_ids)})")
        label_dir = os.path.join(SAM_POSTPROCESSED_LBL, item)
        img_dir = os.path.join(PREPROCESSED, item)

        if not os.path.exists(label_dir):
            print(f"[WARNING] Label directory missing: {label_dir}")
            continue
        if not os.path.exists(img_dir):
            print(f"[WARNING] Image directory missing: {img_dir}")
            continue

        for npy_file in os.listdir(label_dir):
            if not npy_file.endswith(".npy"):
                continue

            auction_id = npy_file.replace(".npy", "")
            if auction_id not in allowed_ids:
                continue  # Skip auctions not in allowed list

            label_path = os.path.join(label_dir, npy_file)
            image_path = os.path.join(img_dir, f"{auction_id}.png")

            if not os.path.exists(image_path):
                print(f"[WARNING] Missing original image for auction {auction_id}")
                continue

            # Extract, upload, and build JSON
            auction_mask_data = extract_and_upload_masks(image_path, label_path, item, auction_id)

            # Save JSON for this auction
            auction_output_dir = os.path.join(LENS, item)
            os.makedirs(auction_output_dir, exist_ok=True)
            json_path = os.path.join(auction_output_dir, f"{auction_id}.json")

            with open(json_path, "w") as f:
                json.dump(auction_mask_data, f, indent=4)

            print(f"[DONE] JSON saved: {json_path}")

if __name__ == "__main__":
    process_items()
    print("\n✅ Filtered auctions processed and uploaded to Firebase!")

# %% [markdown]
# ## GDino: Extract Masks and save them in Firestore

# %%
# obtain masks and their public urls (now reading bboxes from .npz)
import os
import numpy as np
import cv2
import pandas as pd
import json
import firebase_admin
import math
from firebase_admin import credentials, storage

os.makedirs(LENS, exist_ok=True)

# Initialize Firebase only if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate(FIREBASE_CRED_PATH)
    firebase_admin.initialize_app(cred, {
        'storageBucket': BUCKET_NAME
    })
bucket = storage.bucket()

# ────────────── Load Dataset Split ──────────────
with open(ANNOTATION_SPLIT, "r") as f:
    split_data = json.load(f)

test_split = split_data.get("test", {})

# ────────────── HELPERS ──────────────
def clamp_bbox_xyxy_exclusive(x1, y1, x2, y2, width, height):
    """
    Clamp (x1,y1,x2,y2) where x2,y2 are end-exclusive.
    Ensures 0 <= x1 < x2 <= width and 0 <= y1 < y2 <= height.
    """
    x1 = max(0, min(int(x1), max(0, width - 1)))
    y1 = max(0, min(int(y1), max(0, height - 1)))
    x2 = max(x1 + 1, min(int(x2), width))
    y2 = max(y1 + 1, min(int(y2), height))
    return x1, y1, x2, y2


def load_bboxes_from_coco_json(coco_path, image_shape, expected_filename=None):
    with open(coco_path, "r") as f:
        coco = json.load(f)

    height, width = image_shape[:2]
    images = coco.get("images", [])
    anns = coco.get("annotations", [])

    image_id = None
    if expected_filename:
        for img in images:
            if img.get("file_name") == expected_filename or \
               os.path.splitext(img.get("file_name", ""))[0] == os.path.splitext(expected_filename)[0]:
                image_id = img.get("id")
                break
    if image_id is None and images:
        image_id = images[0].get("id")
    if image_id is None:
        return []

    results = []
    for ann in anns:
        if ann.get("image_id") != image_id:
            continue
        bbox = ann.get("bbox")
        if not bbox or len(bbox) != 4:
            continue

        x, y, w, h = map(float, bbox)
        # Convert to xyxy end-exclusive
        x1 = math.floor(x)
        y1 = math.floor(y)
        x2 = math.ceil(x + w)
        y2 = math.ceil(y + h)

        # 🔹 Expand bbox by 5% of its size
        expand_w = 0.05 * w
        expand_h = 0.05 * h
        x1 -= expand_w / 2
        y1 -= expand_h / 2
        x2 += expand_w / 2
        y2 += expand_h / 2

        # Clamp to image boundaries
        x1, y1, x2, y2 = clamp_bbox_xyxy_exclusive(x1, y1, x2, y2, width, height)

        region_id = str(ann.get("id", len(results) + 1))
        results.append((region_id, (x1, y1, x2, y2)))

    return results


# ────────────── FUNCTIONS ──────────────
def upload_image_to_firebase(image_array, remote_name):
    """Uploads an image (NumPy array) as PNG to Firebase without saving locally."""
    success, encoded_image = cv2.imencode('.png', image_array)
    if not success:
        raise ValueError("Failed to encode image to PNG.")

    blob = bucket.blob(remote_name)
    blob.upload_from_string(encoded_image.tobytes(), content_type='image/png')
    blob.make_public()  # Make file publicly accessible
    return blob.public_url

def extract_and_upload_crops_from_coco(image_path, coco_json_path, item_id, auction_id):
    """Read COCO JSON bboxes, crop from image, upload to Firebase, and return JSON dict."""
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"[ERROR] Image not found: {image_path}")
        return {}

    if image.ndim == 3 and image.shape[2] == 4:  # Drop alpha if present
        image = image[:, :, :3]

    # Expected filename to match within the COCO "images" array
    expected_filename = os.path.basename(image_path)

    id_bbox_list = load_bboxes_from_coco_json(coco_json_path, image.shape, expected_filename=expected_filename)

    mask_data = {}
    for region_id, (x1, y1, x2, y2) in id_bbox_list:
        # end-exclusive slicing
        crop = image[y1:y2, x1:x2]
        if crop.size == 0:
            continue

        # Upload crop
        firebase_crop_name = f"{MODEL}/{item_id}/{auction_id}/mask_{region_id}.png"
        url = upload_image_to_firebase(crop, firebase_crop_name)

        mask_data[str(region_id)] = {
            "url": url,
            "bbox": [int(x1), int(y1), int(x2), int(y2)],
            "results": [],
            "tokens": []
        }

    return mask_data


def process_items():
    df = pd.read_csv(TEXT_PROMPT_CSV)
    item_ids = df['id'].astype(str).tolist()

    for item in item_ids:
        if item not in test_split:
            print(f"[SKIP] Item {item} not in test split.")
            continue

        allowed_files = test_split[item]  # e.g., ["auction1.jpg", "auction2.png"]
        allowed_ids = set(os.path.splitext(fname)[0] for fname in allowed_files)

        print(f"\nProcessing Item: {item} (Allowed auctions: {len(allowed_ids)})")
        label_dir = os.path.join(GDINO_POSTPROCESSED_LBL, item)
        img_dir = os.path.join(PREPROCESSED, item)

        if not os.path.exists(label_dir):
            print(f"[WARNING] Label directory missing: {label_dir}")
            continue
        if not os.path.exists(img_dir):
            print(f"[WARNING] Image directory missing: {img_dir}")
            continue

        for label_file in os.listdir(label_dir):
            if not label_file.endswith(".json"):
                continue

            auction_id = os.path.splitext(label_file)[0]
            if auction_id not in allowed_ids:
                continue  # Skip auctions not in allowed list

            coco_json_path = os.path.join(label_dir, label_file)

            # Find matching image (try common extensions)
            image_path = None
            for ext in [".png", ".jpg", ".jpeg", ".JPG", ".PNG", ".JPEG"]:
                candidate = os.path.join(img_dir, f"{auction_id}{ext}")
                if os.path.exists(candidate):
                    image_path = candidate
                    break

            if image_path is None:
                print(f"[WARNING] Missing original image for auction {auction_id}")
                continue

            # Read COCO, crop, upload, and build JSON
            auction_mask_data = extract_and_upload_crops_from_coco(
                image_path=image_path,
                coco_json_path=coco_json_path,
                item_id=item,
                auction_id=auction_id
            )

            # Save JSON for this auction
            auction_output_dir = os.path.join(LENS, item)
            os.makedirs(auction_output_dir, exist_ok=True)
            json_path = os.path.join(auction_output_dir, f"{auction_id}.json")

            with open(json_path, "w") as f:
                json.dump(auction_mask_data, f, indent=4)

            print(f"[DONE] JSON saved: {json_path}")


if __name__ == "__main__":
    process_items()
    print("\n✅ Filtered auctions processed and uploaded to Firebase!")
# Out:
# Processing Item: 1 (Allowed auctions: 60)
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/w1190871465.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/q1177627244.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/t1144496280.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/x1121603563.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/l1180181252.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/r1140105858.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/n1181963058.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/w1191415731.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/l1190559645.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/c1174455551.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/c1186222082.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/1190947766.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/q1185787171.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/q1187025650.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/k1190557636.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/x1191598905.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/q1183324759.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/n1184979547.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/1188971238.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/f1191458213.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/n1191681464.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/q1191599905.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/c1191011512.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/1183014126.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/x1191726070.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/g1187312653.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/s1119897266.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/c1191323690.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/p1187246330.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/b1191454294.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/k1191474797.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/f1182381846.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/g1186111364.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/x1190805798.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/m1133776499.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/x1144497640.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/r1172860507.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/s1175248638.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/b1187681880.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/o1191069257.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/x1191588773.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/p1127453774.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/v1191007699.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/l1185983984.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/j1191431672.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/s1158964294.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/f1152247645.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/w1190845066.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/l1190830129.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/h1191357858.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/s1191791966.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/1187040966.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/o1119853616.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/d1191065516.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/o1187637806.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/k1190934472.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/r1188366109.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/v1187261662.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/d1187227651.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/1/v1157073564.json
#
# Processing Item: 2 (Allowed auctions: 24)
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/m1191712171.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/x1185026795.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/x1171181348.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/l1171615527.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/h1055489564.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/c583016002.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/u1159547663.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/p1101871478.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/f1109446657.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/v1168878467.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/l1189425708.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/j1188223998.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/e1191332130.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/b1174068183.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/k1184414767.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/c1187483831.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/m1175679082.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/1191044626.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/j1191314319.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/t1190192579.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/v1180804864.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/n1190944641.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/v1187327043.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/2/c1132411431.json
#
# Processing Item: 3 (Allowed auctions: 36)
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/h1190298916.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/n1173190176.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/v1187033255.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/h1191064243.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/t1191103807.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/d1191355427.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/b1187277326.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/n1191554586.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/m1179874250.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/h1183729569.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/w1191481916.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/o1186960589.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/j1191735371.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/m1190985464.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/p1171340896.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/j1187022551.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/m1187017242.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/k1190981428.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/l1191485635.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/s1167344625.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/1182698598.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/x1191129028.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/k1183034177.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/m1169461915.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/q1191566819.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/e1191338151.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/q1191056336.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/m1148753453.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/n1191611788.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/l1191174227.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/p1188443975.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/d1181561615.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/b1187441783.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/l1180842849.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/d1190904638.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/3/m1190952251.json
#
# Processing Item: 4 (Allowed auctions: 36)
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/n1191790097.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/m1191610582.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/t1175705831.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/p1191561874.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/f1191683408.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/j1191552346.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/f1191723507.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/t1191616766.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/1191741850.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/l1191357408.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/n1191677586.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/w1160324955.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/l1173441636.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/l1191717769.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/v1191497444.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/e1191586024.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/w1191421468.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/r1191347605.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/g1191575542.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/e1151547546.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/d1189586751.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/c1191618326.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/r1190773866.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/b1191609816.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/s1191590524.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/m1191439995.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/r1191413891.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/k1191592318.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/s1191626724.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/j1132611060.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/v1190982790.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/x1191763053.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/4/h1191819480.json
#
# Processing Item: 5 (Allowed auctions: 57)
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/n1171719181.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/x1191729061.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/u1127527151.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/x1174503138.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/b1160855625.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/c1191161357.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/u1191631296.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/v1191128847.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/d1189096064.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/k1166614719.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/n1182986513.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/g1191190021.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/b1184294295.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/v1191361604.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/o1168947584.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/m1191333843.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/u1172645589.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/x1189139732.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/b1187284300.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/q1186635587.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/j1191729279.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/n1168197738.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/k1191729356.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/o1191731498.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/s1132109786.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/h1159731759.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/q1191731679.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/p1190346016.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/k1125807070.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/u1181871260.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/l1174471422.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/m1165318477.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/o1191160640.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/t1139631929.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/n1191341403.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/e1178664397.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/d1189532281.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/l1158492569.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/u1191230044.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/g1191629025.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/h1183887211.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/x1155423960.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/t1191234802.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/e1191616048.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/c1187760302.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/u1172682421.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/v1173767938.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/p1176859258.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/s1185763843.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/e1191726073.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/l1191626006.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/r1191422542.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/f1191337222.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/s1188945072.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/r1191709797.json
# [DONE] JSON saved: ../zm_scraper/listing/gdino/lens/5/n1125471554.json
#
# ✅ Filtered auctions processed and uploaded to Firebase!

# %% [markdown]
# ## Manual: Extract Masks and save them in Firestore

# %%
# obtain masks and their public urls (now reading bboxes from .npz)
import os
import numpy as np
import cv2
import pandas as pd
import json
import firebase_admin
import math
from firebase_admin import credentials, storage

os.makedirs(LENS, exist_ok=True)

# Initialize Firebase only if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate(FIREBASE_CRED_PATH)
    firebase_admin.initialize_app(cred, {
        'storageBucket': BUCKET_NAME
    })
bucket = storage.bucket()

# ────────────── Load Dataset Split ──────────────
with open(ANNOTATION_SPLIT, "r") as f:
    split_data = json.load(f)

test_split = split_data.get("test", {})

# ────────────── HELPERS ──────────────
def clamp_bbox_xyxy_exclusive(x1, y1, x2, y2, width, height):
    """
    Clamp (x1,y1,x2,y2) where x2,y2 are end-exclusive.
    Ensures 0 <= x1 < x2 <= width and 0 <= y1 < y2 <= height.
    """
    x1 = max(0, min(int(x1), max(0, width - 1)))
    y1 = max(0, min(int(y1), max(0, height - 1)))
    x2 = max(x1 + 1, min(int(x2), width))
    y2 = max(y1 + 1, min(int(y2), height))
    return x1, y1, x2, y2


def load_bboxes_from_coco_json(coco_path, image_shape, expected_filename=None):
    """
    Returns list of tuples: (region_id:str, (x1,y1,x2,y2)) from a COCO JSON file.

    - Supports per-image JSON (your current writer): takes the single image entry.
    - Supports dataset-wide JSON: filters annotations by matching image.file_name
      to `expected_filename` (if provided), else takes the first image block.

    Coordinates:
      COCO bbox is [x, y, w, h] in pixels (floats). We convert to xyxy with:
        x1 = floor(x), y1 = floor(y), x2 = ceil(x + w), y2 = ceil(y + h)
      We then clamp to image bounds and keep (x2, y2) as end-exclusive for slicing.
    """
    with open(coco_path, "r") as f:
        coco = json.load(f)

    height, width = image_shape[:2]

    images = coco.get("images", [])
    anns = coco.get("annotations", [])

    # If per-image JSON, there will be 1 image with id=1 and its annotations use image_id=1
    # If dataset-wide, find the image_id by filename
    image_id = None
    if expected_filename:
        # Handle both exact match and basename match
        for img in images:
            if img.get("file_name") == expected_filename or \
               os.path.splitext(img.get("file_name", ""))[0] == os.path.splitext(expected_filename)[0]:
                image_id = img.get("id")
                break
    if image_id is None:
        # Fallback: use the first image (per-image JSON typical)
        if images:
            image_id = images[0].get("id")

    if image_id is None:
        # No image found; return empty
        return []

    results = []
    for ann in anns:
        if ann.get("image_id") != image_id:
            continue
        bbox = ann.get("bbox")
        if not bbox or len(bbox) != 4:
            continue
        x, y, w, h = map(float, bbox)
        # Convert to xyxy end-exclusive
        x1 = math.floor(x)
        y1 = math.floor(y)
        x2 = math.ceil(x + w)
        y2 = math.ceil(y + h)
        x1, y1, x2, y2 = clamp_bbox_xyxy_exclusive(x1, y1, x2, y2, width, height)

        region_id = str(ann.get("id", len(results) + 1))
        results.append((region_id, (x1, y1, x2, y2)))

    return results

# ────────────── FUNCTIONS ──────────────
def upload_image_to_firebase(image_array, remote_name):
    """Uploads an image (NumPy array) as PNG to Firebase without saving locally."""
    success, encoded_image = cv2.imencode('.png', image_array)
    if not success:
        raise ValueError("Failed to encode image to PNG.")

    blob = bucket.blob(remote_name)
    blob.upload_from_string(encoded_image.tobytes(), content_type='image/png')
    blob.make_public()  # Make file publicly accessible
    return blob.public_url

def extract_and_upload_crops_from_coco(image_path, coco_json_path, item_id, auction_id):
    """Read COCO JSON bboxes, crop from image, upload to Firebase, and return JSON dict."""
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"[ERROR] Image not found: {image_path}")
        return {}

    if image.ndim == 3 and image.shape[2] == 4:  # Drop alpha if present
        image = image[:, :, :3]

    # Expected filename to match within the COCO "images" array
    expected_filename = os.path.basename(image_path)

    id_bbox_list = load_bboxes_from_coco_json(coco_json_path, image.shape, expected_filename=expected_filename)

    mask_data = {}
    for region_id, (x1, y1, x2, y2) in id_bbox_list:
        # end-exclusive slicing
        crop = image[y1:y2, x1:x2]
        if crop.size == 0:
            continue

        # Upload crop
        firebase_crop_name = f"{MODEL}/{item_id}/{auction_id}/mask_{region_id}.png"
        url = upload_image_to_firebase(crop, firebase_crop_name)

        mask_data[str(region_id)] = {
            "url": url,
            "bbox": [int(x1), int(y1), int(x2), int(y2)],
            "results": [],
            "tokens": []
        }

    return mask_data


def process_items():
    # Load item ids from your prompt CSV (used to locate per-item folders)
    df = pd.read_csv(TEXT_PROMPT_CSV)
    item_ids = df['id'].astype(str).tolist()

    # Load the single dataset-wide COCO file once
    COCO_JSON_PATH = MANUAL_POSTPROCESSED_LBL
    with open(COCO_JSON_PATH, "r") as f:
        coco = json.load(f)

    images = coco.get("images", [])
    annotations = coco.get("annotations", [])

    # Index annotations by image_id for fast lookup
    from collections import defaultdict
    anns_by_image = defaultdict(list)
    for ann in annotations:
        anns_by_image[ann.get("image_id")].append(ann)

    # Build: for convenience, map image_id -> image dict
    images_by_id = {img.get("id"): img for img in images}

    for item in item_ids:
        if item not in test_split:
            print(f"[SKIP] Item {item} not in test split.")
            continue

        allowed_files = test_split[item]  # e.g., ["1183014126.jpg", "1187040966.jpg"]
        allowed_ids = set(os.path.splitext(fname)[0] for fname in allowed_files)

        print(f"\nProcessing Item: {item} (Allowed auctions: {len(allowed_ids)})")
        img_dir = os.path.join(RAW, item)

        if not os.path.exists(img_dir):
            print(f"[WARNING] Image directory missing: {img_dir}")
            continue

        # Find all COCO images that belong to this item and are in the allowed split
        prefix = f"{item}/"
        candidate_imgs = []
        for img in images:
            file_name = img.get("file_name", "")
            if not file_name:
                continue
            if not file_name.startswith(prefix):
                continue
            auction_id = os.path.splitext(os.path.basename(file_name))[0]
            if auction_id in allowed_ids:
                candidate_imgs.append(img)

        if not candidate_imgs:
            print(f"[INFO] No matching COCO images for item {item} and given split.")
            continue

        for img in candidate_imgs:
            image_id = img.get("id")
            file_name = img.get("file_name")  # e.g., "1/1183014126.jpg"
            auction_id = os.path.splitext(os.path.basename(file_name))[0]

            # Resolve the image path in PREPROCESSED
            image_path = os.path.join(RAW, file_name)  # PREPROCESSED/<item>/<auction>.jpg
            if not os.path.exists(image_path):
                base_no_ext = os.path.join(RAW, item, auction_id)
                tried = []
                for ext in [".png", ".jpg", ".jpeg", ".JPG", ".PNG", ".JPEG"]:
                    cand = base_no_ext + ext
                    tried.append(cand)
                    if os.path.exists(cand):
                        image_path = cand
                        break
                if not os.path.exists(image_path):
                    print(f"[WARNING] Missing original image for auction {auction_id}. Tried: {tried}")
                    continue

            # Load image (for cropping)
            image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
            if image is None:
                print(f"[ERROR] Failed to read image: {image_path}")
                continue
            if image.ndim == 3 and image.shape[2] == 4:  # drop alpha if present
                image = image[:, :, :3]

            H, W = image.shape[:2]

            # Collect and convert this image's bboxes from COCO
            id_bbox_list = []
            # IMPORTANT: enumerate -> 1..N per IMAGE (not using ann["id"])
            for idx, ann in enumerate(anns_by_image.get(image_id, []), start=1):
                bbox = ann.get("bbox")
                if not bbox or len(bbox) != 4:
                    continue
                x, y, w, h = map(float, bbox)
                # xyxy (end-exclusive)
                x1 = math.floor(x)
                y1 = math.floor(y)
                x2 = math.ceil(x + w)
                y2 = math.ceil(y + h)
                # clamp
                x1, y1, x2, y2 = clamp_bbox_xyxy_exclusive(x1, y1, x2, y2, W, H)
                region_id = str(idx)  # <-- use running count (1,2,3,...) instead of ann["id"]
                id_bbox_list.append((region_id, (x1, y1, x2, y2)))

            # Crop, upload, and build JSON
            mask_data = {}
            for region_id, (x1, y1, x2, y2) in id_bbox_list:
                crop = image[y1:y2, x1:x2]
                if crop.size == 0:
                    continue
                firebase_crop_name = f"{MODEL}/{item}/{auction_id}/mask_{region_id}.png"
                url = upload_image_to_firebase(crop, firebase_crop_name)
                mask_data[str(region_id)] = {
                    "url": url,
                    "bbox": [int(x1), int(y1), int(x2), int(y2)],
                    "results": [],
                    "tokens": []
                }

            # Save JSON for this auction
            auction_output_dir = os.path.join(LENS, item)
            os.makedirs(auction_output_dir, exist_ok=True)
            json_path = os.path.join(auction_output_dir, f"{auction_id}.json")
            with open(json_path, "w") as f:
                json.dump(mask_data, f, indent=4)

            print(f"[DONE] {item}/{auction_id} -> {json_path}")


if __name__ == "__main__":
    process_items()
    print("\n✅ Filtered auctions processed and uploaded to Firebase!")
# Out:
# Processing Item: 1 (Allowed auctions: 60)
# [DONE] 1/1183014126 -> ../zm_scraper/listing/manual/lens/1/1183014126.json
# [DONE] 1/1187040966 -> ../zm_scraper/listing/manual/lens/1/1187040966.json
# [DONE] 1/1188971238 -> ../zm_scraper/listing/manual/lens/1/1188971238.json
# [DONE] 1/1190947766 -> ../zm_scraper/listing/manual/lens/1/1190947766.json
# [DONE] 1/b1187681880 -> ../zm_scraper/listing/manual/lens/1/b1187681880.json
# [DONE] 1/b1191454294 -> ../zm_scraper/listing/manual/lens/1/b1191454294.json
# [DONE] 1/c1174455551 -> ../zm_scraper/listing/manual/lens/1/c1174455551.json
# [DONE] 1/c1186222082 -> ../zm_scraper/listing/manual/lens/1/c1186222082.json
# [DONE] 1/c1191011512 -> ../zm_scraper/listing/manual/lens/1/c1191011512.json
# [DONE] 1/c1191323690 -> ../zm_scraper/listing/manual/lens/1/c1191323690.json
# [DONE] 1/d1187227651 -> ../zm_scraper/listing/manual/lens/1/d1187227651.json
# [DONE] 1/d1191065516 -> ../zm_scraper/listing/manual/lens/1/d1191065516.json
# [DONE] 1/f1152247645 -> ../zm_scraper/listing/manual/lens/1/f1152247645.json
# [DONE] 1/f1182381846 -> ../zm_scraper/listing/manual/lens/1/f1182381846.json
# [DONE] 1/f1191458213 -> ../zm_scraper/listing/manual/lens/1/f1191458213.json
# [DONE] 1/g1186111364 -> ../zm_scraper/listing/manual/lens/1/g1186111364.json
# [DONE] 1/g1187312653 -> ../zm_scraper/listing/manual/lens/1/g1187312653.json
# [DONE] 1/h1191357858 -> ../zm_scraper/listing/manual/lens/1/h1191357858.json
# [DONE] 1/j1191431672 -> ../zm_scraper/listing/manual/lens/1/j1191431672.json
# [DONE] 1/k1190557636 -> ../zm_scraper/listing/manual/lens/1/k1190557636.json
# [DONE] 1/k1190934472 -> ../zm_scraper/listing/manual/lens/1/k1190934472.json
# [DONE] 1/k1191474797 -> ../zm_scraper/listing/manual/lens/1/k1191474797.json
# [DONE] 1/l1180181252 -> ../zm_scraper/listing/manual/lens/1/l1180181252.json
# [DONE] 1/l1185983984 -> ../zm_scraper/listing/manual/lens/1/l1185983984.json
# [DONE] 1/l1190559645 -> ../zm_scraper/listing/manual/lens/1/l1190559645.json
# [DONE] 1/l1190830129 -> ../zm_scraper/listing/manual/lens/1/l1190830129.json
# [DONE] 1/m1133776499 -> ../zm_scraper/listing/manual/lens/1/m1133776499.json
# [DONE] 1/n1181963058 -> ../zm_scraper/listing/manual/lens/1/n1181963058.json
# [DONE] 1/n1184979547 -> ../zm_scraper/listing/manual/lens/1/n1184979547.json
# [DONE] 1/n1191681464 -> ../zm_scraper/listing/manual/lens/1/n1191681464.json
# [DONE] 1/o1119853616 -> ../zm_scraper/listing/manual/lens/1/o1119853616.json
# [DONE] 1/o1187637806 -> ../zm_scraper/listing/manual/lens/1/o1187637806.json
# [DONE] 1/o1191069257 -> ../zm_scraper/listing/manual/lens/1/o1191069257.json
# [DONE] 1/p1127453774 -> ../zm_scraper/listing/manual/lens/1/p1127453774.json
# [DONE] 1/p1187246330 -> ../zm_scraper/listing/manual/lens/1/p1187246330.json
# [DONE] 1/q1177627244 -> ../zm_scraper/listing/manual/lens/1/q1177627244.json
# [DONE] 1/q1183324759 -> ../zm_scraper/listing/manual/lens/1/q1183324759.json
# [DONE] 1/q1185787171 -> ../zm_scraper/listing/manual/lens/1/q1185787171.json
# [DONE] 1/q1187025650 -> ../zm_scraper/listing/manual/lens/1/q1187025650.json
# [DONE] 1/q1191599905 -> ../zm_scraper/listing/manual/lens/1/q1191599905.json
# [DONE] 1/r1140105858 -> ../zm_scraper/listing/manual/lens/1/r1140105858.json
# [DONE] 1/r1172860507 -> ../zm_scraper/listing/manual/lens/1/r1172860507.json
# [DONE] 1/r1188366109 -> ../zm_scraper/listing/manual/lens/1/r1188366109.json
# [DONE] 1/s1119897266 -> ../zm_scraper/listing/manual/lens/1/s1119897266.json
# [DONE] 1/s1158964294 -> ../zm_scraper/listing/manual/lens/1/s1158964294.json
# [DONE] 1/s1175248638 -> ../zm_scraper/listing/manual/lens/1/s1175248638.json
# [DONE] 1/s1191791966 -> ../zm_scraper/listing/manual/lens/1/s1191791966.json
# [DONE] 1/t1144496280 -> ../zm_scraper/listing/manual/lens/1/t1144496280.json
# [DONE] 1/v1157073564 -> ../zm_scraper/listing/manual/lens/1/v1157073564.json
# [DONE] 1/v1187261662 -> ../zm_scraper/listing/manual/lens/1/v1187261662.json
# [DONE] 1/v1191007699 -> ../zm_scraper/listing/manual/lens/1/v1191007699.json
# [DONE] 1/w1190845066 -> ../zm_scraper/listing/manual/lens/1/w1190845066.json
# [DONE] 1/w1190871465 -> ../zm_scraper/listing/manual/lens/1/w1190871465.json
# [DONE] 1/w1191415731 -> ../zm_scraper/listing/manual/lens/1/w1191415731.json
# [DONE] 1/x1121603563 -> ../zm_scraper/listing/manual/lens/1/x1121603563.json
# [DONE] 1/x1144497640 -> ../zm_scraper/listing/manual/lens/1/x1144497640.json
# [DONE] 1/x1190805798 -> ../zm_scraper/listing/manual/lens/1/x1190805798.json
# [DONE] 1/x1191588773 -> ../zm_scraper/listing/manual/lens/1/x1191588773.json
# [DONE] 1/x1191598905 -> ../zm_scraper/listing/manual/lens/1/x1191598905.json
# [DONE] 1/x1191726070 -> ../zm_scraper/listing/manual/lens/1/x1191726070.json
#
# Processing Item: 2 (Allowed auctions: 24)
# [DONE] 2/1191044626 -> ../zm_scraper/listing/manual/lens/2/1191044626.json
# [DONE] 2/b1174068183 -> ../zm_scraper/listing/manual/lens/2/b1174068183.json
# [DONE] 2/c1132411431 -> ../zm_scraper/listing/manual/lens/2/c1132411431.json
# [DONE] 2/c1187483831 -> ../zm_scraper/listing/manual/lens/2/c1187483831.json
# [DONE] 2/c583016002 -> ../zm_scraper/listing/manual/lens/2/c583016002.json
# [DONE] 2/e1191332130 -> ../zm_scraper/listing/manual/lens/2/e1191332130.json
# [DONE] 2/f1109446657 -> ../zm_scraper/listing/manual/lens/2/f1109446657.json
# [DONE] 2/h1055489564 -> ../zm_scraper/listing/manual/lens/2/h1055489564.json
# [DONE] 2/j1188223998 -> ../zm_scraper/listing/manual/lens/2/j1188223998.json
# [DONE] 2/j1191314319 -> ../zm_scraper/listing/manual/lens/2/j1191314319.json
# [DONE] 2/k1184414767 -> ../zm_scraper/listing/manual/lens/2/k1184414767.json
# [DONE] 2/l1171615527 -> ../zm_scraper/listing/manual/lens/2/l1171615527.json
# [DONE] 2/l1189425708 -> ../zm_scraper/listing/manual/lens/2/l1189425708.json
# [DONE] 2/m1175679082 -> ../zm_scraper/listing/manual/lens/2/m1175679082.json
# [DONE] 2/m1191712171 -> ../zm_scraper/listing/manual/lens/2/m1191712171.json
# [DONE] 2/n1190944641 -> ../zm_scraper/listing/manual/lens/2/n1190944641.json
# [DONE] 2/p1101871478 -> ../zm_scraper/listing/manual/lens/2/p1101871478.json
# [DONE] 2/t1190192579 -> ../zm_scraper/listing/manual/lens/2/t1190192579.json
# [DONE] 2/u1159547663 -> ../zm_scraper/listing/manual/lens/2/u1159547663.json
# [DONE] 2/v1168878467 -> ../zm_scraper/listing/manual/lens/2/v1168878467.json
# [DONE] 2/v1180804864 -> ../zm_scraper/listing/manual/lens/2/v1180804864.json
# [DONE] 2/v1187327043 -> ../zm_scraper/listing/manual/lens/2/v1187327043.json
# [DONE] 2/x1171181348 -> ../zm_scraper/listing/manual/lens/2/x1171181348.json
# [DONE] 2/x1185026795 -> ../zm_scraper/listing/manual/lens/2/x1185026795.json
#
# Processing Item: 3 (Allowed auctions: 36)
# [DONE] 3/1182698598 -> ../zm_scraper/listing/manual/lens/3/1182698598.json
# [DONE] 3/b1187277326 -> ../zm_scraper/listing/manual/lens/3/b1187277326.json
# [DONE] 3/b1187441783 -> ../zm_scraper/listing/manual/lens/3/b1187441783.json
# [DONE] 3/d1181561615 -> ../zm_scraper/listing/manual/lens/3/d1181561615.json
# [DONE] 3/d1190904638 -> ../zm_scraper/listing/manual/lens/3/d1190904638.json
# [DONE] 3/d1191355427 -> ../zm_scraper/listing/manual/lens/3/d1191355427.json
# [DONE] 3/e1191338151 -> ../zm_scraper/listing/manual/lens/3/e1191338151.json
# [DONE] 3/h1183729569 -> ../zm_scraper/listing/manual/lens/3/h1183729569.json
# [DONE] 3/h1190298916 -> ../zm_scraper/listing/manual/lens/3/h1190298916.json
# [DONE] 3/h1191064243 -> ../zm_scraper/listing/manual/lens/3/h1191064243.json
# [DONE] 3/j1187022551 -> ../zm_scraper/listing/manual/lens/3/j1187022551.json
# [DONE] 3/j1191735371 -> ../zm_scraper/listing/manual/lens/3/j1191735371.json
# [DONE] 3/k1183034177 -> ../zm_scraper/listing/manual/lens/3/k1183034177.json
# [DONE] 3/k1190981428 -> ../zm_scraper/listing/manual/lens/3/k1190981428.json
# [DONE] 3/l1180842849 -> ../zm_scraper/listing/manual/lens/3/l1180842849.json
# [DONE] 3/l1191174227 -> ../zm_scraper/listing/manual/lens/3/l1191174227.json
# [DONE] 3/l1191485635 -> ../zm_scraper/listing/manual/lens/3/l1191485635.json
# [DONE] 3/m1148753453 -> ../zm_scraper/listing/manual/lens/3/m1148753453.json
# [DONE] 3/m1169461915 -> ../zm_scraper/listing/manual/lens/3/m1169461915.json
# [DONE] 3/m1179874250 -> ../zm_scraper/listing/manual/lens/3/m1179874250.json
# [DONE] 3/m1187017242 -> ../zm_scraper/listing/manual/lens/3/m1187017242.json
# [DONE] 3/m1190952251 -> ../zm_scraper/listing/manual/lens/3/m1190952251.json
# [DONE] 3/m1190985464 -> ../zm_scraper/listing/manual/lens/3/m1190985464.json
# [DONE] 3/n1173190176 -> ../zm_scraper/listing/manual/lens/3/n1173190176.json
# [DONE] 3/n1191554586 -> ../zm_scraper/listing/manual/lens/3/n1191554586.json
# [DONE] 3/n1191611788 -> ../zm_scraper/listing/manual/lens/3/n1191611788.json
# [DONE] 3/o1186960589 -> ../zm_scraper/listing/manual/lens/3/o1186960589.json
# [DONE] 3/p1171340896 -> ../zm_scraper/listing/manual/lens/3/p1171340896.json
# [DONE] 3/p1188443975 -> ../zm_scraper/listing/manual/lens/3/p1188443975.json
# [DONE] 3/q1191056336 -> ../zm_scraper/listing/manual/lens/3/q1191056336.json
# [DONE] 3/q1191566819 -> ../zm_scraper/listing/manual/lens/3/q1191566819.json
# [DONE] 3/s1167344625 -> ../zm_scraper/listing/manual/lens/3/s1167344625.json
# [DONE] 3/t1191103807 -> ../zm_scraper/listing/manual/lens/3/t1191103807.json
# [DONE] 3/v1187033255 -> ../zm_scraper/listing/manual/lens/3/v1187033255.json
# [DONE] 3/w1191481916 -> ../zm_scraper/listing/manual/lens/3/w1191481916.json
# [DONE] 3/x1191129028 -> ../zm_scraper/listing/manual/lens/3/x1191129028.json
#
# Processing Item: 4 (Allowed auctions: 36)
# [DONE] 4/1191441222 -> ../zm_scraper/listing/manual/lens/4/1191441222.json
# [DONE] 4/1191741850 -> ../zm_scraper/listing/manual/lens/4/1191741850.json
# [DONE] 4/b1191609816 -> ../zm_scraper/listing/manual/lens/4/b1191609816.json
# [DONE] 4/c1191618326 -> ../zm_scraper/listing/manual/lens/4/c1191618326.json
# [DONE] 4/d1189586751 -> ../zm_scraper/listing/manual/lens/4/d1189586751.json
# [DONE] 4/e1151547546 -> ../zm_scraper/listing/manual/lens/4/e1151547546.json
# [DONE] 4/e1191586024 -> ../zm_scraper/listing/manual/lens/4/e1191586024.json
# [DONE] 4/f1191683408 -> ../zm_scraper/listing/manual/lens/4/f1191683408.json
# [DONE] 4/f1191723507 -> ../zm_scraper/listing/manual/lens/4/f1191723507.json
# [DONE] 4/g1191575542 -> ../zm_scraper/listing/manual/lens/4/g1191575542.json
# [DONE] 4/h1191819480 -> ../zm_scraper/listing/manual/lens/4/h1191819480.json
# [DONE] 4/j1132611060 -> ../zm_scraper/listing/manual/lens/4/j1132611060.json
# [ERROR] Failed to read image: ../zm_scraper/listing/raw/4/j1155619753.jpg
# [DONE] 4/j1191552346 -> ../zm_scraper/listing/manual/lens/4/j1191552346.json
# [DONE] 4/k1191592318 -> ../zm_scraper/listing/manual/lens/4/k1191592318.json
# [DONE] 4/l1173441636 -> ../zm_scraper/listing/manual/lens/4/l1173441636.json
# [DONE] 4/l1191717769 -> ../zm_scraper/listing/manual/lens/4/l1191717769.json
# [DONE] 4/m1191439995 -> ../zm_scraper/listing/manual/lens/4/m1191439995.json
# [DONE] 4/m1191610582 -> ../zm_scraper/listing/manual/lens/4/m1191610582.json
# [DONE] 4/n1191677586 -> ../zm_scraper/listing/manual/lens/4/n1191677586.json
# [DONE] 4/n1191790097 -> ../zm_scraper/listing/manual/lens/4/n1191790097.json
# [DONE] 4/p1191561874 -> ../zm_scraper/listing/manual/lens/4/p1191561874.json
# [DONE] 4/r1190773866 -> ../zm_scraper/listing/manual/lens/4/r1190773866.json
# [DONE] 4/r1191347605 -> ../zm_scraper/listing/manual/lens/4/r1191347605.json
# [DONE] 4/r1191413891 -> ../zm_scraper/listing/manual/lens/4/r1191413891.json
# [ERROR] Failed to read image: ../zm_scraper/listing/raw/4/s1156142837.jpg
# [DONE] 4/s1191590524 -> ../zm_scraper/listing/manual/lens/4/s1191590524.json
# [DONE] 4/s1191626724 -> ../zm_scraper/listing/manual/lens/4/s1191626724.json
# [DONE] 4/t1175705831 -> ../zm_scraper/listing/manual/lens/4/t1175705831.json
# [DONE] 4/t1191616766 -> ../zm_scraper/listing/manual/lens/4/t1191616766.json
# [DONE] 4/v1190982790 -> ../zm_scraper/listing/manual/lens/4/v1190982790.json
# [DONE] 4/v1191497444 -> ../zm_scraper/listing/manual/lens/4/v1191497444.json
# [DONE] 4/w1160324955 -> ../zm_scraper/listing/manual/lens/4/w1160324955.json
# [DONE] 4/w1191421468 -> ../zm_scraper/listing/manual/lens/4/w1191421468.json
# [DONE] 4/x1191763053 -> ../zm_scraper/listing/manual/lens/4/x1191763053.json
#
# Processing Item: 5 (Allowed auctions: 57)
# [DONE] 5/1158321429 -> ../zm_scraper/listing/manual/lens/5/1158321429.json
# [DONE] 5/b1160855625 -> ../zm_scraper/listing/manual/lens/5/b1160855625.json
# [DONE] 5/b1184294295 -> ../zm_scraper/listing/manual/lens/5/b1184294295.json
# [DONE] 5/b1187284300 -> ../zm_scraper/listing/manual/lens/5/b1187284300.json
# [DONE] 5/c1187760302 -> ../zm_scraper/listing/manual/lens/5/c1187760302.json
# [DONE] 5/d1189096064 -> ../zm_scraper/listing/manual/lens/5/d1189096064.json
# [DONE] 5/d1189532281 -> ../zm_scraper/listing/manual/lens/5/d1189532281.json
# [DONE] 5/e1178664397 -> ../zm_scraper/listing/manual/lens/5/e1178664397.json
# [DONE] 5/e1191616048 -> ../zm_scraper/listing/manual/lens/5/e1191616048.json
# [DONE] 5/e1191726073 -> ../zm_scraper/listing/manual/lens/5/e1191726073.json
# [DONE] 5/f1191337222 -> ../zm_scraper/listing/manual/lens/5/f1191337222.json
# [DONE] 5/g1191190021 -> ../zm_scraper/listing/manual/lens/5/g1191190021.json
# [DONE] 5/g1191629025 -> ../zm_scraper/listing/manual/lens/5/g1191629025.json
# [DONE] 5/h1159731759 -> ../zm_scraper/listing/manual/lens/5/h1159731759.json
# [DONE] 5/h1183887211 -> ../zm_scraper/listing/manual/lens/5/h1183887211.json
# [DONE] 5/j1191729279 -> ../zm_scraper/listing/manual/lens/5/j1191729279.json
# [DONE] 5/k1125807070 -> ../zm_scraper/listing/manual/lens/5/k1125807070.json
# [DONE] 5/k1166614719 -> ../zm_scraper/listing/manual/lens/5/k1166614719.json
# [DONE] 5/k1191729356 -> ../zm_scraper/listing/manual/lens/5/k1191729356.json
# [DONE] 5/l1158492569 -> ../zm_scraper/listing/manual/lens/5/l1158492569.json
# [DONE] 5/l1174471422 -> ../zm_scraper/listing/manual/lens/5/l1174471422.json
# [DONE] 5/l1191626006 -> ../zm_scraper/listing/manual/lens/5/l1191626006.json
# [DONE] 5/m1165318477 -> ../zm_scraper/listing/manual/lens/5/m1165318477.json
# [DONE] 5/m1191333843 -> ../zm_scraper/listing/manual/lens/5/m1191333843.json
# [DONE] 5/n1125471554 -> ../zm_scraper/listing/manual/lens/5/n1125471554.json
# [DONE] 5/n1168197738 -> ../zm_scraper/listing/manual/lens/5/n1168197738.json
# [DONE] 5/n1171719181 -> ../zm_scraper/listing/manual/lens/5/n1171719181.json
# [DONE] 5/n1182986513 -> ../zm_scraper/listing/manual/lens/5/n1182986513.json
# [DONE] 5/n1191341403 -> ../zm_scraper/listing/manual/lens/5/n1191341403.json
# [DONE] 5/o1168947584 -> ../zm_scraper/listing/manual/lens/5/o1168947584.json
# [DONE] 5/o1191160640 -> ../zm_scraper/listing/manual/lens/5/o1191160640.json
# [DONE] 5/o1191731498 -> ../zm_scraper/listing/manual/lens/5/o1191731498.json
# [DONE] 5/p1176859258 -> ../zm_scraper/listing/manual/lens/5/p1176859258.json
# [DONE] 5/p1190346016 -> ../zm_scraper/listing/manual/lens/5/p1190346016.json
# [DONE] 5/q1186635587 -> ../zm_scraper/listing/manual/lens/5/q1186635587.json
# [DONE] 5/q1191731679 -> ../zm_scraper/listing/manual/lens/5/q1191731679.json
# [DONE] 5/r1191422542 -> ../zm_scraper/listing/manual/lens/5/r1191422542.json
# [DONE] 5/r1191709797 -> ../zm_scraper/listing/manual/lens/5/r1191709797.json
# [DONE] 5/s1185763843 -> ../zm_scraper/listing/manual/lens/5/s1185763843.json
# [DONE] 5/s1188945072 -> ../zm_scraper/listing/manual/lens/5/s1188945072.json
# [DONE] 5/t1139631929 -> ../zm_scraper/listing/manual/lens/5/t1139631929.json
# [DONE] 5/t1191234802 -> ../zm_scraper/listing/manual/lens/5/t1191234802.json
# [DONE] 5/u1127527151 -> ../zm_scraper/listing/manual/lens/5/u1127527151.json
# [DONE] 5/u1172645589 -> ../zm_scraper/listing/manual/lens/5/u1172645589.json
# [DONE] 5/u1172682421 -> ../zm_scraper/listing/manual/lens/5/u1172682421.json
# [DONE] 5/u1181871260 -> ../zm_scraper/listing/manual/lens/5/u1181871260.json
# [DONE] 5/u1191230044 -> ../zm_scraper/listing/manual/lens/5/u1191230044.json
# [DONE] 5/v1173767938 -> ../zm_scraper/listing/manual/lens/5/v1173767938.json
# [DONE] 5/v1191128847 -> ../zm_scraper/listing/manual/lens/5/v1191128847.json
# [DONE] 5/v1191361604 -> ../zm_scraper/listing/manual/lens/5/v1191361604.json
# [DONE] 5/x1155423960 -> ../zm_scraper/listing/manual/lens/5/x1155423960.json
# [DONE] 5/x1174503138 -> ../zm_scraper/listing/manual/lens/5/x1174503138.json
# [DONE] 5/x1189139732 -> ../zm_scraper/listing/manual/lens/5/x1189139732.json
# [DONE] 5/x1191729061 -> ../zm_scraper/listing/manual/lens/5/x1191729061.json
#
# ✅ Filtered auctions processed and uploaded to Firebase!

# %% [markdown]
# ## Call ScrapingDog (Lens API)

# %%
# For each json, read each mask ids public url and send it into scrapingdog 
# save its responses into the results array.
import os
import json
import pandas as pd
import requests
from dotenv import load_dotenv

# load variables from .env in the current directory
load_dotenv()

# Paths
SCRAPINGDOG_API_KEY = os.getenv("SCRAPINGDOG_API_KEY")
SCRAPINGDOG_ENDPOINT = "https://api.scrapingdog.com/google_lens"

def call_scrapingdog(image_url):
    """Send image URL to Scrapingdog and return the JSON response."""
    params = {
        "api_key": SCRAPINGDOG_API_KEY,
        "url": f"https://lens.google.com/uploadbyurl?url={image_url}",
    }
    try:
        response = requests.get(SCRAPINGDOG_ENDPOINT, params=params, timeout=60)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"[ERROR] Scrapingdog failed for {image_url} - Status: {response.status_code}")
            return None
    except Exception as e:
        print(f"[EXCEPTION] Error calling Scrapingdog: {e}")
        return None

def process_jsons():
    # Read item IDs from CSV
    df = pd.read_csv(TEXT_PROMPT_CSV)
    item_ids = df['id'].astype(str).tolist()

    for item_id in item_ids:
        item_folder = os.path.join(LENS, item_id)
        if not os.path.exists(item_folder):
            print(f"[SKIP] No JSON folder for item: {item_id}")
            continue

        # Iterate over JSON files for this item
        for json_file in os.listdir(item_folder):
            if not json_file.endswith(".json"):
                continue

            json_path = os.path.join(item_folder, json_file)
            print(f"\n[PROCESSING] {json_path}")

            # Load JSON data
            with open(json_path, "r") as f:
                data = json.load(f)

            updated = False

            for mask_id, mask_info in data.items():
                image_url = mask_info.get("url")
                if not image_url:
                    continue

                # Skip if results already exist
                if (OVERWRITE_RESULTS is False):
                    if "results" in mask_info and len(mask_info["results"]) > 0:
                        print(f"  [SKIP] Mask {mask_id} already has results.")
                        continue
                        
                # Call scraping dog here
                print(f"  [CALLING] Lens for mask {mask_id}")
                result = call_scrapingdog(image_url)                    
                if result:
                    if "results" not in mask_info:
                        mask_info["results"] = []
#                     If invalud result
                    if result['lens_results'] == ["Google Lens didn't return any results."]:
                        mask_info["results"]=[]
                    else:
                        mask_info["results"]=result['lens_results']
                    updated = True
                else:
                    print(f"FAILED")

            if updated:
                with open(json_path, "w") as f:
                    json.dump(data, f, indent=4, ensure_ascii=False)
                print(f"  [UPDATED] {json_path}")

if __name__ == "__main__":
    process_jsons()
    print("\n✅ All JSON files updated with Scrapingdog results!")
# Out:
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/w1190871465.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/w1190871465.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/q1177627244.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/q1177627244.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/t1144496280.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/t1144496280.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/x1121603563.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/x1121603563.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/l1180181252.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/l1180181252.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/r1140105858.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/r1140105858.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/n1181963058.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/n1181963058.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/w1191415731.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/w1191415731.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/l1190559645.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/l1190559645.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/c1174455551.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/c1174455551.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/c1186222082.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/c1186222082.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/1190947766.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/1190947766.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/q1185787171.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/q1185787171.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/q1187025650.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/q1187025650.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/k1190557636.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/k1190557636.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/x1191598905.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/x1191598905.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/q1183324759.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/q1183324759.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/n1184979547.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/n1184979547.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/1188971238.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/1188971238.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/f1191458213.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/f1191458213.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/n1191681464.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/n1191681464.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/q1191599905.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [CALLING] Lens for mask 21
#   [CALLING] Lens for mask 22
#   [CALLING] Lens for mask 23
#   [CALLING] Lens for mask 24
#   [CALLING] Lens for mask 25
#   [CALLING] Lens for mask 26
#   [CALLING] Lens for mask 27
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/q1191599905.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/c1191011512.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/c1191011512.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/1183014126.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/1183014126.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/x1191726070.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/x1191726070.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/g1187312653.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/g1187312653.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/s1119897266.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/s1119897266.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/c1191323690.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/c1191323690.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/p1187246330.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/p1187246330.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/b1191454294.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/b1191454294.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/k1191474797.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/k1191474797.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/f1182381846.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/f1182381846.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/g1186111364.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/g1186111364.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/x1190805798.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/x1190805798.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/m1133776499.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/m1133776499.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/x1144497640.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/x1144497640.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/r1172860507.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/r1172860507.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/s1175248638.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/s1175248638.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/b1187681880.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/b1187681880.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/o1191069257.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/o1191069257.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/x1191588773.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [CALLING] Lens for mask 21
#   [CALLING] Lens for mask 22
#   [CALLING] Lens for mask 23
#   [CALLING] Lens for mask 24
#   [CALLING] Lens for mask 25
#   [CALLING] Lens for mask 26
#   [CALLING] Lens for mask 27
#   [CALLING] Lens for mask 28
#   [CALLING] Lens for mask 29
#   [CALLING] Lens for mask 30
#   [CALLING] Lens for mask 31
#   [CALLING] Lens for mask 32
#   [CALLING] Lens for mask 33
#   [CALLING] Lens for mask 34
#   [CALLING] Lens for mask 35
#   [CALLING] Lens for mask 36
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/x1191588773.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/p1127453774.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/p1127453774.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/v1191007699.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/v1191007699.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/l1185983984.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/l1185983984.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/j1191431672.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/j1191431672.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/s1158964294.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/s1158964294.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/f1152247645.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/f1152247645.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/w1190845066.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/w1190845066.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/l1190830129.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/l1190830129.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/h1191357858.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/h1191357858.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/s1191791966.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/s1191791966.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/1187040966.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/1187040966.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/o1119853616.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/o1119853616.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/d1191065516.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/d1191065516.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/o1187637806.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/o1187637806.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/k1190934472.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/k1190934472.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/r1188366109.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/r1188366109.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/v1187261662.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/v1187261662.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/d1187227651.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/d1187227651.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/1/v1157073564.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/1/v1157073564.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/m1191712171.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/m1191712171.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/x1185026795.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/x1185026795.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/x1171181348.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/x1171181348.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/l1171615527.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/l1171615527.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/h1055489564.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/h1055489564.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/c583016002.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/c583016002.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/u1159547663.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/u1159547663.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/p1101871478.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/p1101871478.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/f1109446657.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/f1109446657.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/v1168878467.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/v1168878467.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/l1189425708.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/l1189425708.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/j1188223998.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/j1188223998.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/e1191332130.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/e1191332130.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/b1174068183.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/b1174068183.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/k1184414767.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/k1184414767.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/c1187483831.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/c1187483831.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/m1175679082.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/m1175679082.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/1191044626.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/1191044626.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/j1191314319.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/j1191314319.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/t1190192579.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/t1190192579.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/v1180804864.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/v1180804864.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/n1190944641.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/n1190944641.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/v1187327043.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/v1187327043.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/2/c1132411431.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/2/c1132411431.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/h1190298916.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/h1190298916.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/n1173190176.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/n1173190176.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/v1187033255.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/v1187033255.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/h1191064243.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/h1191064243.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/t1191103807.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/t1191103807.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/d1191355427.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/d1191355427.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/b1187277326.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/b1187277326.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/n1191554586.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/n1191554586.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/m1179874250.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/m1179874250.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/h1183729569.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/h1183729569.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/w1191481916.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/w1191481916.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/o1186960589.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/o1186960589.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/j1191735371.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/j1191735371.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/m1190985464.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/m1190985464.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/p1171340896.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/p1171340896.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/j1187022551.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/j1187022551.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/m1187017242.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/m1187017242.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/k1190981428.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/k1190981428.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/l1191485635.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/l1191485635.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/s1167344625.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/s1167344625.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/1182698598.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/1182698598.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/x1191129028.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/x1191129028.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/k1183034177.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/k1183034177.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/m1169461915.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/m1169461915.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/q1191566819.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/q1191566819.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/e1191338151.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [CALLING] Lens for mask 21
#   [CALLING] Lens for mask 22
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/e1191338151.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/q1191056336.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/q1191056336.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/m1148753453.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/m1148753453.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/n1191611788.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/n1191611788.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/l1191174227.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/l1191174227.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/p1188443975.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/p1188443975.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/d1181561615.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/d1181561615.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/b1187441783.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/b1187441783.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/l1180842849.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/l1180842849.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/d1190904638.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/d1190904638.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/3/m1190952251.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/3/m1190952251.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/n1191790097.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/n1191790097.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/m1191610582.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/m1191610582.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/t1175705831.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/t1175705831.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/p1191561874.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/p1191561874.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/f1191683408.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/f1191683408.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/j1191552346.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/j1191552346.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/f1191723507.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/f1191723507.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/t1191616766.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/t1191616766.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/1191741850.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/1191741850.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/l1191357408.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/l1191357408.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/n1191677586.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/n1191677586.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/w1160324955.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/l1173441636.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/l1191717769.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/l1191717769.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/v1191497444.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/v1191497444.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/e1191586024.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/e1191586024.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/w1191421468.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/w1191421468.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/r1191347605.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/r1191347605.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/g1191575542.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/g1191575542.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/e1151547546.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/d1189586751.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/d1189586751.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/c1191618326.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/c1191618326.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/r1190773866.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/r1190773866.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/b1191609816.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/b1191609816.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/s1191590524.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [CALLING] Lens for mask 21
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/s1191590524.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/m1191439995.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/m1191439995.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/r1191413891.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/r1191413891.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/k1191592318.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/k1191592318.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/s1191626724.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/s1191626724.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/j1132611060.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/j1132611060.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/v1190982790.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/v1190982790.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/x1191763053.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/x1191763053.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/4/h1191819480.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/4/h1191819480.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/n1171719181.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/n1171719181.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/x1191729061.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/x1191729061.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/u1127527151.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/u1127527151.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/x1174503138.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/x1174503138.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/b1160855625.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/b1160855625.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/c1191161357.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/c1191161357.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/u1191631296.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/u1191631296.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/v1191128847.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/v1191128847.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/d1189096064.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/d1189096064.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/k1166614719.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/k1166614719.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/n1182986513.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/n1182986513.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/g1191190021.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [CALLING] Lens for mask 21
#   [CALLING] Lens for mask 22
#   [CALLING] Lens for mask 23
#   [CALLING] Lens for mask 24
#   [CALLING] Lens for mask 25
#   [CALLING] Lens for mask 26
#   [CALLING] Lens for mask 27
#   [CALLING] Lens for mask 28
#   [CALLING] Lens for mask 29
#   [CALLING] Lens for mask 30
#   [CALLING] Lens for mask 31
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/g1191190021.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/b1184294295.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/b1184294295.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/v1191361604.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [CALLING] Lens for mask 21
#   [CALLING] Lens for mask 22
#   [CALLING] Lens for mask 23
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/v1191361604.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/o1168947584.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/o1168947584.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/m1191333843.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/m1191333843.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/u1172645589.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/u1172645589.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/x1189139732.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/x1189139732.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/b1187284300.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/b1187284300.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/q1186635587.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/q1186635587.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/j1191729279.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/j1191729279.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/n1168197738.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/n1168197738.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/k1191729356.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/k1191729356.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/o1191731498.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/o1191731498.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/s1132109786.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/s1132109786.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/h1159731759.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/h1159731759.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/q1191731679.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/q1191731679.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/p1190346016.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/p1190346016.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/k1125807070.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/k1125807070.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/u1181871260.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/u1181871260.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/l1174471422.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/l1174471422.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/m1165318477.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/m1165318477.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/o1191160640.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/o1191160640.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/t1139631929.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/t1139631929.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/n1191341403.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/n1191341403.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/e1178664397.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/e1178664397.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/d1189532281.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/d1189532281.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/l1158492569.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/l1158492569.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/u1191230044.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/u1191230044.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/g1191629025.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/g1191629025.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/h1183887211.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/h1183887211.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/x1155423960.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/x1155423960.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/t1191234802.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/t1191234802.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/e1191616048.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/e1191616048.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/c1187760302.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/c1187760302.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/u1172682421.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/u1172682421.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/v1173767938.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/v1173767938.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/p1176859258.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/p1176859258.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/s1185763843.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/s1185763843.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/e1191726073.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/e1191726073.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/l1191626006.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/l1191626006.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/r1191422542.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/r1191422542.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/f1191337222.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/f1191337222.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/s1188945072.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/s1188945072.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/r1191709797.json
#   [CALLING] Lens for mask 1
#   [CALLING] Lens for mask 2
#   [CALLING] Lens for mask 3
#   [CALLING] Lens for mask 4
#   [CALLING] Lens for mask 5
#   [CALLING] Lens for mask 6
#   [CALLING] Lens for mask 7
#   [CALLING] Lens for mask 8
#   [CALLING] Lens for mask 9
#   [CALLING] Lens for mask 10
#   [CALLING] Lens for mask 11
#   [CALLING] Lens for mask 12
#   [CALLING] Lens for mask 13
#   [CALLING] Lens for mask 14
#   [CALLING] Lens for mask 15
#   [CALLING] Lens for mask 16
#   [CALLING] Lens for mask 17
#   [CALLING] Lens for mask 18
#   [CALLING] Lens for mask 19
#   [CALLING] Lens for mask 20
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/r1191709797.json
#
# [PROCESSING] ../zm_scraper/listing/gdino/lens/5/n1125471554.json
#   [CALLING] Lens for mask 1
#   [UPDATED] ../zm_scraper/listing/gdino/lens/5/n1125471554.json
#
# ✅ All JSON files updated with Scrapingdog results!

# %% [markdown]
# ## Test scripts

# %%
# Scrapingdog
import requests
url = "https://api.scrapingdog.com/google_lens"
image = "https://storage.googleapis.com/strustore-dev.firebasestorage.app/crops/1/x1121603563/crop_6.png"
params = {
    "api_key": SCRAPINGDOG_API_KEY,
  "url": f"https://lens.google.com/uploadbyurl?url={image}",
}

response = requests.get(url, params=params)

if response.status_code == 200:
  data = response.json()
  print(data['lens_results'])
else:
  print(f"Request failed with status code: {response.status_code}")
