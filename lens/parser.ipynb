# %%
MODEL="gdino" #sam/gdino/manual
LENS = f"../gdinoOutput/lens/"
FINAL = f"../gdinoOutput/final-original/"
TEXT_PROMPT_CSV = "../zm_scraper/items-prompt.csv"
RESULTS_THRESH = 0.05 # only keep tokens that has appeared in at least 10% of results
TOKENS_LIMIT = 0.5 #only keep top x% of sorted tokens 


MASTER_LIST_CSV = "../zm_scraper/master-list.csv"

# %% [markdown]
# ## Parsing Lens data
# 1. based on kept data: keep most frequent keywords
# 2. keep the list to a len of 10 for most freq keywords
# 3. embed this list of freq keywords and find the item closest to our embedded list of items (cosine similarity).

# %%
# NLTK data has been manually installed
import nltk
print("NLTK data ready!")
# Out:
# NLTK data ready!

# %%
# Filter each results array, and extract top substrings algorithm
# 1. Preprocess titles: make lower case, remove stopwords based on the Natural Language Toolkit (NLTK)
# 2. Extract top 10% substrings based on the n-gram tokens. Threshold of count is at least 10% of number of searches obtained
# 3. Store those tokens inside the json 'tokens' key
# Note to future self; remove the bad error checking in request when google lens does not return anything

import os
import json
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.util import ngrams
from collections import Counter

stop_words = set(stopwords.words('english'))
custom_stopwords = {
    'ebay', 'amazon', 'homedepot', 'etsy', 'walmart', 'target', 
    'shop', 'sale', 'brandnew', 'free', 'shipping', 'official', 'store'
}
# Merge words to exclude

stop_words = stop_words.union(custom_stopwords)
def preprocess_title(title):
    # Lowercase
    title = title.lower()
    # Extract words
    tokens = re.findall(r'\b\w+\b', title)
    # Remove stopwords
    filtered_tokens = [t for t in tokens if t not in stop_words]
    return filtered_tokens

def update_json_with_tokens(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    updated = False

    for mask_id, mask_info in data.items():
        results = mask_info.get("results", [])
        mask_tokens = []
        
        if results:
            # Threshold: minimum appearances based on n% of number of results
            min_num_results = max(2, int(len(results) * RESULTS_THRESH))
            if isinstance(results, list) and results and results != ["Google Lens didn't return any results."]:
                for result in results:
                    if isinstance(result, dict):
                        title = result.get("title", "").strip()
                        if not title:
                            continue
                        tokens = preprocess_title(title)
                        mask_tokens.extend(tokens)
                        mask_tokens.extend([" ".join(bg) for bg in ngrams(tokens, 2)])  # Add bigrams

            if not mask_tokens:
                mask_info["tokens"] = []
                mask_info["token_counts"] = {}
                continue

            # Count frequencies
            token_counts = Counter(mask_tokens)

            # Filter tokens that meet frequency threshold
#             print(f"Results:{min_num_results}")
            filtered_tokens = [(token, count) for token, count in token_counts.items() if count >= min_num_results]

            # Sort by frequency (descending)
            filtered_tokens.sort(key=lambda x: x[1], reverse=True)

            # Top n% of tokens
            top_n = max(1, int(len(filtered_tokens) * TOKENS_LIMIT))
            top_tokens_with_counts = filtered_tokens[:top_n]
            top_tokens = [token for token, _ in top_tokens_with_counts]
            top_token_counts = {token: count for token, count in top_tokens_with_counts}
            

            # Save filtered tokens and their counts
#             print(f"MASK {mask_id} OLD TOKENS: {token_counts}")
            print(f"MASK {mask_id} TOKENS: {top_tokens}")
            mask_info["tokens"] = top_tokens
            mask_info["token_counts"] = top_token_counts
            updated = True

    if updated:
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(data, f, indent=4, ensure_ascii=False)
        print(f"[UPDATED] {json_path}")
    else:
        print(f"[SKIPPED] {json_path}")

def process_jsons():
    df = pd.read_csv(TEXT_PROMPT_CSV)
    item_ids = df['id'].astype(str).tolist()

    for item_id in item_ids:
        item_folder = os.path.join(LENS, item_id)
        if not os.path.exists(item_folder):
            continue

        for file_name in os.listdir(item_folder):
            if not file_name.endswith(".json"):
                continue
            print(f"FILE: {file_name}")
            
            json_path = os.path.join(item_folder, file_name)
            update_json_with_tokens(json_path)

if __name__ == "__main__":
    process_jsons()
    print("All COMPLETE!")
# Out:
# FILE: p1187246330.json
# MASK 1 TOKENS: ['red', 'leather', 'bag', 'clutch', 'wallet', 'vintage', 'clutch bag', 'pouch', 'com', 'tray', 'x', 'case', 'red leather', 'patent', 'saint', 'laurent', 'saint laurent', 'set', 'new', '5', 'box', 'purse', 'serving', 'cartier', 'authentic']
# [UPDATED] ../gdinoOutput/lens/1/p1187246330.json
# FILE: c1186222082.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'white', 'console', 'dsi white', 'ds', 'handheld', 'dsi console', 'nintendo ds', 'console white', 'tested', 'game', 'system', 'consoles', 'charger', 'japanese', 'game console', 'japan', 'dsi handheld', 'ntsc', 'j', 'ntsc j', 'pen', 'handheld game', 'white console', 'color', 'box', 'used', 'com', 'com nintendo', 'games', 'mario', 'handheld system', 'white handheld', 'youtube', 'ホワイト', 'w', 'touch', 'touch pen']
# [UPDATED] ../gdinoOutput/lens/1/c1186222082.json
# FILE: r1172860507.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'console', 'black', 'japan', 'ds', 'nintendo ds', 'lite', 'ds lite', 'edition', 'handheld', 'charger', 'tested', 'system', 'dsi console', 'game', 'w', 'black console', '001', 'pen', 'console black', 'twl', 'zekrom', 'limited', 'edition black', 'handheld system', 'touch', 'touch pen', 'box', 'console japan', 'twl 001', 'reshiram', 'pokemon', 'games', 'crimson', 'saga', 'xl', 'used', 'color', 'japanese', 'lite crimson', 'game console', 'dsi xl', 'working', 'rare', 'black handheld', 'jp', 'dsi handheld', 'w charger', 'f', 'black w', 'w touch', 'pen japan', 'japan f', 'version', 'crimson black', 'plays', 'usa', '2', 'goddess', 'destiny', '20th', 'anniversary', 'dsi saga', 'saga 2', 'goddess destiny', '20th anniversary', 'reshiram zekrom', 'zekrom edition', 'set', 'stylus']
# [UPDATED] ../gdinoOutput/lens/1/r1172860507.json
# FILE: x1190805798.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'en', 'de', 'segunda', 'mano', 'wallapop', 'segunda mano', 'por', 'eur', 'de segunda', 'mano por', 'eur en', 'la', 'fat', 'ds fat', 'original', 'consola', 'console', 'plata', 'con', 'gris', 'juegos', 'el', 'silver', 'ds plata', 'comprar', 'ntr', '001', 'ntr 001', 'como', 'se', 'en wallapop', 'cargador', 'mercadolibre', 'gris mercadolibre', 'incluye', 'usb', 'r4', '29', 'es', 'mi']
# MASK 2 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'lite', 'ds lite', 'console', 'white', 'japan', 'dsi', 'nintendo dsi', 'charger', 'tested', 'handheld', 'stylus', 'game', 'edition', 'gundam', 'lite console', 'sd', 'uk', 'handheld console', 'console white', 'used', 'final', 'fantasy', '3', 'final fantasy', 'g', 'generation', 'sd gundam', 'g generation', 'dsi console', 'japanese', 'stylus charger', 'box', 'pokemon', 'giratina', '001', 'system', 'polar', 'lite polar', 'polar white', 'r', '4', 'console nintendo', 'limited', 'gundam g', 'lite white', 'console japan', 'dsi white', 'white handheld', 'console stylus', 'lite final', 'charger stylus', 'lite pokemon', 'crystal', 'ff3', 'bundle', 'us', 'twl']
# MASK 3 TOKENS: ['nintendo', 'ds', 'lite', 'nintendo ds', 'ds lite', 'console', 'white', 'tested', 'game', 'charger', 'system', 'japan', 'edition', 'handheld', 'crystal', 'stylus', 'lite white', 'w', 'dsi', 'uk', 'game console', 'lite console', 'used', 'nintendo dsi', 'japanese', 'final', 'fantasy', 'lite final', 'final fantasy', 'polar', 'polar white', 'white console', 'pokemon', 'handheld system', 'box', 'stylus charger', 'limited', 'console charger', '1', 'console white', 'region', 'ver', 'japanese ver', 'pouch', 'original', 'pink', 'youtube', 'lite handheld', 'dsi white', 'white handheld', 'handheld console', 'various', 'colors']
# [UPDATED] ../gdinoOutput/lens/1/x1190805798.json
# FILE: r1140105858.json
# MASK 1 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'lite', 'ds lite', 'en', 'de', 'cargador', 'mercadolibre', 'con', 'sin', 'consola', 'negro', 'juegos', 'stylus', 'r4', 'incluye', 'azul', 'original', 'juego', 'menú', 'tapa', '2', 'caja', 'precio', 'se', 'negro mercadolibre', 'interés', 'sin interés', 'black', '000', 'usb', 'los', 'la', 'youtube', 'blue', 'gba', 'juegos de', 'rojo', 'por', 'lite azul', 'español', 'cable', 'todos', 'operativos', 'instagram', 'menú en', 'en español', 'español incluye', 'cargador usb', 'todos los', 'para', 'negra', 'lápiz', 'lite negra', 'game', '1', 'cuotas', 'cuotas sin', 'consola nintendo', 'japonesa', 'mundopokeds', 'slot', 'botones', 'mundopokeds nintendo', 'incluye cable', 'cable cargador', 'usb stylus', 'stylus tapa', 'tapa slot', 'slot 2', '2 todos', 'los botones', 'botones operativos', 'nds', 'pantalla', 'de juegos', 'estado', 'las', 'consolas', 'videojuegos', 'navy', 'en caja', 'cargador original', '1 juego', 'lite mercadolibre', 'pokemon', 'mario', 'vendida', 'normal', 'transferencia', 'pago', 'multidioma', 'lee', 'cualquier', 'región', 'idioma', 'compatible', 'requiere', 'vendida nintendo', 'precio normal', 'precio por', 'por transferencia', 'consola japonesa', 'japonesa menú', 'menú multidioma', 'multidioma lee', 'lee juegos', 'de cualquier']
# [UPDATED] ../gdinoOutput/lens/1/r1140105858.json
# FILE: q1183324759.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'rosa', 'de', 'en', 'ds', 'mercadolibre', 'con', 'nintendo ds', 'juegos', 'rosa mercadolibre', 'consola', 'pink', 'console', 'dsi rosa', 'las', 'segunda', 'mano', 'segunda mano', 'por', 'sin', 'r4', 'yahoo', 'mejores', 'ofertas', 'videojuegos', 'las mejores', 'mejores ofertas', 'ofertas en', 'eur', 'wallapop', 'de segunda', 'mano por', 'eur en', 'メルカリ', 'consola nintendo', 'la', 'estado', '任天堂', 'ピンク', 'consolas', 'cargador', 'original', 'de videojuegos', 'tested', 'todo', 'lite', '本体', 'ニンテンドーdsi', 'オークション', 'ニンテンドー', 'yahoo オークション', '2', 'vendido', 'la consola', 'stylus', 'instagram', 'consolas de', 'handheld', 'dsi pink', 'funcionando', 'dsi con']
# [UPDATED] ../gdinoOutput/lens/1/q1183324759.json
# FILE: r1188366109.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'red', 'nintendo ds', 'original', 'game', 'console', 'ds original', '001', 'charger', 'ntr', 'ntr 001', 'video', 'games', 'advance', 'console red', 'gameboy', 'stylus', 'original red', 'video games', 'sp', 'advance sp', 'tested', 'w', '001 console', 'working', 'screen', 'mario', 'kart', 'mario kart', 'cartridge', 'ds console', 'red charger', 'com', 'ds red', 'original nintendo', 'nintendo gameboy', 'gameboy advance', 'used', '1', 'game cartridge', 'refurbished', 'new', 'broken', 'hinge', 'see', 'original ntr', 'charger stylus', 'boy', 'game boy', 'boy advance', 'japan', 'color', 'buy', 'handheld', 'retro', 'online', 'india', 'game console', 'red stylus', 'w mario', 'kart ds', 'works', 'rare', 'video game', 'shell', 'card', 'snes', 'consoles', 'photos']
# [UPDATED] ../gdinoOutput/lens/1/r1188366109.json
# FILE: n1184979547.json
# MASK 1 TOKENS: ['ds', 'nintendo', 'lite', 'nintendo ds', 'ds lite', 'pink', 'console', 'charger', 'game', 'handheld', 'lite pink', 'coral', 'coral pink', 'tested', 'system', 'games', 'lite coral', 'working', 'lite console', 'authentic', 'game console', 'pink handheld', 'stylus', 'usg', 'japan', 'console nintendo', 'works', 'console coral', 'handheld system', 'game authentic', 'rosa', 'lite rosa', 'console handheld', 'video', 'consoles', 'pink console', 'com', 'bundle', 'lite handheld', 'handheld console', 'tested working', '3', 'handheld game', 'noble', 'noble pink', 'console charger', 'w', '001', 'usg 001', 'advance', 'cartridge', 'authentic cartridge', 'cartridge working', 'majo', 'love', 'berry', 'edition', 'authentic nintendo']
# [UPDATED] ../gdinoOutput/lens/1/n1184979547.json
# FILE: k1190934472.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'pink', 'nintendo dsi', 'console', 'dsi pink', 'handheld', 'game', 'system', 'pink handheld', 'ds', 'japanese', 'tested', 'nintendo ds', 'japan', 'handheld system', 'game console', 'original', 'games', 'twl', '001', 'twl 001', 'console pink', 'consoles', 'charger', 'r', 'working', 'box', 'ntsc', 'hot', 'hot pink', 'nds', 'video', 'dsi original', 'dsi console', 'w', 'ver', 'gaming', 'com', 'launch', 'edition', 'dsi launch', 'launch edition', 'pink japanese', 'offerup', 'dsi hot', 'video game', 'u', 'c', 'ntsc u', 'u c', 'got', 'handheld console', '2', '2008', 'pink console', 'japanese ver', 'portable', 'dsi handheld', '256mb', '256mb pink', 'japanese game', 'used']
# [UPDATED] ../gdinoOutput/lens/1/k1190934472.json
# FILE: n1181963058.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'console', 'black', 'ds', 'japan', 'nintendo ds', 'tested', 'charger', 'edition', '001', 'japanese', 'game', 'lite', 'ds lite', 'handheld', 'dsi black', 'dsi console', 'box', 'ver', 'saga', '2', 'pokemon', 'system', 'black console', 'xl', 'dsi xl', 'handheld system', 'edition black', '20th', 'anniversary', 'dsi saga', 'saga 20th', '20th anniversary', 'black japan', 'japan console', 'twl', 'twl 001', 'console japanese', 'pen', 'console black', 'resilam', 'zechrome', 'dsi resilam', 'resilam zechrome', 'zechrome edition', 'manual', 'japanese ver', 'game console', 'used', 'limited', 'goddess', 'destiny', 'saga 2', 'goddess destiny', 'destiny saga', 'anniversary console', 'utl', 'utl 001', 'ntsc', 'w', 'kingdom', 'hearts', 'set', 'kingdom hearts', 'hearts edition', 'black handheld', 'various', 'colors', 'various colors', 'black box', '3']
# [UPDATED] ../gdinoOutput/lens/1/n1181963058.json
# FILE: b1191454294.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'lite', 'nintendo ds', 'ds lite', 'white', 'console', 'box', 'crystal', 'crystal white', 'japan', 'charger', 'game', 'lite crystal', 'lite console', 'tested', 'handheld', 'video', 'white console', 'console box', 'japanese', 'j', 'games', 'system', 'body', 'condition', 'manual', 'picclick', '3ds', 'lite white', 'bundle', 'ntsc', 'region', 'handheld console', 'ntsc j', '001', 'white box', 'edition', 'lite body', '2', 'storage', 'lite handheld', 'white charger', 'w', '00', 'box manual', 'boxed', 'stylus', 'charger stylus', 'video game', 'wii', 'nds', 'dsi', 'nintendo dsi', 'console japan', 'console bundle', 'australia', 'new', 'com', 'ndsl', 'usg']
# MASK 2 TOKENS: ['wii', 'nintendo', 'nintendo wii', 'console', 'white', '001', 'hp', 'u', 'wii u', 'japan', 'wii console', '32gb', 'games', 'mario', 'rvl', 'rvl 001', 'wup', 'tested', '3', 'base', 'cover', 'set', 'w', 'com', 'game', '1', 'bundle', 'system', 'white console', 'controllers', 'new', 'chromebook', 'hp base', 'base cover', 'screen', 'super', 'super mario']
# [UPDATED] ../gdinoOutput/lens/1/b1191454294.json
# FILE: x1144497640.json
# MASK 1 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'silver', 'console', 'original', 'ntr', '001', 'ntr 001', 'ds original', 'handheld', 'system', 'tested', 'game', 'charger', 'ds silver', 'video', 'edition', 'japan', '001 silver', 'video game', 'platinum', 'handheld system', 'ds console', 'works', 'original ntr', 'ds platinum', 'platinum silver', 'original silver', 'broken', 'game console', 'repair', 'parts', 'box', 'stylus', 'silver console', 'console charger', 'color', 'working', 'region', 'gray', 'phat', 'gaming', 'ds handheld', 'hinge', 'handheld video', 'titanium', '001 console', 'consoles']
# [UPDATED] ../gdinoOutput/lens/1/x1144497640.json
# FILE: f1191458213.json
# MASK 1 TOKENS: ['nintendo', 'console', 'new', '2ds', 'xl', 'animal', 'crossing', 'animal crossing', 'ds', 'new nintendo', 'nintendo 2ds', '2ds xl', 'nintendo ds', '3ds', 'japan', 'sp', 'xl animal', 'game', 'edition', 'lite', 'ds lite', 'nintendo 3ds', 'blue', 'japanese', 'advance', 'ver', 'advance sp', 'charger', 'box', 'japanese ver', 'shell', 'gba', 'mori', 'pack', '001', 'gameboy', 'gameboy advance', 'ice']
# MASK 2 TOKENS: ['nintendo', 'advance', '3ds', 'ds', 'monster', 'hunter', 'monster hunter', 'game', 'nintendo ds', 'gameboy', 'gameboy advance', 'new', 'nintendo 3ds', 'games', 'japan', 'video', 'gba', 'video games', 'sealed', 'import', 'cib', 'us', 'boy', 'game boy', 'boy advance', 'new sealed', 'version', 'cross', 'japan import', '4g', '2', 'box', 'xx']
# MASK 3 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'console', 'red', 'mario', 'anniversary', '25th', '25th anniversary', 'super', 'super mario', 'xl', 'japan', 'ds', 'dsi xl', 'bros', 'mario bros', 'bros 25th', 'edition', 'game', 'tested', 'charger', 'nintendo ds', 'japanese', 'games', 'handheld', 'used', 'dsi console', 'video', 'dsi super', 'mario 25th', 'red console', 'box']
# MASK 4 TOKENS: ['nintendo', '3ds', 'dsi', 'xl', 'nintendo dsi', 'nintendo 3ds', 'edition', 'console', 'mario', 'dsi xl', 'red', '25th', 'anniversary', '25th anniversary', 'new', 'ds', 'game', 'tested', 'r', 'handheld', 'anniversary edition', 'bros', 'mario bros', 'nintendo ds', 'super', 'super mario', 'new nintendo', '3ds xl', 'box', 'lite', 'ds lite', 'japan', 'x', 'japanese']
# MASK 5 TOKENS: ['pokemon', 'vanillite', 'sticker', 'nintendo', 'seal', 'pokémon', 'center', 'japanese', 'vanillite pokemon', 'pokemon center', 'deviantart', 'x', 'japan', 'sticker nintendo', 'shiny', 'litwick', 'set', '3']
# MASK 6 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'japan', 'set', 'lot', 'game', '3ds', 'games', 'dragon', 'pokemon', 'nds', '4', 'japanese', 'quest', '7', 'dragon quest', 'ds game', '5', '6', '8', 'ds 3ds', '2', '11', '9', '4 5', '5 6', 'game nds', '7 8', 'software', 'quest 4', 'video', 'video games', 'nds japan', 'piece', 'import', 'game japan', 'ds lot', '1', 'dq', '6 9', '9 3ds', '3ds 7', '8 11', 'used', 'wholesale', '24', 'untested', 'animal', 'crossing', 'wholesale lot', 'lot 24', '24 nintendo', 'japan untested', 'animal crossing', 'square', 'enix', 'ds dragon', 'square enix', 'collection', 'tested', 'set japan', 'emblem', '2006', 'rockman', 'black', 'white', 'diamond', 'pearl', '1 2', 'diamond pearl', '3', 'lot game', 'new', 'super', 'games set', 'etc', 'ds games', 'x', 'game software', 'japan import', 'gundam', '7games']
# MASK 7 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'black', 'console', 'game', 'dsi black', 'handheld', 'charger', 'system', 'japan', 'game console', 'games', 'tested', 'stylus', 'box', 'dsi console', 'ndsi', 'ds', 'video', 'black console', 'japanese', 'handheld system', 'handheld game', 'xl', 'com', 'color', 'used', 'dsi xl', 'console black']
# MASK 8 TOKENS: ['ds', 'nintendo', 'nintendo ds', '3ds', 'nintendo 3ds', 'game', 'mario', 'new', 'japanese', 'super', 'bros', 'super mario', 'mario bros', 'japan', '2', 'ds game', '3ds japanese', 'box', 'nds', 'jp', 'ds japan', 'de', 'new super', 'en', 'dragon', 'quest', 'dragon quest', 'co', 'co jp', 'jp ds', 'lot', 'card', 'lot 2', 'game card', 'training', 'import', 'japan import', '3ds game']
# [UPDATED] ../gdinoOutput/lens/1/f1191458213.json
# FILE: s1119897266.json
# MASK 1 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'console', 'original', 'ntr', '001', 'ntr 001', 'ds original', 'pink', 'tested', 'edition', 'japan', 'silver', 'white', 'charger', 'ds console', 'system', 'mew', 'phat', 'center', 'pokemon', 'color', '001 console', 'limited', 'nds', 'ds ntr', 'shell', 'original nintendo', 'ds mew', 'game', 'stylus', 'limited edition', 'mew edition', 'candy', 'candy pink', 'rare', 'pokemon center', 'region', 'video', 'choose', 'charger choose', 'choose color', 'works', 'tested works', 'console white', 'w', 'center limited', 'handheld', 'working', 'original phat', 'console stylus', 'stylus charger', 'original ntr', 'console pink', 'pink tested', 'console ntr', 'used', 'white ntr', 'box', 'edition console', 'pokémon']
# [UPDATED] ../gdinoOutput/lens/1/s1119897266.json
# FILE: f1152247645.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'console', 'black', 'japan', 'edition', 'game', 'ds', 'dsi console', 'nintendo ds', 'japanese', 'tested', 'charger', 'handheld', 'ver', 'pokemon', 'games', '001', 'lite', 'ds lite', 'dsi black', 'black console', 'japanese ver', 'zekrom', 'system', 'ntsc', 'j', 'ntsc j', 'reshiram', 'edition black', 'twl', 'w', 'box', 'game console', 'color', 'handheld system', 'console black', 'twl 001', 'black handheld', 'stylus', 'console japan', 'various', 'jp', 'ver ntsc', 'j japan', 'kingdom', 'hearts', '2', 'kingdom hearts', 'reshiram zekrom', 'zekrom edition', 'handheld game', 'menu', 'saga', 'black japan', 'plays', 'usa', 'language', 'xl', 'dsi xl', 'xl console', 'various color', 'hearts edition', 'console tested', 'video', 'touch', 'limited', 'mario', 'pen', 'japan menu', 'menu plays', 'plays usa', 'usa game', 'japanese language']
# [UPDATED] ../gdinoOutput/lens/1/f1152247645.json
# FILE: s1191791966.json
# MASK 1 TOKENS: ['nintendo', 'pokemon', 'white', 'dsi', 'nintendo dsi', 'ds', 'pokemon white', 'edition', 'black', 'zekrom', 'nintendo ds', 'console', 'reshiram', 'reshiram zekrom', 'version', 'japan', '3ds', 'black white', 'limited', 'box', 'pokémon', 'zekrom edition', 'pokemon black', 'india', 'games', 'edition pokemon', 'game', 'white version', 'kyurem', 'case', 'म', 'क', 'white nintendo', 'dsi pokemon', 'pokemon reshiram', 'dsi console', 'japanese', 'nintendo 3ds', 'white edition', 'limited edition', 'video', 'cib', 'र', 'स', 'set', 'new', 'dsi reshiram', 'bundle', 'ntsc', 'tested', 'version nintendo', 'buy', 'cover', 'online', 'black kyurem', 'video games', 'ल', 'ह', 'used', 'white set', 'new nintendo', 'white game', 'xl', 'hard', 'pokémon white', 'j', 'western', 'cinematographers', 'association', 'ntsc j', 'western india', 'india cinematographers', 'cinematographers association', 'pocket', 'monster', 'pocket monster', 'page']
# [UPDATED] ../gdinoOutput/lens/1/s1191791966.json
# FILE: x1191598905.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'pink', 'ds', 'console', 'nintendo ds', 'games', 'r', 'game', 'dsi pink', 'handheld', 'youtube', 'nds', 'tested', 'consoles', 'video', 'good', 'charger', 'pink nintendo', 'case', 'japanese', 'original', 'condition', 'card', 'pink console', 'box', 'r nds', 'japan', 'console pink', 'dsi console', 'twl', '001', 'twl 001', 'pal', 'video games', 'w', 'working', 'good condition', 'system', 'stylus', 'nintendods', 'picclick']
# [UPDATED] ../gdinoOutput/lens/1/x1191598905.json
# FILE: q1191599905.json
# MASK 1 TOKENS: ['nintendo', 'console', 'white', 'ds', 'nintendo ds', 'japan', 'lite', 'ds lite', 'tested', 'handheld', '001', 'game', 'sega', 'dreamcast', 'working', 'system', 'hkt', 'sega dreamcast', 'super', 'used', '3000', 'hkt 3000', 'edition', 'ntsc', 'dsi', 'portable', 'games', 'box']
# MASK 2 TOKENS: ['pink', 'ds', 'nintendo', 'keyboard', 'nintendo ds', 'lite', 'ds lite', '2', 'com', 'portable', 'japan', 'console', 'vibration', 'psp', 'rgb', '4', 'mechanical', 'wireless', 'usb', 'sony', 'blossom', 'jp', 'blossom pink', '001', 'gaming', 'case', 'game', 'r', 'plate']
# MASK 3 TOKENS: ['ps3', 'playstation', 'sony', 'console', 'black', 'hp', '3', '4', 'slim', 'playstation 3', '1', 'pro', '2', 'frame', 'playstation 4', 'r']
# MASK 4 TOKENS: ['de', 'youtube', 'mercadolivre', 'e', 'sem', 'parcelamento', 'juros', 'parcelamento sem', 'sem juros', 'para', 'one', 'impressora', 'olx', 'tv', 'com', 'como', 'vídeo', 'r', 'epson']
# MASK 5 TOKENS: ['nintendo', 'ds', 'japan', 'nintendo ds', 'lite', 'ds lite', 'console', 'blue', 'game', 'working', 'siemens', 'ice', 'ice blue', 'tested', 'cassette', 'module', 'used', 'lite ice', '0aa0', 'player', 'blue console']
# MASK 6 TOKENS: ['r', 'vintage', '1', 'snes', 'nintendo', 'ac', 'used', 'reviews', '3', 'super']
# MASK 7 TOKENS: ['system', 'tested', 'white', 'vacuum', 'sealing', 'machine', 'model', 'vintage', '2', 'vacuum sealing', 'r', 'keyboard']
# MASK 8 TOKENS: ['nintendo', 'ds', 'lite', 'ds lite', 'nintendo ds', 'white', 'console', 'japan', 'tested', 'handheld', 'charger', 'game', '3ds', 'nintendo 3ds', 'new', 'edition', 'usg', '001', 'usg 001', 'lite white', 'lite handheld', 'system', 'stylus', 'dsi', 'w', 'video', 'r', 'original', 'uk', 'lite console', 'working', 'consoles', 'used', 'video game', 'nintendods', 'r nintendods', 'ver', 'pink', 'games', 'pokemon', 'limited', 'new nintendo', 'xl', 'giratina', 'lite giratina', 'giratina edition', 'japanese', 'adapter', 'tested japanese', 'japanese ver', 'white console']
# MASK 9 TOKENS: ['nintendo', 'ds', 'lite', 'nintendo ds', 'ds lite', 'rose', 'gold', 'r', '2', 'keyboard', 'metallic', 'pink', 'metallic rose', 'rose gold', 'console', 'one', 'com', 'box', 'cover', '3', '16gb', 'case']
# MASK 10 TOKENS: ['tiktok', 'r', 'youtube', 'black']
# MASK 11 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'lite', 'ds lite', 'console', 'parts', 'blue', 'japan', 'pink', 'lot', 'repair', 'handheld', 'parts repair', 'game', 'junk', 'usg', '001', 'usg 001', 'lite console', 'charger', 'ice', 'ice blue', '10', 'tested', 'lite ice', '5', 'system', 'read', 'working', 'console parts', 'lite handheld', 'handheld system', 'lite usg', 'region', 'repair junk', 'case', 'color', 'uk', 'lite lot', 'description', 'read description', 'dsi', 'dslite', '2', 'game console', 'stylus', 'nds', 'blue console', 'mario', 'pink nintendo', 'retro', 'untested', 'ug', '001 console', 'console lot', 'lot 5', '5 untested', 'untested parts', 'repair japan', 'systems', 'handheld systems', 'lites']
# MASK 12 TOKENS: ['youtube', 'r', 'tiktok', '24', 'help', '1', 'x', '2025', '2025 youtube']
# MASK 13 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'lite', 'ds lite', 'console', 'parts', 'pink', 'lot', 'japan', 'repair', 'junk', 'parts repair', 'charger', 'lite console', 'game', '5', 'handheld', 'usg', '001', 'usg 001', 'console parts', 'blue', 'color', 'coral', 'read', 'lite coral', 'coral pink', 'system', '10', 'repair junk', 'youtube', 'lite usg', '20', 'region', 'video', 'video game', 'lite lot', 'broken', 'consoles', 'untested', 'ug', '001 console', 'console lot', 'lot 5', '5 untested', 'untested parts', 'repair japan', 'dsi', 'repairs', 'parts repairs', 'ice', 'tested', 'lite ice', 'ice blue', 'set', 'random', 'console set', 'random color', 'nds', 'junk parts', '1', 'systems']
# MASK 14 TOKENS: ['black', 'r', 'x', 'box', 'com', '3', 'new', '4', '2']
# MASK 15 TOKENS: ['walter', 'japan', 'carbide', 'de', 'com', 'walkman', 'cassette', 'mint', 'new', 'portable', 'green', 'vintage', 'player', 'cassette player', 'mini', 'case', '5', '12', 'nintendo', 'gel', 'printer', '8', 'x', 'retro', 'camera', 'unisef', 'unisef walkman', 'walkman cassette', 'console', 'cutter', 'machine', 'psp']
# MASK 16 TOKENS: ['8', 'track', '8 track', 'tape', 'track tape', 'untested', 'vintage', 'radio', '2', '1', 'rca', 'inch', '6', 'home', 'transistor', 'transistor radio', 'model', 'cartridge']
# MASK 17 TOKENS: ['black', 'leather', 'size', 'boots', 'com', 'knee', 'women', 'new', 'x', 'blue', 'home', '5', 'shoes', 'poshmark', '10', '2', 'serenelife', 'tote']
# MASK 18 TOKENS: ['de', 'nintendo', 'wii', 'com', 'mercadolibre', 'para', 'en', 'verde', 'con', 'videojuegos', 'consola', 'xbox', 'blanco', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'mx', 'com mx', 'ds', 'juego', 'gratis', 'nintendo wii', '360', 'xbox 360', 'color', 'lite', 'la', 'ds lite', 'envío', 'envío gratis', 'para consola', 'piezas', 'super', 'el', 'original', 'console', 'azul']
# MASK 19 TOKENS: ['youtube', 'hp', 'walter', 'new', 'siemens', '0aa0', 'laserjet', 'printer', 'hp laserjet', '01', '6es7', '4']
# MASK 20 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'lite', 'ds lite', 'console', 'white', 'japan', '3ds', 'super', 'handheld', 'blue', 'game', 'xl', 'nintendo 3ds', 'ice', 'ice blue', '001', 'japanese', 'box', 'new', '2ds', 'mint', 'used', '2', 'charger', 'lite ice']
# MASK 21 TOKENS: ['de', 'para', 'en', 'dp', 'uñas', 'rosa', 'ds', 'tiktok', 'nintendo', 'de uñas', 'portátil', 'mano', 'control', 'lite', 'nintendo ds', 'ds lite', '13', 'pro', 'msh', 'segunda', 'wallapop', 'de segunda', 'segunda mano', 'facebook', '3', 'color', '13 pro', 'con', 'cuotas', 'sin', 'interés', 'cuotas sin']
# MASK 22 TOKENS: ['panel', 'used', 'control', 'vintage', 'jtag', 'cdp312r', 'acs800', 'control panel', 'la', 'untested', 'module', 'com', 'schneider', 'electric', 'schneider electric', 'new', 'tested', 'abb', 'lauterbach', '7708', 'la 7708', 'plc']
# MASK 23 TOKENS: ['8', 'track', '8 track', 'tape', 'track tape', 'vintage', 'untested', 'rca', 'cartridge', 'radio', 'remote', 'tested', 'john', 'denver', 'records', 'john denver', 'tape cartridge', '2', 'model', 'module', 'panasonic']
# MASK 24 TOKENS: ['de', 'e', 'com', 'youtube', 'para', 'em', 'tiktok', 'porta', 'mercadolivre', 'da', 'sem']
# MASK 25 TOKENS: ['メルカリ', 'yahoo', 'ホワイト', 'フリマ', '旧paypayフリマ', 'yahoo フリマ', 'フリマ 旧paypayフリマ', 'docomo', 'ガラケー', 'softbank', '携帯電話', 'リモコン', 'foma', 'オークション', 'yahoo オークション', 'sharp', '501kc', 'digno']
# MASK 26 TOKENS: ['tiktok', 'youtube', '2025', 'instagram']
# MASK 27 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'lite', 'ds lite', 'console', 'parts', 'junk', 'pink', 'japan', 'lot', 'lite console', 'repair', 'parts repair', 'blue', 'game', 'handheld', 'charger', 'color', '5', 'console parts', 'usg', '001', 'usg 001', 'ice', 'ice blue', 'read', '10', 'tested', 'lite ice', 'system', 'region', 'lite lot', 'repair junk', 'lite handheld', 'junk nintendo', 'console japan', 'random', 'random color', 'dsi', 'lite usg', 'adapter', 'broken', 'working', 'handheld system', 'plz', 'item', 'condi', 'plz read', 'read item', 'item condi', 'condi nintendo', 'nds', 'junk parts', 'case', 'stylus', 'w', 'bundle']
# [UPDATED] ../gdinoOutput/lens/1/q1191599905.json
# FILE: d1187227651.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'lite', 'ds lite', 'en', 'rosa', 'de', 'eur', 'es', 'consola', 'segunda', 'mano', 'wallapop', 'segunda mano', 'lite rosa', 'picclick', 'picclick es', 'de segunda', 'pink', 'juegos', 'por', 'mano por', 'eur en', 'con', 'console', 'cargador', 'stylus', 'coral', 'consola nintendo', 'usb', 'rosa nintendo', 'cargador usb', 'para', 'usg', '001', 'game', 'usg 001', 'portátil', 'rosa consola', 'consola portátil', '2', 'probado', 'online', 'coral pink', 'venta', 'region', 'todos', 'los', 'botones', 'todos los', 'los botones', 'menú', 'incluye', 'buen', 'estado', 'lo', 'buen estado', 'bundle', 'videojuegos', 'compra', 'pink game', 'las', 'mejores', 'ofertas', 'consolas', 'las mejores', 'mejores ofertas', 'ofertas en', 'rose']
# [UPDATED] ../gdinoOutput/lens/1/d1187227651.json
# FILE: l1185983984.json
# MASK 1 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'black', 'console', 'charger', 'games', 'dsi black', 'tested', 'game', 'handheld', 'case', 'console black', 'dsi console', 'ver', 'box', 'japan', 'w', 'com', 'ndsi', 'game console', 'dsi handheld', 'japanese', '001', 'cover', 'video', 'matte', 'matte black', 'ds', 'twl', 'twl 001', 'xl', 'replacement', 'full', 'housing', 'complete', 'full housing', 'video games', 'system', 'handheld system', 'black tested', 'dsi matte', 'used', 'black console', 'japanese ver', 'nintendo ds', 'dsi xl', 'shell', 'buttons', 'accessories', 'housing cover', 'cover case', 'dsi ndsi', 'jp', 'w charger', 'consoles', 'bundle', 'lite', 'ds lite']
# [UPDATED] ../gdinoOutput/lens/1/l1185983984.json
# FILE: v1187261662.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'en', 'lite', 'ds lite', 'de', 'blanca', 'eur', 'por', 'segunda', 'mano', 'wallapop', 'segunda mano', 'lite blanca', 'de segunda', 'consola', 'mano por', 'eur en', 'dsi', 'cargador', 'nintendo dsi', 'consola nintendo', 'menú', 'incluye', 'juegos', 'stylus', 'los', 'audio', 'estado', 'menú en', 'console', 'es', 'usb', 'todos', 'botones', 'operativos', 'cargador usb', 'todos los', 'los botones', 'botones operativos', 'operativos audio', 'juegos de', 'pokemon', 'blanco', 'edición', 'cable', 'incluye cable', 'cable cargador', 'usb stylus', '2', 'el', 'la', 'blanca de', 'con', 'edition', 'videojuegos', 'especial', 'funcionando', 'edición especial', 'audio funcionando', 'blanca consola', 'español', 'muy', 'buen', 'lo', 'en español', 'buen estado', 'consolas', 'manuales', '50', '30', 'picclick', 'picclick es', 'en wallapop', 'japan', 'lite console', 'japonés', 'original', 'excelente', 'en japonés', 'excelente estado', 'tapa', 'que', '40', 'blanca menú', 'español incluye', 'muy buen', 'gundam', 'game', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'consolas de', 'de videojuegos', 'lite edición', 'online', 'white', 'libre', 'region']
# [UPDATED] ../gdinoOutput/lens/1/v1187261662.json
# FILE: q1187025650.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'console', 'original', 'silver', 'ds original', 'ntr', '001', 'ntr 001', 'tested', 'japan', 'edition', 'system', 'charger', 'handheld', 'original ntr', 'game', '001 console', 'ds console', 'working', 'works', 'box', 'mew', 'handheld system', 'tested works', 'white', 'ds mew', 'mew edition', 'usa', '1', '001 silver', 'region', 'titanium', 'stylus', 'w', 'original console', 'used', 'center', 'edition console', 'dhl', 'week', 'japan dhl', 'dhl 1', '1 week', 'week usa', 'launch', 'ds launch', 'launch edition', 'system silver', 'game console', 'ds silver', 'color', 'console tested', 'touch', 'pen', 'ds ntr', 'touch pen', 'hinge', 'limited', 'super', 'mario']
# [UPDATED] ../gdinoOutput/lens/1/q1187025650.json
# FILE: l1190830129.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'lite', 'ds lite', 'console', 'navy', 'black', 'handheld', 'system', 'charger', 'game', 'lite console', 'blue', 'enamel', 'japan', 'enamel navy', '001', 'box', 'game console', 'usg', 'usg 001', 'stylus', 'region', 'tested', 'colors', 'working', 'gaming', 'lite black', 'black console', 'onyx', 'onyx black', 'lite handheld', 'video', 'ndsl', 'lite navy', 'jet', 'jet black', 'color', 'various', 'various colors', 'screen', 'w', 'used', 'console enamel', 'handheld system', 'games', 'navy blue', 'video game', 'game system', 'console region', 'lite system', 'ver', 'repair', 'console usg', 'choose', 'handheld console']
# MASK 2 TOKENS: ['nintendo', 'ds', 'lite', 'nintendo ds', 'ds lite', 'console', 'navy', 'game', 'handheld', 'system', 'black', 'lite console', 'blue', 'enamel', 'enamel navy', 'charger', 'japan', 'games', 'game console', '001', 'usg', 'usg 001', 'video', 'tested', 'handheld console', 'lite handheld', 'lite navy', 'various', 'colors', 'box', 'handheld system', 'cobalt', 'w', 'region', 'various colors', 'working', 'stylus', 'color', 'gaming', 'ndsl', 'case', 'console enamel', 'jet', 'nds', 'jet black', 'lite enamel', 'navy handheld', 'game system', 'console region', 'console various', 'ver', 'screen', 'original', 'repair', 'video game']
# [UPDATED] ../gdinoOutput/lens/1/l1190830129.json
# FILE: x1191588773.json
# MASK 1 TOKENS: ['com', 'door', 'white', 'home', 'refrigerator', '4', 'cover', 'toilet', 'whirlpool', 'storage', 'replacement', 'bin', 'x', 'dryer', 'handle', 'shelf', '8', 'door handle', 'tank', 'lid', 'toilet tank', 'kitchen', 'parts']
# MASK 2 TOKENS: ['bag', 'yellow', 'shoulder', 'shoulder bag', 'women', 'leather', 'com', 'wallet', 'cover', 'white', 'beige', 'whole', 'clutch', 'light', 'home', 'size', 'sg', 'foods', 'market']
# MASK 3 TOKENS: ['black', 'com', 'case', 'automotive', 'leather', '5', 'sunglasses', 'gray', 'x', 'owners', 'console', 'small', '2', 'saint', 'laurent', 'blue', 'saint laurent', '1', 'front', 'mercedes', 'manual', 'oem', 'owners manual', 'wallet', 'gold']
# MASK 4 TOKENS: ['home', 'com', 'white', 'depot', 'home depot', '2', 'kitchen', '1', 'pg', 'refrigerator', '4', '5', '8', 'x', '3', 'cover', 'door', 'shelf', 'light', 'white pg', 'bin', 'refrigerator door', 'door shelf', 'plug', 'switch', 'drain']
# MASK 5 TOKENS: ['com', 'white', '2', 'laundry', 'wall', 'led', 'home', 'universal', 'cisco', 'light', 'stand', '5', 'products', 'brush', 'set']
# MASK 6 TOKENS: ['lcd', 'screen', 'display', 'panel', 'new', 'lcd screen', 'warranty', '90', 'days', '90 days', 'days warranty', 'inch', 'lcd display', '7', 'lcd panel', 'screen display', '8', 'display panel', 'panel 90', 'display screen', '15', '5', '1', '6', 'screen panel', '4', '10', 'touch', 'repair', 'inch lcd', 'panel screen']
# MASK 7 TOKENS: ['home', 'depot', 'com', 'home depot', 'white', 'pg', 'tile', 'x', 'question', '1', 'wall', '4', 'pg 1', '1 home', '5', '6', 'ft', '3', 'case', 'cover', 'sq', 'wall tile', 'sq ft', '3 x', 'x 6', 'bath', '0', '2', 'ceramic', '10', 'laundry', 'nails', 'waterproof', 'covers', 'patio', 'set', 'vinyl']
# MASK 8 TOKENS: ['com', 'black', '15', 'laptop', 'electronics', 'keyboard', 'replacement', 'cover', '2', 'touchpad', 'pad', 'new', 'dell', 'inspiron', 'pro', '6', 'surface', 'surface pro', '1', 'desk', 'asus', 'replacement laptop', '5', '4', 'type', 'car', 'touch', '14', 'com replacement', 'laptop touch', 'touch pad', 'pad asus', 'black electronics', 'battery', 'hp', 'dell inspiron', 'inspiron 15']
# MASK 9 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'de', 'rosa', 'juegos', 'con', 'mercadolibre', 'rosa mercadolibre', 'consola', 'en', 'ds', 'la', 'cargador', 'r', 'dsi rosa', 'consolas', 'nintendo ds', 'pink', 'original', 'nintendods', 'r nintendods', 'es', 'memoria', 'sin', 'dsi con', 'estado', 'para', 'ofertas', 'una', 'de juegos', 'videojuegos', 'eur', 'por', 'mi', '32gb', 'juegos rosa', 'sd', 'juegos de', 'ds rosa', 'excelente', 'consola nintendo', '3ds', 'com', 'el', 'las', 'mejores', 'las mejores', 'mejores ofertas', 'ofertas en', 'dsi pink', 'un', 'ndsi', 'standard', 'color', '1200', 'r4', 'excelente estado', 'mx', 'incluye', 'incluye cargador', 'ntsc', '50', 'japanese', 'game', 'portátil', 'como', 'picclick', 'portátil nintendo', 'picclick es', 'facebook', 'intenso', 'rosa intenso', 'rosa en', 'ni', 'botones', 'lápiz', 'cargador lápiz', 'de la', 'la consola', 'se', 'nueva', 'consolas de', 'de videojuegos', 'nds', 'standard color', 'color rosa', '32gb con', 'con juegos', 'funcionando', 'meses', 'interés', 'meses sin', 'sin interés']
# MASK 10 TOKENS: ['red', 'lens', 'light', 'vintage', 'case', 'new', 'tail', 'set', '6', 'led', 'storage', '4', 'bar', 'light bar', 'tail light', 'box', '8', 'star', 'glass', 'inch']
# MASK 11 TOKENS: ['x', 'home', 'com', 'depot', 'home depot', 'tile', 'bag', 'pink', 'pg', '12', '1', 'black', 'stencil', '4', '2', 'new', 'question', 'ceramic', 'wall', 'organizer', 'blush', 'leather', 'mini', 'ipad', '5', 'knife', 'wallet', 'beige']
# MASK 12 TOKENS: ['com', 'electronics', 'replacement', 'laptop', '8', 'asus', 'black', 'wall', 'x', 'battery', 'display', 'case', 'ta', 'cover', 'home', 'new', 'kitchen', 'clipboard', 'dark', 'dell', '0', 'gray', '7', 'office', '3', 'leather', 'storage', 'smart', 'grey', 'repair']
# MASK 13 TOKENS: ['red', 'case', 'x', 'bag', 'vintage', '5', 'leather', 'com', 'clutch', 'plastic', '10', 'pouch', 'purse', 'khaite', 'poshmark', 'coffee', 'bags', 'set', 'box', 'products', 'oliver']
# MASK 14 TOKENS: ['navy', 'home', 'ca', 'r', 'blue', '1', 'fabric', 'com', 'cotton', 'background', 'fabrics', 'office']
# MASK 15 TOKENS: ['white', 'home', 'com', 'x', '1', 'office', 'black', 'magnetic', 'glass', 'board', 'moda', 'smart', 'heating', 'desk', 'luxury', 'shower', 'pg', 'depot', 'sensor', 'pedestal', 'dry']
# MASK 16 TOKENS: ['nintendo', 'dsi', 'nintendo dsi', 'mario', 'xl', 'anniversary', '25th', '25th anniversary', 'dsi xl', 'red', 'super', 'super mario', 'edition', 'bros', 'mario bros', 'anniversary edition', 'ds', 'games', 'console', 'r', 'bros 25th', 'xl 25th', 'nintendo ds', 'charger', 'xl super', 'mario 25th', 'tested', 'video', 'picclick', '3ds', 'system', 'handheld', 'limited', 'edition red', 'used', 'consoles', 'new', 'com', 'video games', 'limited edition', 'nintendods', 'r nintendods', 'game', 'anniversary super', 'anniversary red', 'red video', 'red console', 'japan', 'dsi super', 'working', 'edition mario', 'console red', 'included']
# MASK 17 TOKENS: ['de', '抖音', 'navy', 'r', '1', 'checks', 'blue']
# MASK 18 TOKENS: ['blue', 'com', 'kitchen', 'light', 'drying', 'x', 'glass', 'dish', 'mat', 'tile', 'home', 'dish drying', 'home kitchen', 'green', 'screen', 'door', 'aqua', 'mats', 'pad', 'drying mat', 'rear', 'front', 'laptop', '3d', '6']
# MASK 19 TOKENS: ['com', 'black', 'leather', 'bag', 'online', 'r', 'buy', 'wallet', '2', 'home', 'jewelry', 'clothing', 'shoes', 'clothing shoes', 'tray', 'case', 'desk', 'men', 'purse', 'shoes jewelry', '3', 'box', 'uae', '1', 'gray', 'women', 'price', 'buy online', 'x', 'keyboard', 'compatible', 'office', 'wallets', 'card', 'coin', 'coin purse', 'storage', 'depot', 'home depot', 'size', '8', 'foam', 'pad', 'handbag', 'best', 'online best', 'best price', 'laptop', '15', 'low', 'slim', '100', 'boruto', 'trays', 'hermès', 'spoilers', '2024', 'oil', 'diffuser', 'oil diffuser', 'dacasso', 'pads', 'desk pads', 'genuine', 'head', 'layer', 'cowhide', 'ca', 'wallets men', 'genuine leather', 'leather wallet', 'wallet card', 'card bag', 'bag head', 'head layer', 'layer cowhide']
# MASK 20 TOKENS: ['bag', 'paper', 'bags', 'gift', 'white', 'paper bags', 'packaging', 'black', 'shopping', 'paper bag', 'handle', 'gift bags', 'gift bag', 'com', 'china', 'price', 'large', 'kraft', 'kraft paper', 'box', 'gifts', 'christmas', 'handles', 'logo', 'alibaba', 'shopping bags', 'x', '5', 'luxury', 'made', 'price made', 'made china', 'china com', 'mockup', 'edge', 'black edge', 'ribbon', 'custom', 'wholesale', 'buy', 'wedding', 'clothing', 'alibaba com', 'birthday']
# MASK 21 TOKENS: ['blue', '2', 'buy', 'color', 'box', 'india', 'com', 'de', 'jewellery', 'display', 'cover', 'computer', 'sleeve', 'pcs', 'red']
# MASK 22 TOKENS: ['de', 'en', 'para', 'x', 'blanco', 'del', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'mercadolibre', 'color', 'por', 'tiktok', 'con', 'revestimiento', 'stock', 'sin', 'tela']
# MASK 23 TOKENS: ['com', 'home', 'pillow', 'white', 'x', 'tile', 'kitchen', 'joseph', 'mallord', 'william', 'turner', 'tate', 'joseph mallord', 'mallord william', 'william turner', 'cover', '3', 'home kitchen', 'body', 'ivory', 'accessories', 'pack', 'storage', 'zipper', 'women', '1', 'beige', '12', 'leather', 'wall']
# MASK 24 TOKENS: ['screen', 'com', 'inch', 'glass', 'edge', 'laptop', 'black', 'lenovo', '6', 'lcd', 'led', 'galaxy', 'pro', 'samsung', '15', '15 6', '2', 'online', 'mobile', 'tempered', 'redmi', '1', 'tempered glass', 'edge edge', 'tv', 'display', 'panelook', 'panelook com', 'ल', 'sheet']
# MASK 25 TOKENS: ['nintendo', 'console', 'dsi', 'ds', 'nintendo ds', 'nintendo dsi', 'game', 'lite', 'ds lite', 'picclick', 'various', 'color', 'ndsi', 'japanese', 'handheld', '3ds', 'shell', 'consoles', 'lot', 'colors', 'charger', 'various colors', 'tested', 'set', '10', 'screen', 'housing', 'case', 'cover', 'buttons', 'replacement', 'video', 'select', 'dsi console', 'console various']
# MASK 26 TOKENS: ['tile', 'home', 'x', 'depot', 'home depot', 'pg', 'wall', 'ft', '1', 'gray', '5', 'wall tile', 'sq', 'sq ft', 'pg 1', '1 home', 'porcelain', 'light', 'case', '4', 'sample', 'question', 'floor', 'white', 'reviews', 'ivy', 'hill', 'ivy hill', 'hill tile', 'ft case', 'ceramic', '12', '3', '24', 'com', '9', '6', 'x 24', 'floor wall', 'case pg', '8', '4 x', 'tile sample', 'grey', '12 x', 'kitchen', '2', 'light gray', '0', 'porcelain floor', 'polished', 'reviews ivy', '10', 'matte', 'subway', 'light grey', 'tiles', 'outdoor', 'silver', 'glossy', 'rectangular', 'take', 'take home', '11', '5 8', 'ceramic wall', 'glass', 'daltile', '9 5', '3 x', 'x 6', 'air', 'conditioner', 'drip', 'universal', 'air conditioner', 'de', 'glossy ceramic', 'remington', '32', 'tile remington', 'remington light', 'x 5', 'polished porcelain', 'porcelain wall', 'slate', 'waterproof', 'rigid', 'core', 'click', 'lock', 'luxury', 'vinyl', 'plank', 'flooring']
# MASK 27 TOKENS: ['x', 'whiteboard', 'de', 'в', '4', '5', '1', 'home', '2', 'food']
# MASK 28 TOKENS: ['x', 'glass', 'tile', 'com', 'wall', '3', '6', '3 x', 'x 6', '1', 'kitchen', '2', 'green', 'door', 'home', 'window', 'color', 'subway', 'mint', 'door glass', 'soft', 'series', 'wall tile', 'light', 'blue']
# MASK 29 TOKENS: ['de', 'com', 'olx', 'display', 'para', 'e', 'b', 'samsung', 'apple', '9', 'tv', '7', 'на', 'lenovo', 'lcd']
# MASK 30 TOKENS: ['blue', 'nintendo', 'com', 'game', 'case', 'console', '1', 'dsi', 'nintendo dsi', 'playstation', '001', 'w', 'charger', '4', 'purple', 'battery', 'video', 'pro', 'metallic', 'tested']
# MASK 31 TOKENS: ['nintendo', 'ds', 'console', 'nintendo ds', 'lite', 'ds lite', 'charger', 'lite console', 'color', 'junk', 'dsi', 'nintendo dsi', 'parts', 'picclick', 'lot', 'japan', 'region', 'game', 'colors', 'random', 'random color', 'various', '10', 'junk nintendo', 'set', 'w', 'handheld', 'choose', 'choose color', 'blue', '001', 'jpn', '5', 'lot 5', 'console random', 'junk parts', 'various colors', 'tested', 'w charger', 'original', '20']
# MASK 32 TOKENS: ['vintage', 'signed', 'white', 'x', 'art', 'print', 'movie', 'photo', 'poster', 'new', 'japanese', 'black', 'rare', 'original', '5']
# MASK 33 TOKENS: ['1', 'office', 'white', 'x', 'paper', 'products', 'office products', 'com', 'ट', 'envelopes', '3', '4', 'प', 'स', 'स ट', 'check', '100', 'system', '5', 'pack', 'tile']
# MASK 34 TOKENS: ['com', 'home', 'holder', 'gray', 'depot', 'home depot', 'console', 'cover', 'ford', 'white', 'cup', 'nissan', 'rear', 'center', 'black', '96965', 'automotive', 'grey', 'pg', 'kitchen', 'new', 'desk', 'plate', 'flexible', 'spring', 'magnetic', 'mono']
# MASK 35 TOKENS: ['bag', 'zipper', 'com', 'canvas', 'pouch', 'blue', 'bags', 'bank', 'money', 'pencil', 'navy', 'tool', 'cash', 'leather', 'organizer', 'deposit', 'clutch', 'storage', 'office', 'pencil bag', 'cotton', 'x', 'travel', 'shoulder', 'wallet', 'case', 'makeup', 'tools', 'women', 'tool bag', 'products', 'office products', 'black', 'wristlet', '4', 'inches', 'canvas zipper', 'zipper pouch', 'small', 'shoulder bag', '2', 'nwt', 'bill', 'money bags', 'cosmetic', 'receipt']
# MASK 36 TOKENS: ['white', 'home', '3', 'water', 'kit', 'led', 'battery', 'wall', 'heater', 'water heater', 'buy', 'smart', 'com', 'instantaneous', 'instantaneous water', 'detector', 'cover', 'switch', 'socket']
# [UPDATED] ../gdinoOutput/lens/1/x1191588773.json
# FILE: j1191431672.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'lite', 'ds lite', 'console', 'white', 'dsi', 'nintendo dsi', 'japan', 'edition', 'game', 'crystal', 'tested', 'final', 'fantasy', 'final fantasy', 'handheld', 'game console', 'console white', 'lite final', 'limited', 'pokemon', 'edition console', 'lite white', 'system', 'lite console', 'used', 'w', 'dsi console', 'gundam', 'fantasy crystal', '2', 'limited edition', 'console tested', '001', 'crystal white', 'crystal edition', 'stylus', 'charger', 'pen', 'chronicles', 'crystal chronicles', 'software', 'echoes', 'time', 'echoes time', 'giratina', 'japanese', 'usg', 'gaming', 'jp', 'usg 001', 'iii', 'fantasy iii', 'iii crystal', 'white w', 'box', 'lite crystal', 'white console', 'console japan', 'touch']
# MASK 2 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'japan', 'japanese', 'アルクの10分間英語マスター', 'training', 'games', 'import', 'japan import', 'brain', 'master', 'ds japan', 'game', 'yahoo', 'japanese nintendo', '10', '中級', 'used', 'punkan', 'eigo', '10 punkan', 'punkan eigo', 'eigo master', '新品', 'lot', 'オークション', 'alc', 'yahoo オークション', '初級', 'com', 'メルカリ', 'ds アルクの10分間英語マスター', 'アルクの10分間英語マスター 中級', 'software', 'ds training', '2025年最新', '未使用品一覧', '2025年最新 yahoo', '新品 未使用品一覧', 'alc 10', 'us', 'seller', 'import us', 'us seller', 'アルクの10分間英語マスター 初級', 'オークション ds', 'shiki', 'de', 'kanji', '2', 'ark', 'video', 'video games', '中級 メルカリ', 'adults', 'ds game', 'training adults', '4', 'kids', 'kanshuu', 'japan game', '3', 'maru', 'wo', 'ds japanese', 'age', 'brain age', 'ark 10', 'import video', 'ニンテンドー']
# MASK 3 TOKENS: ['キクタン', 'メルカリ', 'yahoo', 'advanced', '改訂版', 'フリマ', '旧paypayフリマ', 'yahoo フリマ', 'フリマ 旧paypayフリマ', '6000', 'advanced 6000', 'basic', '聞いて覚えるコーパス英単語', 'ラクマ', '4000', 'キクタン advanced', '４０００', '美品', 'basic 4000', 'キクタン basic', 'ｂａｓｉｃ', 'キクタン ｂａｓｉｃ', 'ｂａｓｉｃ ４０００', 'リーディング', 'cd付', 'super', 'japan', 'パス英単語', 'entry', 'キクタン entry', '英検', '美品 キクタン', 'アルク', '聞いて覚えるコ', 'cd', '2000', '改訂版 キクタン', 'entry 2000', 'キクタン リーディング', '英単語', '高校', '大学', '受験', '英語', '入試', '高校 大学', '大学 受験', '英語の超人になる', 'アルク学参シリーズ', '英語の超人になる アルク学参シリーズ', '改訂版の通販', '４０００ 聞いて覚えるコ', '聞いて覚えるコ パス英単語', 'パス英単語 改訂版の通販', '４０００ 聞いて覚えるコーパス英単語', '聞いて覚えるコーパス英単語 メルカリ', '大学受験', '大学入試', '暗記', '英単語 高校', '受験 大学受験', '大学受験 大学入試', '大学入試 英語', '英語 英検', '英検 入試']
# MASK 4 TOKENS: ['layton', 'nintendo', 'ds', 'professor', 'professor layton', 'nintendo ds', 'box', 'diabolical', 'layton diabolical', 'diabolical box', 'games', 'box nintendo', 'global', 'japan', 'bunjang', 'import', 'video', '닌텐도', 'site', 'bunjang global', 'global site', 'japan import', 'game', 'video games', 'japanese', 'complete', 'uk', 'case', 'ds games', 'nintendo 닌텐도', 'devil', 'layton devil', 'us', 'ds japan', '3ds', 'layton nintendo', 'ds professor', 'devil box', 'seller', 'cib', 'import us', 'us seller', 'レイトン教授と悪魔の箱', 'bundle', '2009', 'online', 'picclick', 'kyouju', 'layton kyouju', 'chip']
# MASK 5 TOKENS: ['quest', 'dragon', 'dragon quest', 'ix', 'quest ix', 'starry', 'sentinels', 'skies', 'ix sentinels', 'sentinels starry', 'starry skies', 'nintendo', 'ds', 'nintendo ds', 'skies nintendo', 'ds dragon', 'review', 'skies ds', 'ドラゴンクエストix', 'com', 'com dragon']
# MASK 6 TOKENS: ['ds', 'nintendo', 'nintendo ds', 'japan', 'game', 'import', 'wario', 'japanese', 'games', 'warioware', 'seller', 'touched', 'us', 'us seller', 'trainer', 'lot', 'ds japan', 'warioware touched', 'kabutore', 'trainer kabutore', 'kabushiki', 'baibai', 'kabushiki baibai', 'baibai trainer', 'japan import', 'touched nintendo', 'ds game', 'ds japanese', 'nds', 'import us', 'online', 'uk', 'ware', 'manual', 'wario ware', 'made', 'made wario', 'tank', 'next', 'ver', 'video', 'sawaru', 'collection', 'set', 'video games', 'kabutore nintendo', 'japanese import', '2025年最新', 'yahoo', 'オークション', '新品', '未使用品一覧', '2025年最新 yahoo', 'yahoo オークション', '新品 未使用品一覧', 'sawaru made', 'tank nintendo', '2005', 'ds 2005', 'yawaraka', 'atama', 'juku', 'yawaraka atama']
# MASK 7 TOKENS: ['final', 'fantasy', 'final fantasy', 'ds', 'iv', 'メルカリ', 'nintendo', 'nintendo ds', 'fantasy iv', '4', 'ds final', 'iii', 'fantasy iii', '3', 'iii iv', 'japan', 'set', 'japanese', 'tested']
# [UPDATED] ../gdinoOutput/lens/1/j1191431672.json
# FILE: o1119853616.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'de', 'en', 'las', 'mejores', 'juegos', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'videojuegos', 'fat', 'ds fat', 'consolas', 'en nintendo', 'con', 'ntsc', 'consolas de', 'de videojuegos', 'video', 'la', 'para', 'ds ntsc', 'silver', 'los', 'consola', 'incluye', '1', 'funcionando', 'estado', 'u', 'mercadolibre', 'nds', 'juego', 'pantalla', 'c', 'ntsc u', 'u c', 'j', 'ntsc j', 'juegos de', 'de nintendo', 'original', 'gris', 'cargador', 'consola nintendo', 'youtube', 'instagram', 'es', 'se', 'j consolas', 'standard', 'color', 'platinum', 'sin', 'ds standard', 'platinum silver', 'plata', 'r4', 'plateado', 'cable', 'de video', 'emulador', 'buen', 'este']
# [UPDATED] ../gdinoOutput/lens/1/o1119853616.json
# FILE: c1174455551.json
# MASK 1 TOKENS: ['nintendo', 'ds', 'nintendo ds', 'console', 'original', 'silver', 'ds original', '001', 'game', 'ntr', 'ntr 001', 'ds silver', 'titanium', 'charger', 'mario', 'tested', 'stylus', 'handheld', 'lot', 'platinum', 'ds titanium', 'system', 'works', 'original nintendo', 'silver handheld', 'parts', 'uk', 'original ntr', 'ds platinum', 'box', 'japan', 'super', 'super mario', 'ds console', 'gameboy', 'video', 'handheld video', 'video game', 'game console', 'lite', 'repair', 'junk', 'ds lite', 'console parts']
# [UPDATED] ../gdinoOutput/lens/1/c1174455551.json
# FILE: 1183014126.json
# MASK 1 TOKENS: ['ds', 'nintendo', 'lite', 'ds lite', 'nintendo ds', 'pink', 'console', 'games', 'lite console', 'handheld', 'coral', 'coral pink', 'lite pink', 'lite coral', 'charger', 'tested', 'repair', 'uk', 'pink console', 'lite handheld', 'handheld console', 'rose', 'video', 'video games', 'new', 'stylus', 'console stylus', 'game', 'noble', 'lite noble', 'noble pink', 'parts']
# [UPDATED] ../gdinoOutput/lens/1/x1191588773.json
# FILE: j1191431672.json
# ...
# MASK 3 TOKENS: ['nintendo', '64', 'nintendo 64', 'de', 'n64', 'en', 'videojuegos', 'controller', 'console', 'consola', '64 n64', 'para', 'con', 'youtube', 'de nintendo', 'juegos', 'com', 'cable', 'mando', 'consolas', 'consolas de', 'los', 'la', 'las', 'mejores', 'n64 console', 'system', 'bundle', 'color', 'de videojuegos', 'video', 'games', 'más', 'mercadolibre', 'black', 'game', 'gray', 'joystick', '10', 'el', 'ntsc', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', '2', 'envío', 'gratis', 'envío gratis', 'control', 'wired', 'original', 'consola de', 'negro', 'para consola', 'videojuegos nintendo', '4', 'classic', 'video games', 'en consolas', 'c', 'consola nintendo', 'para nintendo']
# [UPDATED] ../gdinoOutput/lens/5/d1189096064.json
# FILE: x1191729061.json
# MASK 1 TOKENS: ['playstation', 'ps1', '1', 'de', 'sony', 'playstation 1', 'en', 'sony playstation', 'original', 'para', 'gris', 'mercadolibre', 'la', 'scph', 'mando', 'controller', 'control', 'el', 'mandos', 'por', 'classic', 'joystick', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'play', 'los', 'segunda', 'mano', 'eur', 'wallapop', 'de segunda', 'segunda mano', 'mano por', 'eur en', 'gris mercadolibre', 'juegos', 'se', 'consola', 'gray', 'con', 'station', 'play station', 'r', 'fat', 'sin', 'com', 'videojuegos', 'digital', 'caja', 'precio', 'estado', 'en caja', 'ps1 original', '1 ps1', 'facebook', 'oem', 'color', 'cable', 'de playstation', '990', 'del', 'psx', 'gris para', 'para sony', 'youtube', 'games', 'playstation controller']
# MASK 2 TOKENS: ['playstation', 'sony', '1', 'console', 'ps1', 'sony playstation', 'playstation 1', 'scph', '1 ps1', 'controller', 'ps1 console', 'tested', 'gray', 'w', 'system', 'games', 'japan', '1 console', 'game', 'used', 'original', 'gray console', 'ps1 scph', 'bundle', '7000', 'working', 'playstation ps1', '7501', 'scph 7501', 'vintage', 'game console', 'box', '1 scph', 'console ps1', 'works', 'complete', 'w controller', 'memory', 'ps', 'scph 7000', '9001', 'scph 9001', 'console system', 'set', 'vintage sony', '5000']
# [UPDATED] ../gdinoOutput/lens/5/x1191729061.json
# FILE: h1183887211.json
# MASK 1 TOKENS: ['pop', 'n', 'pop n', 'controller', 'music', 'n music', 'konami', 'playstation', 'music controller', 'japan', 'controllers', 'ps1', '1', 'ps2', 'sony', 'dreamcast', 'konami pop', 'playstation 1', 'sony playstation', 'sega', 'n controller', 'video', 'game', 'ps1 ps2', 'video game', 'ps', 'controller konami', 'ru014', '2', 'sega dreamcast', 'game controllers', 'playstation pop', 'controller playstation', 'tested', 'games', 'clear', 'facebook', 'mania', 'de', 'youtube', 'import', 'music video', 'picclick', 'uk', '1 2', 'dc']
# [UPDATED] ../gdinoOutput/lens/5/h1183887211.json
# FILE: q1186635587.json
# MASK 1 TOKENS: ['arcade', 'stick', 'hori', 'pro', 'controller', 'ps3', 'switch', 'arcade stick', 'playstation', 'fighting', 'real', 'real arcade', 'hayabusa', 'fighting stick', 'nintendo', 'arcade pro', 'v', 'pro v', 'nintendo switch', 'fight', 'com', 'fight stick', 'v hayabusa', 'fightstick', 'street', 'fighter', 'street fighter', 'ps4', 'custom', 'japan', 'pad', 'video', 'mini', 'hori real', 'arcade fight', 'rap', 'jp', 'game', '1', '2', 'pc', 'elecom', 'jc', 'tested', '4', 'hayabusa fighting', 'mad', 'catz', 'edition', 'mad catz', 'victrix', 'arcade controller', 'command', 'ps', 'ps1', 'ps2', 'command stick', 'stick ps', 'ps custom', 'ps1 ps2', 'video game', 'xbox', 'games', 'stick nintendo', 'usb', 'gmas01rd', 'work', 'ps3 elecom', 'elecom arcade', 'stick usb', 'usb jc', 'jc gmas01rd', 'gmas01rd pad', 'pad controller', 'controller tested', 'tested work', 'fighter 2', '3d', 'stl', 'pc playstation', 'arcade fightstick', 'ps5', 'hori rap', 'rap real', 'iv', 'fighter iv', 'fs', 'joy', 'custom ps1']
# MASK 2 TOKENS: ['vintage', 'power', '2', '0', 'red', 'used', 'electric', 'transmitter', 'unit', 'battery', 'rare', 'allen', 'bradley', 'allen bradley', 'electronics', 'system', 'converter', 'durite', 'genuine', 'milwaukee', '48', '59', 'charger', '48 59', 'battery charger', 'ac', 'radio', 'amplifier', 'pr', 'fire', '1', 'guitar', 'pedal', '4', 'new', 'safety', 'boss', 'decimator', 'design', 'dmon', 'channel', 'multi', 'hdmi', 'sdi', '24', 'vdc', '24 vdc', 'voltage', 'control', 'voltage converter', 'plus', '9', '6v', '18v', 'milwaukee power', 'power plus', '9 6v', '6v 18v', 'controller', 'hz', 'transistor']
# [UPDATED] ../gdinoOutput/lens/5/q1186635587.json
# FILE: v1191128847.json
# MASK 1 TOKENS: ['gamecube', 'nintendo', 'en', 'nintendo gamecube', 'blanco', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'controladores', 'wii', 'para', 'de', 'control', 'controller', 'en controladores', 'mercadolibre', 'videojuegos', 'joystick', 'com', 'game', 'control gamecube', 'para nintendo', 'white', 'gc', 'mando', 'con', 'cube', 'game cube', 'gamecube blanco', 'smash', 'bros', 'original', 'smash bros', 'super', 'super smash', 'blanco mercadolibre', 'ngc', 'gamecube controller', 'cable', 'con cable', 'inalámbrico', 'en nintendo', 'controladores nintendo', 'u', 'wii u', 'original blanco', 'mx', 'com mx', 'mx videojuegos', 'wired', 'gamecube original', '2', '4', 'controladores de', 'joystick nintendo', 'los', 'gamecube los', 'los controladores']
# [UPDATED] ../gdinoOutput/lens/5/v1191128847.json
# FILE: s1132109786.json
# MASK 1 TOKENS: ['de', 'arcade', 'hori', 'stick', 'fighting', 'fighting stick', 'joystick', 'sega', 'saturn', 'para', 'sega saturn', 'hori fighting', 'en', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'controladores', 'videojuegos', 'controladores de', 'super', 'youtube', 'pc', 'juegos', 'controller', 'japan', 'en controladores', 'de videojuegos', 'para sega', 'con', 'neo', 'mercadolibre', 'box', 'méxico', 'sanwa', '07']
# [UPDATED] ../gdinoOutput/lens/5/s1132109786.json
# FILE: u1172682421.json
# MASK 1 TOKENS: ['nintendo', 'gamecube', 'controller', 'nintendo gamecube', 'gamecube controller', 'purple', 'dol', '2', 'clear', 'indigo', 'game', '003', 'dol 003', 'wii', 'console', 'mario', 'gc', 'controller nintendo', 'boxed', 'controller purple', 'com', 'violet', 'ngc', 'switch', 'games', 'site', 'nintendo site', 'purple clear', '003 boxed']
# [UPDATED] ../gdinoOutput/lens/5/u1172682421.json
# FILE: k1125807070.json
# MASK 1 TOKENS: ['metal', 'thumbsticks', 'ps5', 'analog', 'xbox', 'joystick', 'ps4', 'metal thumbsticks', 'aluminum', 'extremerate', 'thumb', 'replacement', 'silver', 'one', 'xbox one', 'com', 'custom', 'stick', 'controller', 'analog joystick', 'de', 'extremerate custom', 'thumbsticks ps5', 'thumb stick', 'silver metal', 'thumbstick', '2', 'metal analog', 'set', 'alloy', 'aluminum alloy', 'x', 'sticks', 'thumbsticks analog', '3d', 'ps5 controller', 'para', '4', 'buttons', 'playstation', '2pcs', 'rocker', 'rocker metal', 'caps', 'metal aluminum', 'cap', 'joystick cap', 'new', 'для', 'series', 'aluminio', 'black', 'replacement thumbsticks', 'button', 'grips', 'kit', 'set thumbsticks']
# [UPDATED] ../gdinoOutput/lens/5/k1125807070.json
# FILE: k1191729356.json
# MASK 1 TOKENS: ['gamecube', 'nintendo', 'console', 'nintendo gamecube', 'gamecube console', 'game', 'silver', 'tales', 'symphonia', 'japan', 'tales symphonia', 'controller', 'gamecube tales', 'green', 'video', 'symphonia console', 'dol', 'gamecube silver', 'rare', 'symphonic', 'edition', 'good', 'console silver', 'consoles', 'video game', 'bundle', '001', 'jp', 'dol 001', 'japan game', 'region', 'nintendo game', 'console dol', 'games', 'white', 'silver console', 'pokemon', 'set', 'memory', 'card', 'memory card', 'tested', 'symphonic green', 'box', 'japanese', 'w', 'cd', 'game cd', 'cube', 'pack', 'game cube', 'limited', 'used', 'gamecube controller', 'platinum', 'ca', 'ca video', 'video games', 'pal', 'version', 'console pal', 'pal version', 'cable', 'console controller', 'ngc', 'home', 'import', 'console bundle', 'japan import', 'en', 'green gamecube']
# [UPDATED] ../gdinoOutput/lens/5/k1191729356.json
# FILE: b1184294295.json
# MASK 1 TOKENS: ['gamecube', 'nintendo', 'controller', 'nintendo gamecube', 'green', 'gamecube controller', 'tales', 'symphonia', 'symphonic', 'tales symphonia', 'wii', 'symphonic green', 'oem', 'dol', 'r', 'game', 'blue', 'emerald', 'controllers', 'rare', 'cube', 'game cube', 'r gamecube', 'wired', 'japan', 'gamecube wii', '003', 'gc', 'dol 003', 'pack', 'gamecube tales', 'custom', 'com', '2', 'ngc', 'console', 'wavebird', 'tested', 'emerald blue', 'used', 'controller tales', 'symphonia symphonic', 'enjoy']
# [UPDATED] ../gdinoOutput/lens/5/b1184294295.json
# FILE: m1165318477.json
# MASK 1 TOKENS: ['gamecube', 'nintendo', 'nintendo gamecube', 'game', 'rack', 'station', 'storage', 'japan', 'cube', 'storage rack', 'game cube', 'r', 'r gamecube', 'gamecube station', 'station rack', 'video', 'ゲームキューブ', 'casters', 'box', 'case', 'orange', 'anyone', 'retro', 'games', 'rack station', 'yahoo', 'auction', 'used', '1', 'online', 'storage case', 'real', 'salling', 'real yahoo', 'yahoo auction', 'auction salling', 'gamecube storage', 'retro game', 'rare', 'gc', '任天堂', 'controller', 'video game', '3', 'tv', 'tiktok', 'cable', 'ultimate', 'ngc', 'dedicated', 'dedicated storage', 'rack orange', 'japan used']
# MASK 2 TOKENS: ['gamecube', 'nintendo', 'console', 'nintendo gamecube', 'black', 'gamecube console', 'console black']
# MASK 3 TOKENS: ['gamecube', 'nintendo', 'nintendo gamecube', 'console', 'silver', 'controller', 'gamecube console', 'dol', 'game', 'gamecube silver', 'r', 'bundle', '101', 'limited', 'console controller', 'platinum', 'w', 'dol 101', 'system', 'gc', '001', 'tested', 'japan', 'pokemon', 'gamecube pokemon', 'pal', 'r gamecube', 'edition', 'ntsc', 'cable', 'model', 'working', 'dol 001', 'plus', 'cables', 'rare', 'used', 'games', 'jp', 'xd', 'offerup', 'pokemon xd', 'consoles', 'video', 'video game', 'console system', 'limited edition', 'replacement', 'oem', 'port', 'set', 'starlight', 'gold', 'gamecube starlight', 'starlight gold', 'gold console', 'post', 'silver console', 'controllers', '101 console', 'enjoy', 'pack', 'enjoy plus', 'plus pack', 'white', 'u', 'custom', 'tales', 'symphonia']
# [UPDATED] ../gdinoOutput/lens/5/m1165318477.json
# FILE: d1189532281.json
# MASK 1 TOKENS: ['gamecube', 'controller', 'gamecube controller', 'nintendo', 'nintendo gamecube', 'indigo', 'controller indigo', 'wired', 'purple', 'clear', 'indigo purple', 'com']
# MASK 2 TOKENS: ['gamecube', 'controller', 'nintendo', 'nintendo gamecube', 'gamecube controller', 'purple', 'indigo', 'indigo purple', 'dol']
# MASK 3 TOKENS: ['gamecube', 'wavebird', 'control', 'nintendo', 'de', 'nintendo gamecube', 'con', 'en', 'para', 'original', 'controller', 'r', 'mercadolibre', 'inalámbrico', 'gamecube wavebird', 'game', 'r gamecube', 'cube', 'receptor', 'game cube', 'control wavebird', 'com', 'silver', 'gris', 'la', 'por', 'las', 'mejores', 'ofertas', 'las mejores', 'mejores ofertas', 'ofertas en', 'sin', 'videojuegos', 'wii', 'controlador', 'el', 'interés', 'sin interés', 'wireless', 'wavebird wireless', 'ngc', 'wave', 'bird', 'wave bird', 'inalambrico', 'gamecube control', 'wavebird gamecube', '1', 'facebook', 'mando', 'juegos', 'gamecube controller', 'control gamecube', 'mx', 'com mx', 'mx videojuegos', 'grey', 'compatible', 'wireless controller', 'controller grey']
# MASK 4 TOKENS: ['gamecube', 'nintendo', 'controller', 'nintendo gamecube', 'gamecube controller', 'indigo', 'dol', 'purple', 'clear', '003', 'dol 003', 'violet', 'japan', 'game', 'com', 'controller indigo', 'gc', 'tested', 'console', 'cube', 'game cube', 'oem', 'games', 'pad', 'blue', 'indigo purple', 'wii', 'indigo clear', '2', 'ngc', 'controller violet', 'color', 'video', 'video games', 'purple clear', 'gamecube console', 'gamepad', 'nintendo game', 'used', 'bundle', 'console controller', 'wired', 'violet clear', 'original', 'cube controller', 'box', 'controller purple', 'genuine', 'new', '003 purple', 'clear nintendo']
# MASK 5 TOKENS: ['gamecube', 'controle', 'nintendo', 'de', 'game', 'com', 'e', 'para', 'nintendo gamecube', 'wii', 'preto', 'mercadolivre', 'cube', 'game cube', 'controller', 'consoles', 'vídeo', 'de vídeo', 'vídeo game', 'games', 'original', 'fio', 'console', 'controle gamecube', 'olx', 'é', 'ngc', 'usb', 'black', 'br', 'com br', 'preto mercadolivre', 'joystick', 'um', 'r', 'wired', 'acessórios', 'e acessórios', 'com fio', 'clássico', 'compatível', '2', 'para nintendo', 'gamepad', 'brasil', 'são', 'consoles de', 'r gamecube', 'pc', 'br games', 'games e', 'e consoles', 'sem', 'fio para', 'controle de', 'na', 'gamecube controller', 'gc', 'em', 'gamecube original', 'peças', 'peças e', 'acessórios de', 'mac', 'e wii', 'controle clássico']
# MASK 6 TOKENS: ['gamecube', 'controller', 'nintendo', 'nintendo gamecube', 'video', 'black', 'com', 'games', 'video games', 'wired', 'game', 'ngc', 'gamecube controller']
# [UPDATED] ../gdinoOutput/lens/5/d1189532281.json
# FILE: l1191626006.json
# MASK 1 TOKENS: ['3', 'sony', 'playstation', 'playstation 3', 'dualshock', 'blue', 'sony playstation', 'dualshock 3', 'ps3', 'video', 'gaming']
# MASK 2 TOKENS: ['controller', 'ps3', '3', 'blue', 'sony', 'wireless', 'playstation', 'playstation 3', 'dualshock', 'dualshock 3', 'ps3 controller', 'metallic', 'sony playstation', 'wireless controller']
# [UPDATED] ../gdinoOutput/lens/5/l1191626006.json
# FILE: s1185763843.json
# MASK 1 TOKENS: ['gamecube', 'controller', 'orange', 'nintendo', 'nintendo gamecube', 'gamecube controller', 'spice', 'gc', 'oem', 'wii', 'spice orange', 'dol', 'japan', 'ngc', '003', 'dol 003', 'console', 'wired', 'pad', 'pad orange', '2', 'gamecube wii', 'wii controller', 'orange japan', 'controller orange', 'cube', 'orange dol', 'gamepad', 'tested', 'ngc controller', 'controller gc', 'gc pad', '3', 'authentic', 'u', 'controller oem', 'game', 'game cube']
# [UPDATED] ../gdinoOutput/lens/5/s1185763843.json
# FILE: f1191337222.json
# MASK 1 TOKENS: ['nintendo', 'gamecube', 'nintendo gamecube', 'controller', 'silver', 'dol', 'gamecube controller', 'console', 'tested', '003', 'dol 003', 'platinum', 'oem', 'game', 'controller silver', 'bundle', 'w', 'gc', 'controller dol', 'authentic', 'platinum silver', 'genuine', 'wavebird', 'wireless', 'controllers', 'gamecube silver', 'japan', 'working', 'wired', 'gamecube oem', 'original', 'gamecube console', 'silver controller', 'silver tested', '001', 'dol 001', 'pad', 'tested working', 'wii', 'oem platinum', 'wired controller', 'mario', 'controller oem', 'set', 'pad gc', '101', 'system', '2', 'dol 101', 'silver console', 'gamecube wii', 'cube', 'memory', 'card', 'silver dol', 'memory card', 'genuine nintendo', 'gamecube wavebird', 'wavebird controller']
# MASK 2 TOKENS: ['gamecube', 'nintendo', 'nintendo gamecube', 'console', 'silver', 'gamecube console', 'platinum', 'controller', 'dol', 'w', 'bundle', '101', 'video', 'games', '001', 'gamecube platinum', 'platinum silver', 'dol 101', 'console silver', 'dol 001', 'tested', 'gaming', 'system', 'console dol', 'video gaming', 'consoles', 'gamecube silver', 'game', 'complete', 'cables', 'silver nintendo', 'platinum console', 'gc', '4', 'controllers', 'parts', 'repair', 'silver console', 'controller cables', 'edition', 'used', 'authentic', '1', 'owner']
# [UPDATED] ../gdinoOutput/lens/5/f1191337222.json
# FILE: g1191629025.json
# MASK 1 TOKENS: ['3', 'controller', 'sony', 'blue', 'playstation', 'ps3', 'playstation 3', 'sony playstation', 'wireless', 'wireless controller', 'dualshock', 'sony ps3', 'dualshock 3', 'buy', 'game', 'controllers']
# MASK 2 TOKENS: ['3', 'controller', 'blue', 'ps3', 'playstation', 'playstation 3', 'sony', 'oem']
# [UPDATED] ../gdinoOutput/lens/5/g1191629025.json
# All COMPLETE!

# %% [markdown]
# ### Embed token results
# 1. Embed those tokens with LLM.
# 2. Based on the embeddings, derive from the item list what is the item's cosine similairity,
#
# **Embedding Concerns**
# 1. Multilinguity : 'rosa'(Espanol) = 'rose'(English). The embeddings need to be able to match cross language
# 2. Match to item list: soft match hard match?
# 3.

# %% [markdown]
# ## DETERMINISTIC MATCHING

# %%
TRANSLATE=False

# %%
import os
import json
import pandas as pd
from collections import defaultdict
from langdetect import detect
from deep_translator import GoogleTranslator

# Detect and translate individual token if needed
def translate_token(token):
    try:
        lang = detect(token)
        if lang != "en":
            translated = GoogleTranslator(source='auto', target='en').translate(token)
            return translated.lower().strip()
    except:
        pass
    return token.lower().strip()  # fallback: return as-is (lowercased)

# -------------------
# Load Master List
# -------------------
master_list_df = pd.read_csv(MASTER_LIST_CSV)
master_hashmap = dict(zip(master_list_df.iloc[:, 0].astype(str), master_list_df.iloc[:, 1]))

# Normalize master list into token sets
def normalize(text):
    return text.lower().replace("-", " ").split()

master_processed = {}
token_index = defaultdict(set)

for item_id, name in master_hashmap.items():
    tokens = normalize(name)
    master_processed[item_id] = {
        "tokens": set(tokens),
        "type_tokens": {"console", "controller"} & set(tokens),  # type terms
        "raw": name
    }
    for token in tokens:
        token_index[token].add(item_id)

# -------------------
# Deterministic Matching Logic (rank-aware)
# -------------------
def match_mask(ranked_tokens):
    if TRANSLATE:
        translated_ranked = [translate_token(token) for token in ranked_tokens]
        token_weights = {token: len(translated_ranked) - i for i, token in enumerate(translated_ranked)}
    else:
        token_weights = {token.lower(): len(ranked_tokens) - i for i, token in enumerate(ranked_tokens)}
    seen_items = defaultdict(int)

    for token, weight in token_weights.items():
        for item_id in token_index.get(token, []):
            seen_items[item_id] += weight

    # Apply type-token filter
    filtered = {
        item_id: score
        for item_id, score in seen_items.items()
        if master_processed[item_id]["type_tokens"] & set(token_weights.keys())
    }

    # Final selection
    best_match_id = max(filtered.items(), key=lambda x: x[1], default=(None, 0))[0]
    return best_match_id if best_match_id else ""

# -------------------
# Read JSON and Match
# -------------------
def update_json_with_tokens(json_path, item_id, file_name):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    mask_tokens_map = {}
    mask_token_counts_map = {}
    for mask_id, mask_info in data.items():
        tokens = mask_info.get("tokens", [])
        token_counts = mask_info.get("token_counts", {})
        if tokens:
            mask_tokens_map[str(mask_id)] = tokens
            mask_token_counts_map[str(mask_id)] = token_counts

    if not mask_tokens_map:
        print(f"[SKIPPED] No tokens in {json_path}")
        return

    # Run deterministic matching
    final = {
        mask_id: match_mask(tokens)
        for mask_id, tokens in mask_tokens_map.items()
    }

    # Map to human-readable names
    final_readable = {
        mask_id: master_hashmap.get(item_id, "No Match") if item_id else "No Match"
        for mask_id, item_id in final.items()
    }

    output_data = {
        MODEL: final,
        f"{MODEL}_readable": final_readable,
        f"{MODEL}_token_counts": mask_token_counts_map
    }

    # Save output
    output_folder = os.path.join(FINAL, item_id)
    print(output_folder)
    os.makedirs(output_folder, exist_ok=True)
    output_path = os.path.join(output_folder, file_name)

    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(output_data, f, indent=4, ensure_ascii=False)

    print(f"[FINAL SAVED] {output_path}")

# -------------------
# Process All Files
# -------------------
def process_jsons():
    df = pd.read_csv(TEXT_PROMPT_CSV)
    item_ids = df['id'].astype(str).tolist()

    for item_id in item_ids:
        item_folder = os.path.join(LENS, item_id)
        if not os.path.exists(item_folder):
            continue

        for file_name in os.listdir(item_folder):
            if not file_name.endswith(".json"):
                continue
            json_path = os.path.join(item_folder, file_name)
            update_json_with_tokens(json_path, item_id, file_name)

if __name__ == "__main__":
    process_jsons()
    print("ALL COMPLETE!")
# Out:
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/p1187246330.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/c1186222082.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/r1172860507.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/x1190805798.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/r1140105858.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/q1183324759.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/r1188366109.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/n1184979547.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/k1190934472.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/n1181963058.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/b1191454294.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/x1144497640.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/f1191458213.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/s1119897266.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/f1152247645.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/s1191791966.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/x1191598905.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/q1191599905.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/d1187227651.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/l1185983984.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/v1187261662.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/q1187025650.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/l1190830129.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/x1191588773.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/j1191431672.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/o1119853616.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/c1174455551.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/1183014126.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/1190947766.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/g1186111364.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/w1190845066.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/c1191323690.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/p1127453774.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/x1191726070.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/m1133776499.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/o1191069257.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/w1190871465.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/w1191415731.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/n1191681464.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/o1187637806.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/1188971238.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/k1191474797.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/s1175248638.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/1187040966.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/v1191007699.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/s1158964294.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/g1187312653.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/l1190559645.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/c1191011512.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/k1190557636.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/l1180181252.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/h1191357858.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/b1187681880.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/v1157073564.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/t1144496280.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/q1185787171.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/q1177627244.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/d1191065516.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/x1121603563.json
# ../gdinoOutput/final-original/1
# [FINAL SAVED] ../gdinoOutput/final-original/1/f1182381846.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/v1168878467.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/h1055489564.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/v1187327043.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/j1188223998.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/u1159547663.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/l1171615527.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/t1190192579.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/f1109446657.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/p1101871478.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/x1171181348.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/m1191712171.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/e1191332130.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/1191044626.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/m1175679082.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/b1174068183.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/c1132411431.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/n1190944641.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/v1180804864.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/l1189425708.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/c583016002.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/x1185026795.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/c1187483831.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/j1191314319.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/k1184414767.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/n1173190176.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/x1191129028.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/d1181561615.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/p1171340896.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/v1187033255.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/l1191174227.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1190985464.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/e1191338151.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/l1180842849.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1169461915.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/t1191103807.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/p1188443975.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/o1186960589.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/b1187277326.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/j1191735371.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/n1191554586.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/n1191611788.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1179874250.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1190952251.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/d1191355427.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/b1187441783.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/q1191056336.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/1/f1182381846.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/v1168878467.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/h1055489564.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/v1187327043.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/j1188223998.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/u1159547663.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/l1171615527.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/t1190192579.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/f1109446657.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/p1101871478.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/x1171181348.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/m1191712171.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/e1191332130.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/1191044626.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/m1175679082.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/b1174068183.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/c1132411431.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/n1190944641.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/v1180804864.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/l1189425708.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/c583016002.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/x1185026795.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/c1187483831.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/j1191314319.json
# ../gdinoOutput/final-original/2
# [FINAL SAVED] ../gdinoOutput/final-original/2/k1184414767.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/n1173190176.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/x1191129028.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/d1181561615.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/p1171340896.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/v1187033255.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/l1191174227.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1190985464.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/e1191338151.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/l1180842849.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1169461915.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/t1191103807.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/p1188443975.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/o1186960589.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/b1187277326.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/j1191735371.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/n1191554586.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/n1191611788.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1179874250.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1190952251.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/d1191355427.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/b1187441783.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/q1191056336.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/h1191064243.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/h1190298916.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/h1183729569.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1187017242.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/s1167344625.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/1182698598.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/k1183034177.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/w1191481916.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1148753453.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/j1187022551.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/d1190904638.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/l1191485635.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/k1190981428.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/q1191566819.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/v1191497444.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/s1191590524.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/1191741850.json
# [SKIPPED] No tokens in ../gdinoOutput/lens/4/w1160324955.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/j1132611060.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/t1191616766.json
# [SKIPPED] No tokens in ../gdinoOutput/lens/4/l1173441636.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/l1191717769.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/j1191552346.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/r1191413891.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/p1191561874.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/s1191626724.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/n1191677586.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/m1191610582.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/d1189586751.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/m1191439995.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/r1191347605.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/c1191618326.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/w1191421468.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/h1191819480.json
# [SKIPPED] No tokens in ../gdinoOutput/lens/4/e1151547546.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/g1191575542.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/x1191763053.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/f1191683408.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/n1191790097.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/k1191592318.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/e1191586024.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/t1175705831.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/v1190982790.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/f1191723507.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/r1190773866.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/l1191357408.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/b1191609816.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1171719181.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/v1191361604.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/p1176859258.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/e1178664397.json
# [FINAL SAVED] ../gdinoOutput/final-original/3/h1191064243.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/h1190298916.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/h1183729569.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1187017242.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/s1167344625.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/1182698598.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/k1183034177.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/w1191481916.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/m1148753453.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/j1187022551.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/d1190904638.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/l1191485635.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/k1190981428.json
# ../gdinoOutput/final-original/3
# [FINAL SAVED] ../gdinoOutput/final-original/3/q1191566819.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/v1191497444.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/s1191590524.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/1191741850.json
# [SKIPPED] No tokens in ../gdinoOutput/lens/4/w1160324955.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/j1132611060.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/t1191616766.json
# [SKIPPED] No tokens in ../gdinoOutput/lens/4/l1173441636.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/l1191717769.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/j1191552346.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/r1191413891.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/p1191561874.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/s1191626724.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/n1191677586.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/m1191610582.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/d1189586751.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/m1191439995.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/r1191347605.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/c1191618326.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/w1191421468.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/h1191819480.json
# [SKIPPED] No tokens in ../gdinoOutput/lens/4/e1151547546.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/g1191575542.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/x1191763053.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/f1191683408.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/n1191790097.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/k1191592318.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/e1191586024.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/t1175705831.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/v1190982790.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/f1191723507.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/r1190773866.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/l1191357408.json
# ../gdinoOutput/final-original/4
# [FINAL SAVED] ../gdinoOutput/final-original/4/b1191609816.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1171719181.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/v1191361604.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/p1176859258.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/e1178664397.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/g1191190021.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/l1174471422.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1127527151.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1181871260.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/s1188945072.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/h1159731759.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/c1191161357.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/l1158492569.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/m1191333843.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/q1191731679.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1189139732.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/r1191709797.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1174503138.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1182986513.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1191631296.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1125471554.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/e1191726073.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1191341403.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/o1168947584.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/v1173767938.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1155423960.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1168197738.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/o1191731498.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/p1190346016.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/b1160855625.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/r1191422542.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/t1191234802.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/k1166614719.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/b1187284300.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/o1191160640.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/e1191616048.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1191230044.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/t1139631929.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/j1191729279.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1172645589.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/c1187760302.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/d1189096064.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1191729061.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/h1183887211.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/q1186635587.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/v1191128847.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/s1132109786.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1172682421.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/k1125807070.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/k1191729356.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/b1184294295.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/m1165318477.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/d1189532281.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/l1191626006.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/s1185763843.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/f1191337222.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/g1191629025.json
# ALL COMPLETE!
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/g1191190021.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/l1174471422.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1127527151.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1181871260.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/s1188945072.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/h1159731759.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/c1191161357.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/l1158492569.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/m1191333843.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/q1191731679.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1189139732.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/r1191709797.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1174503138.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1182986513.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1191631296.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1125471554.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/e1191726073.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1191341403.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/o1168947584.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/v1173767938.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1155423960.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/n1168197738.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/o1191731498.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/p1190346016.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/b1160855625.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/r1191422542.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/t1191234802.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/k1166614719.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/b1187284300.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/o1191160640.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/e1191616048.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1191230044.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/t1139631929.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/j1191729279.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1172645589.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/c1187760302.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/d1189096064.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/x1191729061.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/h1183887211.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/q1186635587.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/v1191128847.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/s1132109786.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/u1172682421.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/k1125807070.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/k1191729356.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/b1184294295.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/m1165318477.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/d1189532281.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/l1191626006.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/s1185763843.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/f1191337222.json
# ../gdinoOutput/final-original/5
# [FINAL SAVED] ../gdinoOutput/final-original/5/g1191629025.json
# ALL COMPLETE!
